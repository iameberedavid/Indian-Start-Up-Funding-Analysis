# %% [markdown]
# ### Indian Start-Up Funding

# %% [raw]
# ## HYPOTHESIS
#
# Null hypothesis: The sector does not influence the funding amounts received by the start-ups.
#
# Alternate hypothesis: The sector influences the funding amounts received by the start-ups.

# %% [markdown]
# # Questions
#
# 1. How many start-ups got funded each year?
# 2. What is the total funding amount received each year?
# 3. What are the top ten start-ups that received the most single funding?
# 4. What are the top ten start-ups that received the least funding?
# 5. What are the top ten sectors that received the most funding?
# 6. What are the top ten sectors that received the least funding?
# 7. What are the top ten headquarters that received the most funding?
# 8. What are the top ten headquarters that received the least funding?
# 9. What is the trend of funding received by the top 5 HeadQuarters from 2018 to 2021?

# %%
# Importing libraries

import pandas as pd
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as  plt
import seaborn as sns
import scipy.stats as stats

# %%
# Loading the datasets

df1 = pd.read_csv('startup_funding2018.csv')
df2 = pd.read_csv('startup_funding2019.csv')
df3 = pd.read_csv('startup_funding2020.csv')
df4 = pd.read_csv('startup_funding2021.csv')

# %%
# Evaluating the first dataset

df1.head()
# Out:
#       Company Name                                           Industry
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...  \
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location
# 0         Seed       250000       Bangalore, Karnataka, India  \
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# 2          Leading Online Loans Marketplace in India
# 3  PayMe India is an innovative FinTech organizat...
# 4  Eunimart is a one stop solution for merchants ...

# %%
# Evaluating the second dataset

df2.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector
# 0  Bombay Shaving      NaN         NaN        Ecommerce  \
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does
# 0         Provides a range of male grooming products  \
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders
# 0                     Shantanu Deshpande  \
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor     Amount($)
# 0                               Sixth Sense Ventures    $6,300,000  \
# 1                                   General Atlantic  $150,000,000
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4           Innovation in Food and Agriculture (IFA)    $6,000,000
#
#            Stage
# 0            NaN
# 1       Series C
# 2  Fresh funding
# 3       Series D
# 4            NaN

# %%
# Evaluating the third dataset

df3.head()
# Out:
#   Company/Brand Founded HeadQuarter              Sector
# 0    Aqgromalin    2019     Chennai            AgriTech  \
# 1      Krayonnz    2019   Bangalore              EdTech
# 2  PadCare Labs    2018        Pune  Hygiene management
# 3         NCOME    2020   New Delhi              Escrow
# 4    Gramophone    2016      Indore            AgriTech
#
#                                         What it does
# 0                       Cultivating Ideas for Profit  \
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders
# 0                    Prasanna Manogaran, Bharani C L  \
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor    Amount($)     Stage Unnamed: 9
# 0                      Angel investors     $200,000       NaN        NaN
# 1                      GSF Accelerator     $100,000  Pre-seed        NaN
# 2                       Venture Center  Undisclosed  Pre-seed        NaN
# 3  Venture Catalysts, PointOne Capital     $400,000       NaN        NaN
# 4  Siana Capital Management, Info Edge     $340,000       NaN        NaN

# %%
# Evaluating the fourth dataset

df4.head()
# Out:
#     Company/Brand  Founded HeadQuarter          Sector
# 0  Unbox Robotics   2019.0   Bangalore      AI startup  \
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What it does
# 0  Unbox Robotics builds on-demand AI-driven ware...  \
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders
# 0                        Pramod Ghadge, Shahid Memon  \
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor     Amount($)         Stage
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000           NaN
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed

# %% [markdown]
# # Observations
#
# The first dataset does not have columns named "Founded", "Founders" and "Investor" which are in the other three datasets. Considering the fact that the information on these columns do not affect our hypothesis and questions, these columns will be dropped to enable us merge all the datasets. The "What it does" and "Stage" columns that are not relevant to the hypothesis and analytical questions, and will also be dropped in order to make the dataset more manageable and to reduce the amount of noise in the dataset. We will do this while cleaning the datasets.
#
# There is a column named "Unnamed: 9" in the third dataset. Its first five rows have missing values, and other datasets do not contain such column. This column will be examined while cleaning the third dataset.
#
# All the datasets have similar column names except the first dataset. This means that there is need to edit the column names of the first dataset to match the column names of the other datasets. This will be done while cleaning the first dataset.
#
# There will be need to add a column named "Funding Year" to each of the datasets. This "Funding Year" column will show the year of funding that each row belong to, for easy identification when all the datasets are merged, and for anwering our analytical questions.

# %% [markdown]
# # Cleaning the first dataset

# %%
# Evaluating the dataset

df1.head()
# Out:
#       Company Name                                           Industry
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...  \
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location
# 0         Seed       250000       Bangalore, Karnataka, India  \
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# 2          Leading Online Loans Marketplace in India
# 3  PayMe India is an innovative FinTech organizat...
# 4  Eunimart is a one stop solution for merchants ...

# %%
# Changing the column names using a dictionary, to fit the column names of the other datasets.

column_dict = {
    'Company Name': 'Company/Brand',
    'Industry': 'Sector',
    'Round/Series': 'Stage',
    'Location': 'HeadQuarter',
    'About Company': 'What it does',
    'Amount': 'Amount($)'
}

df1 = df1.rename(columns=column_dict)
df1.head()
# Out:
#      Company/Brand                                             Sector
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...  \
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#       Stage    Amount($)                       HeadQuarter
# 0      Seed       250000       Bangalore, Karnataka, India  \
# 1      Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2  Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3     Angel      2000000       Noida, Uttar Pradesh, India
# 4      Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                         What it does
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# 2          Leading Online Loans Marketplace in India
# 3  PayMe India is an innovative FinTech organizat...
# 4  Eunimart is a one stop solution for merchants ...

# %%
# Dropping the "Stage" and "What it does" columns that are irrelevant to our hypothesis and analytical questions

df1 = df1.drop(["Stage", "What it does"], axis=1)
df1.head()
# Out:
#      Company/Brand                                             Sector
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...  \
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#      Amount($)                       HeadQuarter
# 0       250000       Bangalore, Karnataka, India
# 1  ₹40,000,000        Mumbai, Maharashtra, India
# 2  ₹65,000,000           Gurgaon, Haryana, India
# 3      2000000       Noida, Uttar Pradesh, India
# 4            —  Hyderabad, Andhra Pradesh, India

# %%
# Checking the cell values

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  526 non-null    object
#  1   Sector         526 non-null    object
#  2   Amount($)      526 non-null    object
#  3   HeadQuarter    526 non-null    object
# dtypes: object(4)
# memory usage: 16.6+ KB

# %%
# Confirming that there are no empty cells

df1.isna().sum()
# Out:
# Company/Brand    0
# Sector           0
# Amount($)        0
# HeadQuarter      0
# dtype: int64

# %% [markdown]
# There are no empty cells in the dataset.

# %%
# Checking for duplicate rows

df1.duplicated().sum()
# Out:
# 1

# %% [markdown]
# The dataset has one duplicate row

# %%
# Dropping the duplicate row

df1 = df1.drop_duplicates()

# Confirming that the duplicate row has been dropped

df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# The duplicate row has been dropped

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 525 entries, 0 to 525
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  525 non-null    object
#  1   Sector         525 non-null    object
#  2   Amount($)      525 non-null    object
#  3   HeadQuarter    525 non-null    object
# dtypes: object(4)
# memory usage: 20.5+ KB

# %% [markdown]
# After dropping the duplicate row, the number of rows reduced from 526 to 525

# %% [markdown]
# # Checking for data quality

# %%
# Rearranging the columns in the dataset to fit the format in the second, third and fourth datasets

df1 = df1.loc[:, ["Company/Brand", "HeadQuarter", "Sector", "Amount($)"]]
df1.head()
# Out:
#      Company/Brand                       HeadQuarter
# 0  TheCollegeFever       Bangalore, Karnataka, India  \
# 1  Happy Cow Dairy        Mumbai, Maharashtra, India
# 2       MyLoanCare           Gurgaon, Haryana, India
# 3      PayMe India       Noida, Uttar Pradesh, India
# 4         Eunimart  Hyderabad, Andhra Pradesh, India
#
#                                               Sector    Amount($)
# 0  Brand Marketing, Event Promotion, Marketing, S...       250000
# 1                               Agriculture, Farming  ₹40,000,000
# 2   Credit, Financial Services, Lending, Marketplace  ₹65,000,000
# 3                        Financial Services, FinTech      2000000
# 4                 E-Commerce Platforms, Retail, SaaS            —

# %%
# Inspecting the "Company/Brand" column

df1["Company/Brand"].unique()
# Out:
# array(['TheCollegeFever', 'Happy Cow Dairy', 'MyLoanCare', 'PayMe India',
#        'Eunimart', 'Hasura', 'Tripshelf', 'Hyperdata.IO', 'Freightwalla',
#        'Microchip Payments', 'BizCrum Infotech Pvt. Ltd.', 'Emojifi',
#        'Flock', 'Freshboxx', 'Wide Mobility Mechatronics', 'Pitstop',
#        'Mihuru', 'Fyle', 'AppWharf', 'Antariksh Waste Ventures Pvt ltd',
#        'Cogoport', 'PaisaDukan', 'Sleepy Owl Coffee', 'BlueJack',
#        'PregBuddy', 'AgNext Technologies', 'Pando', 'Mintifi', 'Carcrew',
#        'NicheAI', 'Chariot Tech',
#        'Ideal Insurance Brokers/ 121Policy.com', 'Loanzen',
#        'Mojro Technologies', 'Elemential', 'Loadshare', 'Yumlane',
#        'Kriger Campus', 'Pipa+Bella', 'Kaleidofin', 'Chakr Innovation',
#        'IndigoLearn', 'UClean', 'Coutloot', 'Letstrack', 'Pooltoo',
#        'Finzy', 'Fitternity', 'Keito', 'Tolet for Students', 'Chai Kings',
#        'Dainik Jagran', 'Playtoome', 'ONGO Framework', 'Notesgen',
#        'Arogya MedTech', 'Propshop24', 'myUpchar',
#        'MissMalini Entertainment', 'Rooter', 'ZestMoney',
#        'alphaics Corporation', 'MyDentistChoice', 'Sattviko', 'Sensibull',
#        'Bombay Shaving Company', 'MedCords', 'University Living', '&ME',
#        'Enakshi', 'Ultraviolette Automotive', 'Inthree Access',
#        'BUGWORKS Research India', 'Guardian.in', 'PrestLoans', 'Wimoxez',
#        'India Accelerator', 'HappyEMI', 'Wishup', 'Hansel.io', 'Propelld',
#        'PivotRoots', 'ZiffyHomes', 'Carmesi', 'OckyPocky', 'Racetrack',
#        'WHR', 'Asteria Aerospace', 'FabAlley', 'Tranzmeo', 'SBI Life',
#        'Studds Accessories', 'Design Cafe',
#        'NoPaperForms Solutions Pvt. Ltd.', 'Rays Power Infra',
#        'AuthMetrik', 'Khidki', 'LetsTransport', 'Next Digital Solutions',
#        'Portea Medical', 'Aavas Financiers', 'Swiggy', 'Milkbasket',
#        'Nutrisattva (Proliva)', 'Toppr', 'Jagaran Microfin',
#        'Vivriti Capital', 'Be U Salons', 'Impact Guru', 'MobiKwik',
#        'Stones2Milestones', 'Generico', 'Adiuvo Diagnostics',
#        'DataTrained', 'OneAssist',
#        'Satin Creditcare Network Limited (SCNL)',
#        'APAC Financial Services', 'Moglix', 'SEDEMAC Mechatronics',
#        'MadGuy Labs', 'Dee Dee Labs', 'FLEECA', 'Shop101',
#        'FeedMyPockets', 'Housejoy', 'Ambee', 'FoodBuddy', 'Ninjacart',
#        'Olly Smart Credit Card', 'Zestl', 'BYJU’S', 'Wakefit',
#        'Hero Electric', 'Pentation Analytics', 'PerkFinance', 'Roposo',
#        'Plum Goodness', 'Drstore', 'Wow Venue', 'Chizel', 'OTO Capital',
#        'Boodmo', 'Khabri', 'MyNewCar.in', 'HalaPlay Technologies',
#        'PlanetSpark', 'WheelsEMI',
#        'Forum for Innovation Incubation Research and Entrepreneurship',
#        'OYO', 'Quikr', 'Tabono', 'LearnApp', 'Shopkirana', 'Fric Bergen',
#        'Articbot', 'BuildSupply', 'Fusion Microfinance',
#        'Any time Doctor', 'Go Payments', 'Guiddoo World', 'ION Energy',
#        'UnoTag', 'CivilCops', 'Rockmetric', 'Classworks India',
#        'Snapmint', 'artbandhu', 'Survaider', 'Credy', 'iChamp', 'Qandle',
#        'Avishkaar Box', 'Gegadyne Energy', 'HyperXchange', 'Deftouch',
#        'Doodhwala', 'DronaHQ', 'FastFox', 'BuyForexOnline', 'Colive.in',
#        'Agricxlab Private Limited', 'Corefactors', 'Fincash.com',
#        'Pandorum Technologies', 'Shirsa Labs', 'PetSutra', 'Awaaz De',
#        'PinkBlue', 'Eduvanz', 'Rupeek',
#        'Backpacker Panda Holidays Private Limited',
#        'Shape (School Health and Physical Education)', 'Placio',
#        'Aviom India Housing Finance', 'GenRobotic', 'HeyHolidays',
#        'Pratilipi', 'SectorQube', 'Food Memories', 'ZAMROO',
#        'Silversparro Technologies Pvt. Ltd', 'Creator’s Gurukul',
#        'Emflux Motors', 'Tricog Health Services Pvt Ltd', 'Scapic',
#        '6Degree', 'Chrysalis (EZ Vidya)', 'Ekincare', 'Streo', 'Groww',
#        'Cell Propulsion', 'Chezuba', 'Ontrack Technologies Pvt. Ltd',
#        'Wealthtrust', 'Faclon Labs', 'Awign Enterprises', 'CollPoll',
#        'Zyla Health', 'Hubhopper', 'Rubix108 Technologies', 'Workflexi',
#        'Streak', 'Kuants', 'NiYO Solutions', 'Hippo Video', 'Satvacart',
#        'Daaki', 'Simulanis', 'MY CHIRAAG CAB', 'WOTU', 'Flathalt',
#        'True Elements', 'Trendlyne Technologies', 'Planys Technologies',
#        'HealthPlix', 'dishq', 'Entropik Technology', 'myHQ', 'Trell',
#        'Kidovators (by GyanLab)', 'Log 9 Materials', 'VTION',
#        'HousingMan.com', 'Steradian Semiconductors', 'RupeeCircle',
#        'Wooden Street', 'The Ken', 'SaffronStays', 'Vebbler', 'Foyr',
#        'MEngage', 'Inner Being Wellness', 'Kobster', 'Wishberry',
#        'McXtra', 'Magic Crate', 'SmartVizX', 'MySEODoc',
#        'ENLYFT DIGITAL SOLUTIONS PRIVATE LIMITED', 'Scale Labs',
#        'HungerBox', 'Biryani By Kilo', 'Wholesome Habits (EAT Anytime)',
#        'GoBumpr', 'Fixpocket', 'edureka!',
#        'Hashtag Loyalty Private Limited', 'Wow Express', 'ZunRoof',
#        'Eggoz', 'Sqrrl Fintech', 'GalaxyCard', 'IndiQube', 'EGK Foods',
#        'NirogStreet', 'Pixr8', 'Nivesh.com', 'Theranosis Life Sciences',
#        'Poshmiles Online Solutions Private Limited', 'Reculta', 'Orbo.ai',
#        'Inntot Technologies', 'Zoctr Health', 'Hey Deedee',
#        'DigiConnectt Technologys', 'Locus.sh', 'Sports Flashes Pvt. Ltd',
#        'Inc42', 'Picxy', 'Huddle', 'Benepik', 'Cash Suvidha', 'Smartcoin',
#        'Carmel Organics', 'Roadcast', 'Printline Media(ThePrint)',
#        'Creditas Solutions', 'UrbanPiper', 'Doxper', 'i2ifunding',
#        'ShakeDeal', 'HelloVerify', 'Fasal', 'CoinGeto', 'Avail Finance',
#        'Tripeur', 'Wedeterna', 'Stumagz', 'Doubtnut', 'MCaffeine',
#        'TrustCheckr', 'HealthAssure', 'Picture TIme', '1Crowd',
#        'Aarav Unmanned Systems', 'Wellthy Therapeutics Pvt Ltd', 'Nua',
#        'Kuvera.in', 'Livehealth', 'Gramophone', 'Ora', 'Buddy4Study.com',
#        'Predible Health', 'Syncremedies Healthcare Pvt Ltd',
#        'Blueleaf Cyberspace Systems', 'Toffee', 'ORO Wealth',
#        'HealWell24', 'Acko General Insurance', 'arzooo.com',
#        'Bonphul Air Products', 'DheeYantra Research Labs', 'Edyoo',
#        'Chtrbox', 'Aashiyaan Housing and Development Finance',
#        'BetterPlace Safety Solutions Pvt. Ltd.', 'Cashkumar', 'Rocketium',
#        'FreightBazaar', 'OPEN', 'mfine', 'Earth Food', 'Charcoal Eats',
#        'Wishfie', 'The Social Hook', 'FreightBro', 'Finwego', 'Cricnwin',
#        'Wicked Ride Adventure Services Private Limited', 'Career Anna',
#        'ERUDITUS Executive Education', 'Gaia Smart Cities', 'Square Off',
#        'UrbanClap', 'Hospals', 'Kogta Financial India Limited',
#        'Perspectico', 'The Souled Store',
#        'Hush - Speak Up. Make Work Better', 'Drivezy', 'Freyr Energy',
#        'NIRAMAI Health Analytix', 'CloudSek', 'Lendbox', 'Verloop',
#        'Flickstree', 'Paymatrix', 'Idha Skin Clinic', 'InCred', 'Vedantu',
#        'Sportido', 'Stelis Biopharma', 'Magicpin', 'Try & Buy',
#        'Mech Mocha', 'Aye Finance', 'Aldopay', 'Detect Technologies',
#        'Signzy', 'CashRich', 'Cloudnine Hospitals', 'CropIn Technologies',
#        'Billdesk', 'Yaantra', 'TECHBOOZE', 'HealthifyMe', 'hoi foods',
#        'Perpule', 'Royal Sundaram General Insurance Co. Limited',
#        'CleanseCar', 'DRIVEU', 'Spinny',
#        'Asset Reconstruction Company (India) Ltd.', 'Med365 Healthcare',
#        'Dunzo', 'Mobile Premier League (MPL)', 'WalMart India', 'Cred',
#        'Meesho', 'BhaskarGuru', 'Gugu', 'FarmTaaza', 'Vizzbee',
#        'BIGPHI TECHNOLOGIES PVT. LTD.', 'Mobycy', 'Traveo Soft Pvt. Ltd.',
#        'Em Personal Care', 'Lucideus', 'Eupheus Learning', 'GamingMonk',
#        'Sukkhi Jewellery', 'INDwealth', 'Medikabazaar', 'NIRA',
#        'Duroflex Pvt. Ltd.', 'Clensta', 'Jetbrain Robotics', 'Medimetry',
#        'Healthkart', 'Indiabulls Ventures', 'Vistara', 'ClearTax',
#        'Shuttl', 'GuruQ', 'Azure Power', 'Cube', 'RAHI Care', 'Mynvax',
#        'Loans4SME', 'UpCyclersLab', 'Cellerite Systems', 'Taru Naturals',
#        'LetsMD', 'Twenty Two Motors', 'Truebil', 'FarmersFZ', 'Worxogo',
#        'Vivish Technologies (myGate)', 'Singularity Dynamics',
#        'Virtual MetalStreet(MetalStreet)', 'Veritas Finance',
#        'Manjushree Technopack', 'GoZefo', 'Zomato', 'Innov8 Coworking',
#        'RevFin', 'Lavelle Networks', 'Blackbuck', 'Cardekho',
#        'ElasticRun', 'Droom Technology Private Limited', 'Vogo Rentals',
#        'InnerChef', 'LivQuik', 'Disprz', '9stacks', 'Origo',
#        'YourOwnROOM', 'Vahdam Teas', 'Spoofin', 'Strom Motors',
#        'PharmEasy', 'Licious', 'Stanza Living', 'docturnal',
#        'Bounce (Metro Bikes)', 'Technology 9 Labs (T9L)', 'Goals101',
#        'Satya MicroCapital', 'Ummeed Housing Finance Private Limited',
#        'StockEdge', 'Sequretek', 'Avenues Payments India Pvt. Ltd.',
#        'Qbera', 'Urban Ladder',
#        'Planet11 eCommerce Solutions India (Avenue11)', 'DailyNinja',
#        'Iba Halal Care', 'Knocksense', 'Togedr', 'Parkwheels',
#        'ShareChat', 'Cyclops Medtech', 'Livspace', 'NewsBytes',
#        'Leena AI', 'Max Healthcare', 'GoBolt', 'GoGaga', 'Mate Labs',
#        'Furlenco', 'Ola', 'DocPrime', 'CLP India Pvt. Ltd.', 'Xplorabox',
#        'Myra', 'Vokal', 'Kissht', 'Upwards Fintech',
#        'Bon(Bonfleet Solutions)', 'Mamaearth', 'BabyChakra',
#        'Belstar Investment and Finance Private Limited', 'Naaptol',
#        'Moonshine Meadery', 'Verzeo', 'Haazri', 'Connect India',
#        'Flyrobe', 'Scholify', 'Dream11', 'srJna', 'Nykaa', 'Chaayos',
#        'Heelium', 'LT Foods', 'Multibashi', 'Cleardekho', 'Dailyhunt',
#        'SlicePay', 'Udaan', 'Happyeasygo Group', 'Mombay', 'Droni Tech',
#        'Netmeds'], dtype=object)

# %%
# Converting the values in "Company/Brand" column to sentence case

df1["Company/Brand"] = df1["Company/Brand"].str.title()
df1["Company/Brand"].unique()
# Out:
# array(['Thecollegefever', 'Happy Cow Dairy', 'Myloancare', 'Payme India',
#        'Eunimart', 'Hasura', 'Tripshelf', 'Hyperdata.Io', 'Freightwalla',
#        'Microchip Payments', 'Bizcrum Infotech Pvt. Ltd.', 'Emojifi',
#        'Flock', 'Freshboxx', 'Wide Mobility Mechatronics', 'Pitstop',
#        'Mihuru', 'Fyle', 'Appwharf', 'Antariksh Waste Ventures Pvt Ltd',
#        'Cogoport', 'Paisadukan', 'Sleepy Owl Coffee', 'Bluejack',
#        'Pregbuddy', 'Agnext Technologies', 'Pando', 'Mintifi', 'Carcrew',
#        'Nicheai', 'Chariot Tech',
#        'Ideal Insurance Brokers/ 121Policy.Com', 'Loanzen',
#        'Mojro Technologies', 'Elemential', 'Loadshare', 'Yumlane',
#        'Kriger Campus', 'Pipa+Bella', 'Kaleidofin', 'Chakr Innovation',
#        'Indigolearn', 'Uclean', 'Coutloot', 'Letstrack', 'Pooltoo',
#        'Finzy', 'Fitternity', 'Keito', 'Tolet For Students', 'Chai Kings',
#        'Dainik Jagran', 'Playtoome', 'Ongo Framework', 'Notesgen',
#        'Arogya Medtech', 'Propshop24', 'Myupchar',
#        'Missmalini Entertainment', 'Rooter', 'Zestmoney',
#        'Alphaics Corporation', 'Mydentistchoice', 'Sattviko', 'Sensibull',
#        'Bombay Shaving Company', 'Medcords', 'University Living', '&Me',
#        'Enakshi', 'Ultraviolette Automotive', 'Inthree Access',
#        'Bugworks Research India', 'Guardian.In', 'Prestloans', 'Wimoxez',
#        'India Accelerator', 'Happyemi', 'Wishup', 'Hansel.Io', 'Propelld',
#        'Pivotroots', 'Ziffyhomes', 'Carmesi', 'Ockypocky', 'Racetrack',
#        'Whr', 'Asteria Aerospace', 'Faballey', 'Tranzmeo', 'Sbi Life',
#        'Studds Accessories', 'Design Cafe',
#        'Nopaperforms Solutions Pvt. Ltd.', 'Rays Power Infra',
#        'Authmetrik', 'Khidki', 'Letstransport', 'Next Digital Solutions',
#        'Portea Medical', 'Aavas Financiers', 'Swiggy', 'Milkbasket',
#        'Nutrisattva (Proliva)', 'Toppr', 'Jagaran Microfin',
#        'Vivriti Capital', 'Be U Salons', 'Impact Guru', 'Mobikwik',
#        'Stones2Milestones', 'Generico', 'Adiuvo Diagnostics',
#        'Datatrained', 'Oneassist',
#        'Satin Creditcare Network Limited (Scnl)',
#        'Apac Financial Services', 'Moglix', 'Sedemac Mechatronics',
#        'Madguy Labs', 'Dee Dee Labs', 'Fleeca', 'Shop101',
#        'Feedmypockets', 'Housejoy', 'Ambee', 'Foodbuddy', 'Ninjacart',
#        'Olly Smart Credit Card', 'Zestl', 'Byju’S', 'Wakefit',
#        'Hero Electric', 'Pentation Analytics', 'Perkfinance', 'Roposo',
#        'Plum Goodness', 'Drstore', 'Wow Venue', 'Chizel', 'Oto Capital',
#        'Boodmo', 'Khabri', 'Mynewcar.In', 'Halaplay Technologies',
#        'Planetspark', 'Wheelsemi',
#        'Forum For Innovation Incubation Research And Entrepreneurship',
#        'Oyo', 'Quikr', 'Tabono', 'Learnapp', 'Shopkirana', 'Fric Bergen',
#        'Articbot', 'Buildsupply', 'Fusion Microfinance',
#        'Any Time Doctor', 'Go Payments', 'Guiddoo World', 'Ion Energy',
#        'Unotag', 'Civilcops', 'Rockmetric', 'Classworks India',
#        'Snapmint', 'Artbandhu', 'Survaider', 'Credy', 'Ichamp', 'Qandle',
#        'Avishkaar Box', 'Gegadyne Energy', 'Hyperxchange', 'Deftouch',
#        'Doodhwala', 'Dronahq', 'Fastfox', 'Buyforexonline', 'Colive.In',
#        'Agricxlab Private Limited', 'Corefactors', 'Fincash.Com',
#        'Pandorum Technologies', 'Shirsa Labs', 'Petsutra', 'Awaaz De',
#        'Pinkblue', 'Eduvanz', 'Rupeek',
#        'Backpacker Panda Holidays Private Limited',
#        'Shape (School Health And Physical Education)', 'Placio',
#        'Aviom India Housing Finance', 'Genrobotic', 'Heyholidays',
#        'Pratilipi', 'Sectorqube', 'Food Memories', 'Zamroo',
#        'Silversparro Technologies Pvt. Ltd', 'Creator’S Gurukul',
#        'Emflux Motors', 'Tricog Health Services Pvt Ltd', 'Scapic',
#        '6Degree', 'Chrysalis (Ez Vidya)', 'Ekincare', 'Streo', 'Groww',
#        'Cell Propulsion', 'Chezuba', 'Ontrack Technologies Pvt. Ltd',
#        'Wealthtrust', 'Faclon Labs', 'Awign Enterprises', 'Collpoll',
#        'Zyla Health', 'Hubhopper', 'Rubix108 Technologies', 'Workflexi',
#        'Streak', 'Kuants', 'Niyo Solutions', 'Hippo Video', 'Satvacart',
#        'Daaki', 'Simulanis', 'My Chiraag Cab', 'Wotu', 'Flathalt',
#        'True Elements', 'Trendlyne Technologies', 'Planys Technologies',
#        'Healthplix', 'Dishq', 'Entropik Technology', 'Myhq', 'Trell',
#        'Kidovators (By Gyanlab)', 'Log 9 Materials', 'Vtion',
#        'Housingman.Com', 'Steradian Semiconductors', 'Rupeecircle',
#        'Wooden Street', 'The Ken', 'Saffronstays', 'Vebbler', 'Foyr',
#        'Mengage', 'Inner Being Wellness', 'Kobster', 'Wishberry',
#        'Mcxtra', 'Magic Crate', 'Smartvizx', 'Myseodoc',
#        'Enlyft Digital Solutions Private Limited', 'Scale Labs',
#        'Hungerbox', 'Biryani By Kilo', 'Wholesome Habits (Eat Anytime)',
#        'Gobumpr', 'Fixpocket', 'Edureka!',
#        'Hashtag Loyalty Private Limited', 'Wow Express', 'Zunroof',
#        'Eggoz', 'Sqrrl Fintech', 'Galaxycard', 'Indiqube', 'Egk Foods',
#        'Nirogstreet', 'Pixr8', 'Nivesh.Com', 'Theranosis Life Sciences',
#        'Poshmiles Online Solutions Private Limited', 'Reculta', 'Orbo.Ai',
#        'Inntot Technologies', 'Zoctr Health', 'Hey Deedee',
#        'Digiconnectt Technologys', 'Locus.Sh', 'Sports Flashes Pvt. Ltd',
#        'Inc42', 'Picxy', 'Huddle', 'Benepik', 'Cash Suvidha', 'Smartcoin',
#        'Carmel Organics', 'Roadcast', 'Printline Media(Theprint)',
#        'Creditas Solutions', 'Urbanpiper', 'Doxper', 'I2Ifunding',
#        'Shakedeal', 'Helloverify', 'Fasal', 'Coingeto', 'Avail Finance',
#        'Tripeur', 'Wedeterna', 'Stumagz', 'Doubtnut', 'Mcaffeine',
#        'Trustcheckr', 'Healthassure', 'Picture Time', '1Crowd',
#        'Aarav Unmanned Systems', 'Wellthy Therapeutics Pvt Ltd', 'Nua',
#        'Kuvera.In', 'Livehealth', 'Gramophone', 'Ora', 'Buddy4Study.Com',
#        'Predible Health', 'Syncremedies Healthcare Pvt Ltd',
#        'Blueleaf Cyberspace Systems', 'Toffee', 'Oro Wealth',
#        'Healwell24', 'Acko General Insurance', 'Arzooo.Com',
#        'Bonphul Air Products', 'Dheeyantra Research Labs', 'Edyoo',
#        'Chtrbox', 'Aashiyaan Housing And Development Finance',
#        'Betterplace Safety Solutions Pvt. Ltd.', 'Cashkumar', 'Rocketium',
#        'Freightbazaar', 'Open', 'Mfine', 'Earth Food', 'Charcoal Eats',
#        'Wishfie', 'The Social Hook', 'Freightbro', 'Finwego', 'Cricnwin',
#        'Wicked Ride Adventure Services Private Limited', 'Career Anna',
#        'Eruditus Executive Education', 'Gaia Smart Cities', 'Square Off',
#        'Urbanclap', 'Hospals', 'Kogta Financial India Limited',
#        'Perspectico', 'The Souled Store',
#        'Hush - Speak Up. Make Work Better', 'Drivezy', 'Freyr Energy',
#        'Niramai Health Analytix', 'Cloudsek', 'Lendbox', 'Verloop',
#        'Flickstree', 'Paymatrix', 'Idha Skin Clinic', 'Incred', 'Vedantu',
#        'Sportido', 'Stelis Biopharma', 'Magicpin', 'Try & Buy',
#        'Mech Mocha', 'Aye Finance', 'Aldopay', 'Detect Technologies',
#        'Signzy', 'Cashrich', 'Cloudnine Hospitals', 'Cropin Technologies',
#        'Billdesk', 'Yaantra', 'Techbooze', 'Healthifyme', 'Hoi Foods',
#        'Perpule', 'Royal Sundaram General Insurance Co. Limited',
#        'Cleansecar', 'Driveu', 'Spinny',
#        'Asset Reconstruction Company (India) Ltd.', 'Med365 Healthcare',
#        'Dunzo', 'Mobile Premier League (Mpl)', 'Walmart India', 'Cred',
#        'Meesho', 'Bhaskarguru', 'Gugu', 'Farmtaaza', 'Vizzbee',
#        'Bigphi Technologies Pvt. Ltd.', 'Mobycy', 'Traveo Soft Pvt. Ltd.',
#        'Em Personal Care', 'Lucideus', 'Eupheus Learning', 'Gamingmonk',
#        'Sukkhi Jewellery', 'Indwealth', 'Medikabazaar', 'Nira',
#        'Duroflex Pvt. Ltd.', 'Clensta', 'Jetbrain Robotics', 'Medimetry',
#        'Healthkart', 'Indiabulls Ventures', 'Vistara', 'Cleartax',
#        'Shuttl', 'Guruq', 'Azure Power', 'Cube', 'Rahi Care', 'Mynvax',
#        'Loans4Sme', 'Upcyclerslab', 'Cellerite Systems', 'Taru Naturals',
#        'Letsmd', 'Twenty Two Motors', 'Truebil', 'Farmersfz', 'Worxogo',
#        'Vivish Technologies (Mygate)', 'Singularity Dynamics',
#        'Virtual Metalstreet(Metalstreet)', 'Veritas Finance',
#        'Manjushree Technopack', 'Gozefo', 'Zomato', 'Innov8 Coworking',
#        'Revfin', 'Lavelle Networks', 'Blackbuck', 'Cardekho',
#        'Elasticrun', 'Droom Technology Private Limited', 'Vogo Rentals',
#        'Innerchef', 'Livquik', 'Disprz', '9Stacks', 'Origo',
#        'Yourownroom', 'Vahdam Teas', 'Spoofin', 'Strom Motors',
#        'Pharmeasy', 'Licious', 'Stanza Living', 'Docturnal',
#        'Bounce (Metro Bikes)', 'Technology 9 Labs (T9L)', 'Goals101',
#        'Satya Microcapital', 'Ummeed Housing Finance Private Limited',
#        'Stockedge', 'Sequretek', 'Avenues Payments India Pvt. Ltd.',
#        'Qbera', 'Urban Ladder',
#        'Planet11 Ecommerce Solutions India (Avenue11)', 'Dailyninja',
#        'Iba Halal Care', 'Knocksense', 'Togedr', 'Parkwheels',
#        'Sharechat', 'Cyclops Medtech', 'Livspace', 'Newsbytes',
#        'Leena Ai', 'Max Healthcare', 'Gobolt', 'Gogaga', 'Mate Labs',
#        'Furlenco', 'Ola', 'Docprime', 'Clp India Pvt. Ltd.', 'Xplorabox',
#        'Myra', 'Vokal', 'Kissht', 'Upwards Fintech',
#        'Bon(Bonfleet Solutions)', 'Mamaearth', 'Babychakra',
#        'Belstar Investment And Finance Private Limited', 'Naaptol',
#        'Moonshine Meadery', 'Verzeo', 'Haazri', 'Connect India',
#        'Flyrobe', 'Scholify', 'Dream11', 'Srjna', 'Nykaa', 'Chaayos',
#        'Heelium', 'Lt Foods', 'Multibashi', 'Cleardekho', 'Dailyhunt',
#        'Slicepay', 'Udaan', 'Happyeasygo Group', 'Mombay', 'Droni Tech',
#        'Netmeds'], dtype=object)

# %%
# Inspecting the "HeadQuarter" column

df1["HeadQuarter"].unique()
# Out:
# array(['Bangalore, Karnataka, India', 'Mumbai, Maharashtra, India',
#        'Gurgaon, Haryana, India', 'Noida, Uttar Pradesh, India',
#        'Hyderabad, Andhra Pradesh, India', 'Bengaluru, Karnataka, India',
#        'Kalkaji, Delhi, India', 'Delhi, Delhi, India', 'India, Asia',
#        'Hubli, Karnataka, India', 'New Delhi, Delhi, India',
#        'Chennai, Tamil Nadu, India', 'Mohali, Punjab, India',
#        'Kolkata, West Bengal, India', 'Pune, Maharashtra, India',
#        'Jodhpur, Rajasthan, India', 'Kanpur, Uttar Pradesh, India',
#        'Ahmedabad, Gujarat, India', 'Azadpur, Delhi, India',
#        'Haryana, Haryana, India', 'Cochin, Kerala, India',
#        'Faridabad, Haryana, India', 'Jaipur, Rajasthan, India',
#        'Kota, Rajasthan, India', 'Anand, Gujarat, India',
#        'Bangalore City, Karnataka, India', 'Belgaum, Karnataka, India',
#        'Thane, Maharashtra, India', 'Margão, Goa, India',
#        'Indore, Madhya Pradesh, India', 'Alwar, Rajasthan, India',
#        'Kannur, Kerala, India', 'Trivandrum, Kerala, India',
#        'Ernakulam, Kerala, India', 'Kormangala, Karnataka, India',
#        'Uttar Pradesh, India, Asia', 'Andheri, Maharashtra, India',
#        'Mylapore, Tamil Nadu, India', 'Ghaziabad, Uttar Pradesh, India',
#        'Kochi, Kerala, India', 'Powai, Assam, India',
#        'Guntur, Andhra Pradesh, India', 'Kalpakkam, Tamil Nadu, India',
#        'Bhopal, Madhya Pradesh, India', 'Coimbatore, Tamil Nadu, India',
#        'Worli, Maharashtra, India', 'Alleppey, Kerala, India',
#        'Chandigarh, Chandigarh, India', 'Guindy, Tamil Nadu, India',
#        'Lucknow, Uttar Pradesh, India'], dtype=object)

# %% [markdown]
# The cells in the "HeadQuarter" column contain the name of the city, state, and country. Since only the name of the city is required and it is the first name before the first comma on the cells, the first name on each cell will be kept and the rest of the names removed.

# %%
# Splitting the "HeadQuarter" column values by comma and selecting only the first word (name of the city)

df1["HeadQuarter"] = df1["HeadQuarter"].str.split(',').str[0]
df1
# Out:
#          Company/Brand HeadQuarter
# 0      Thecollegefever   Bangalore  \
# 1      Happy Cow Dairy      Mumbai
# 2           Myloancare     Gurgaon
# 3          Payme India       Noida
# 4             Eunimart   Hyderabad
# ..                 ...         ...
# 521              Udaan   Bangalore
# 522  Happyeasygo Group     Haryana
# 523             Mombay      Mumbai
# 524         Droni Tech      Mumbai
# 525            Netmeds     Chennai
#
#                                                 Sector    Amount($)
# 0    Brand Marketing, Event Promotion, Marketing, S...       250000
# 1                                 Agriculture, Farming  ₹40,000,000
# 2     Credit, Financial Services, Lending, Marketplace  ₹65,000,000
# 3                          Financial Services, FinTech      2000000
# 4                   E-Commerce Platforms, Retail, SaaS            —
# ..                                                 ...          ...
# 521   B2B, Business Development, Internet, Marketplace    225000000
# 522                                    Tourism, Travel            —
# 523         Food and Beverage, Food Delivery, Internet         7500
# 524                             Information Technology  ₹35,000,000
# 525         Biotechnology, Health Care, Pharmaceutical     35000000
#
# [525 rows x 4 columns]

# %%
# Inspecting the "HeadQuarter" column again

df1["HeadQuarter"].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurgaon', 'Noida', 'Hyderabad',
#        'Bengaluru', 'Kalkaji', 'Delhi', 'India', 'Hubli', 'New Delhi',
#        'Chennai', 'Mohali', 'Kolkata', 'Pune', 'Jodhpur', 'Kanpur',
#        'Ahmedabad', 'Azadpur', 'Haryana', 'Cochin', 'Faridabad', 'Jaipur',
#        'Kota', 'Anand', 'Bangalore City', 'Belgaum', 'Thane', 'Margão',
#        'Indore', 'Alwar', 'Kannur', 'Trivandrum', 'Ernakulam',
#        'Kormangala', 'Uttar Pradesh', 'Andheri', 'Mylapore', 'Ghaziabad',
#        'Kochi', 'Powai', 'Guntur', 'Kalpakkam', 'Bhopal', 'Coimbatore',
#        'Worli', 'Alleppey', 'Chandigarh', 'Guindy', 'Lucknow'],
#       dtype=object)

# %%
# Identifying the rows that have 'India' in the "HeadQuarter" column.

df1.loc[df1["HeadQuarter"] == 'India']
# Out:
#     Company/Brand HeadQuarter
# 12          Flock       India  \
# 42         Uclean       India
# 59         Rooter       India
# 199        Zamroo       India
#
#                                                 Sector    Amount($)
# 12   Apps, Collaboration, Developer Platform, Enter...            —
# 42   Clean Energy, CleanTech, Laundry and Dry-cleaning  ₹40,000,000
# 59                                              Sports  ₹45,000,000
# 199                    Internet, Marketplace, Shopping            —

# %% [markdown]
# These rows are all in the 2018 (first) dataset. Let's evaluate these rows in the original 2018 dataset.

# %%
# Loading the original 2018 dataset with a different name
ddf1 = pd.read_csv('startup_funding2018.csv')

# Inspecting the 13th row in the original 2018 dataset
ddf1.iloc[12:13]
# Out:
#    Company Name                                           Industry
# 12        Flock  Apps, Collaboration, Developer Platform, Enter...  \
#
#    Round/Series Amount     Location
# 12         Seed      —  India, Asia  \
#
#                                         About Company
# 12  Flock is a real-time messaging and collaborati...

# %%
# Inspecting the 43rd row in the original 2018 dataset
ddf1.iloc[42:43]
# Out:
#    Company Name                                           Industry
# 42       UClean  Clean Energy, CleanTech, Laundry and Dry-cleaning  \
#
#    Round/Series       Amount     Location
# 42         Seed  ₹40,000,000  India, Asia  \
#
#                                         About Company
# 42  UClean is a tech enabled laundry service provi...

# %%
# Inspecting the 59th row in the original 2018 dataset
ddf1.iloc[59:60]
# Out:
#    Company Name Industry Round/Series       Amount     Location
# 59       Rooter   Sports         Seed  ₹45,000,000  India, Asia  \
#
#                         About Company
# 59  Rooter is a mobile-based platform

# %%
# Inspecting the 199th row in the original 2018 dataset
ddf1.iloc[199:200]
# Out:
#     Company Name                         Industry Round/Series Amount
# 199       ZAMROO  Internet, Marketplace, Shopping         Seed      —  \
#
#         Location                                      About Company
# 199  India, Asia  Zamroo is a growing mobile marketplace that al...

# %% [markdown]
# Since each of these rows do not have any city or state name in the "Location" (now named "HeadQuarter") column, 'India' will be replaced with 'N/A'. 'India' cannot be used as the HeadQuarter to avoid a false generalization since other locations in the column are all in India.

# %%
# Replacing 'India' with 'N/A'.
df1["HeadQuarter"] = df1["HeadQuarter"].replace('India', 'N/A', regex=True)

# %%
# Replacing Bangalore and Bangalore City with Bengaluru, which is the official name of the city.

df1["HeadQuarter"] = df1["HeadQuarter"].replace(['Bangalore', 'Bangalore City'], 'Bengaluru', regex=True)
df1["HeadQuarter"].unique()
# Out:
# array(['Bengaluru', 'Mumbai', 'Gurgaon', 'Noida', 'Hyderabad', 'Kalkaji',
#        'Delhi', 'N/A', 'Hubli', 'New Delhi', 'Chennai', 'Mohali',
#        'Kolkata', 'Pune', 'Jodhpur', 'Kanpur', 'Ahmedabad', 'Azadpur',
#        'Haryana', 'Cochin', 'Faridabad', 'Jaipur', 'Kota', 'Anand',
#        'Bengaluru City', 'Belgaum', 'Thane', 'Margão', 'Indore', 'Alwar',
#        'Kannur', 'Trivandrum', 'Ernakulam', 'Kormangala', 'Uttar Pradesh',
#        'Andheri', 'Mylapore', 'Ghaziabad', 'Kochi', 'Powai', 'Guntur',
#        'Kalpakkam', 'Bhopal', 'Coimbatore', 'Worli', 'Alleppey',
#        'Chandigarh', 'Guindy', 'Lucknow'], dtype=object)

# %%
# Inspecting the "Sector" column

df1["Sector"].unique()
# Out:
# array(['Brand Marketing, Event Promotion, Marketing, Sponsorship, Ticketing',
#        'Agriculture, Farming',
#        'Credit, Financial Services, Lending, Marketplace',
#        'Financial Services, FinTech',
#        'E-Commerce Platforms, Retail, SaaS',
#        'Cloud Infrastructure, PaaS, SaaS',
#        'Internet, Leisure, Marketplace', 'Market Research',
#        'Information Services, Information Technology', 'Mobile Payments',
#        'B2B, Shoes', 'Internet',
#        'Apps, Collaboration, Developer Platform, Enterprise Software, Messaging, Productivity Tools, Video Chat',
#        'Food Delivery', 'Industrial Automation',
#        'Automotive, Search Engine, Service Industry',
#        'Finance, Internet, Travel',
#        'Accounting, Business Information Systems, Business Travel, Finance, SaaS',
#        'Artificial Intelligence, Product Search, SaaS, Service Industry, Software',
#        'Internet of Things, Waste Management',
#        'Air Transportation, Freight Service, Logistics, Marine Transportation',
#        'Financial Services', 'Food and Beverage', 'Autonomous Vehicles',
#        'Enterprise Software, Health Care, Hospital, Parenting, Personal Health, SaaS',
#        'Agriculture, Analytics, Big Data, Farming',
#        'Logistics, Supply Chain Management',
#        'Financial Services, Lending',
#        'Automotive, Marketplace, Online Portals',
#        'Artificial Intelligence',
#        'Internet of Things, Telecommunications', 'Insurance',
#        'Information Technology, Logistics, Supply Chain Management',
#        'Blockchain, Developer Tools, Enterprise Software',
#        'Industrial Automation, Logistics, Supply Chain Management',
#        'Food and Beverage, Food Delivery, Snack Food', 'Education',
#        'E-Commerce, Fashion, Jewelry, Retail', 'Renewable Energy',
#        'E-Learning, Education',
#        'Clean Energy, CleanTech, Laundry and Dry-cleaning',
#        'E-Commerce, Fashion, Mobile',
#        'Apps, Messaging, Navigation, Public Safety', 'Transportation',
#        'Fitness, Health Care, Wellness',
#        'Artificial Intelligence, Machine Learning, SaaS, Virtual Assistant',
#        'Hospitality', 'Food and Beverage, Tea',
#        'Media and Entertainment, News, Outdoors',
#        'Broadcasting, Media and Entertainment, Music, Music Streaming, Video, Video Streaming',
#        'B2B, Information Services, Information Technology',
#        'EdTech, Education, Enterprise Software, Peer to Peer',
#        'Health Care, Medical', 'E-Commerce',
#        'Health Care, Hospital, Wellness', '—', 'Sports',
#        'Big Data, Consumer Lending, FinTech',
#        'Cloud Computing, Computer, Semiconductor',
#        'Health Care, Medical, Pharmaceutical', 'Food Processing, Retail',
#        'Trading Platform', "Consumer Goods, Lifestyle, Men's", 'Wellness',
#        'Food and Beverage, Food Processing, Nutrition', 'Fashion',
#        'Automotive, Electric Vehicle, Energy Storage',
#        'Consulting, Retail, Social',
#        'Biotechnology, Life Science, Pharmaceutical, Product Research',
#        'Health Care',
#        'Credit, Financial Services, FinTech, Personal Finance',
#        'Communities, Coworking, Incubators',
#        'Consumer, Financial Services, FinTech',
#        'Consumer Applications, Information Services, Location Based Services, Virtual Assistant',
#        'Mobile, Mobile Apps, Personalization, Test and Measurement, Web Apps',
#        'Education, Financial Services, FinTech',
#        'Advertising, Consulting, Digital Marketing',
#        'Marketplace, Real Estate, Rental Property',
#        'E-Learning, Internet, Video Games',
#        'Artificial Intelligence, Cloud Computing, Video',
#        'Health Care, Information Technology', 'Aerospace',
#        'E-Commerce, Fashion, Lifestyle',
#        'Artificial Intelligence, Business Intelligence, Industrial Automation, Machine Learning',
#        'Home Decor, Home Improvement, Home Renovation, Home Services, Interior Design, Smart Home',
#        'EdTech, Education, Information Services, SaaS', 'Energy, Solar',
#        'B2B, Biometrics, Cyber Security, Fraud Detection, SaaS, Security',
#        'Artificial Intelligence, Social',
#        'Logistics, Transportation, Travel',
#        'Digital Marketing, SEM, SEO, Web Development',
#        'Health Care, Hospital, Medical', 'Finance, Financial Services',
#        'Food Delivery, Food Processing, Internet',
#        'E-Commerce, Food and Beverage, Internet',
#        'Fitness, Food and Beverage, Health Care, Nutrition',
#        'EdTech, Education, Knowledge Management',
#        'Apps, Beauty, Consumer, Retail',
#        'Creative Agency, Crowdfunding, EdTech, Health Care, Internet, Medical, Non Profit, Personal Health',
#        'Consumer Lending, Financial Services, FinTech, Insurance, Lending, Mobile Payments, Payments, Wealth Management',
#        'E-Learning, Education, Higher Education', 'Health Diagnostics',
#        'EdTech, Education', 'Financial Services, SaaS, Security',
#        'Banking, Finance, Financial Services, Non Profit',
#        'B2B, E-Commerce, Mobile',
#        'Automotive, Electric Vehicle, Renewable Energy', 'E-Learning',
#        'Embedded Systems, Health Care, Medical, Product Research',
#        'Apps, E-Commerce, Internet',
#        'Advertising, Human Resources, Marketing',
#        'Beauty, Fitness, Home Services, Internet',
#        'Health Care, Medical Device, Public Safety',
#        'Food Delivery, Online Portals, Restaurants',
#        'AgTech, B2B, Supply Chain Management',
#        'Credit Cards, Finance, Mobile Apps, Mobile Payments, Payments',
#        'Software',
#        'EdTech, Education, Higher Education, Secondary Education',
#        'Manufacturing, Retail', 'Manufacturing',
#        'Information Services, Information Technology, InsurTech',
#        'Consumer Lending, FinTech', 'Internet, Social Network, TV',
#        'Beauty, Health Care', 'Hospital', 'Events',
#        '3D Printing, Manufacturing, Product Design', 'Automotive',
#        'Automotive, Retail', 'Apps, Audio', 'Automotive, E-Commerce',
#        'Digital Entertainment, Fantasy Sports, Sports',
#        'E-Learning, EdTech, Education',
#        'Funding Platform, Incubators, Non Profit',
#        'Hospitality, Hotel, Leisure, Travel',
#        'Classifieds, Internet, Marketplace, Rental Property',
#        'Banking, E-Learning, Trading Platform',
#        'E-Commerce, Mobile, Retail',
#        'Artificial Intelligence, Information Technology',
#        'Enterprise Resource Planning (ERP), Information Services, Information Technology, Real Estate',
#        'Banking, Finance, Financial Services',
#        'Audio, Mobile, Tourism, Travel',
#        'Energy, Energy Storage, Infrastructure',
#        'Government, Information Technology, Software',
#        'Information Technology',
#        'Education, Information Technology, Internet, Mobile, Software',
#        'Consumer Lending, Financial Services, Lending, Personal Finance',
#        'Digital Media, Internet, Media and Entertainment, Online Portals, Social Media',
#        'Business Intelligence, Customer Service, Market Research, SaaS',
#        'Credit, Financial Services, FinTech, Lending',
#        'Children, Education, Parenting',
#        'Automotive, Battery, Energy, Energy Storage',
#        'E-Commerce, Mobile, Sharing Economy',
#        'Food Delivery, Organic, Organic Food', 'Mobile', 'Rental',
#        'Travel', 'Consumer', 'B2B, Farming, Marketplace',
#        'Wealth Management', 'Biotechnology',
#        'Education, Gaming, Training', 'Veterinary',
#        'Internet, Mobile, Social Entrepreneurship, Telecommunications, Wireless',
#        'Health Care, Hospital, Supply Chain Management',
#        'Tourism, Travel', 'Hospitality, Real Estate', 'Finance',
#        'Digital Media, EBooks, Publishing, Reading Apps',
#        'Consumer Electronics, Embedded Systems, Hardware, Smart Building, Software',
#        'Food and Beverage, Food Processing',
#        'Internet, Marketplace, Shopping',
#        'Analytics, Computer Vision, Enterprise Software, Machine Learning, Natural Language Processing, Speech Recognition',
#        'Facilities Support Services',
#        'Automotive, Electric Vehicle, Energy',
#        'Health Care, Health Diagnostics, Predictive Analytics',
#        'Cloud Computing, Computer, SaaS, Software',
#        'Fashion, Lifestyle, Retail', 'Medical', 'Music Streaming',
#        'Finance, Impact Investing, Internet',
#        'Internet, Social Entrepreneurship', 'Retail',
#        'Finance, Impact Investing, Mobile Apps',
#        'Cloud Computing, Computer, Software',
#        'Business Development, Market Research, Outsourcing',
#        'Health Care, Hospitality', 'Internet, Social News, Sports',
#        'Human Resources', 'Finance, Financial Services, FinTech',
#        'Customer Service, Software, Video, Video Streaming',
#        'E-Commerce, Food Processing', 'Training',
#        'Dietary Supplements, Food and Beverage, Health Care, Organic Food, Snack Food',
#        'Manufacturing, Oil and Gas, Robotics',
#        'Artificial Intelligence, Computer, Machine Learning',
#        'Collaboration, Communities, Coworking, Sharing Economy',
#        'Big Data, EdTech, Machine Learning', 'Nanotechnology',
#        'Analytics, Audio, Digital Media, Innovation Management, Internet Radio, Media and Entertainment',
#        'Financial Services, Lending, Peer to Peer',
#        'E-Commerce, Furniture, Home Decor, Interior Design, Internet',
#        'Digital Media', 'File Sharing, Personalization, Social Media',
#        'Home Decor, Interior Design',
#        'Health Care, Medical Device, Mobile Apps',
#        'E-Commerce, Facilities Support Services, Procurement, Supply Chain Management',
#        'Crowdfunding, Finance, Financial Services',
#        'Finance, Financial Services, Insurance',
#        'Children, Education, Online Portals', 'Software, Virtual Reality',
#        'B2B, Food and Beverage, Food Delivery',
#        'Catering, Food and Beverage, Food Delivery, Food Processing',
#        'Food and Beverage, Snack Food', 'Automotive, E-Commerce, Mobile',
#        'Computer, Digital Marketing, Facilities Support Services, Graphic Design, Internet, Mobile Apps, Social Media Marketing, Web Development',
#        'Android, Big Data, Blockchain, Cloud Computing, EdTech, Education, Information Technology, iOS, Training, Web Development',
#        'Analytics, CRM, Loyalty Programs, Machine Learning, Marketing Automation, Retail Technology, SaaS, Small and Medium Businesses',
#        'Delivery, Information Technology, Mobile Apps',
#        'Environmental Consulting, Renewable Energy',
#        'Big Data, Business Intelligence, Financial Services, FinTech, Personal Finance',
#        'Commercial Real Estate, Coworking, Office Administration, Real Estate',
#        'Food and Beverage, Food Processing, Organic Food, Snack Food',
#        'Apps, Health Care, Internet, Mobile Apps, Personal Health',
#        'Digital Media, Incubators, Social Entrepreneurship',
#        'Finance, Financial Services, Marketing',
#        'Biotechnology, Health Care, Life Science, Medical Device',
#        'Education, Human Resources', 'Consumer Electronics',
#        'Apps, Health Care, Hospital, Mobile Apps',
#        'Delivery Service, Logistics, Service Industry',
#        'Big Data, Data Visualization, Logistics, Software',
#        'Basketball, Cricket, Cycling, eSports, Fitness, Golf, Health Care, Hockey, Sports, Swimming, Table Tennis, Volley Ball',
#        'Media and Entertainment, News, Publishing', 'Consulting',
#        'Big Data, Financial Services, Machine Learning, Predictive Analytics',
#        'Agriculture, AgTech, Manufacturing',
#        'Digital Media, News, Publishing', 'Health Care, Hospital',
#        'B2B, E-Commerce, Enterprise',
#        'Fraud Detection, Information Services, Security',
#        'Agriculture, AgTech, Artificial Intelligence, Internet of Things, Machine Learning',
#        'Cryptocurrency, Trading Platform',
#        'Finance, FinTech, Mobile Payments', 'Wedding',
#        'E-Learning, EdTech, Education, Image Recognition, Machine Learning, STEM Education',
#        'Consumer Goods', 'Digital Entertainment',
#        'Crowdsourcing, Financial Services, Funding Platform, Venture Capital',
#        'Delivery, Drones, Geospatial, Robotics',
#        'Health Care, Information Technology, Management Information Systems',
#        'Farming',
#        'Business Travel, Hospitality, Hotel, Marketplace, Tourism, Travel Accommodations',
#        'Career Planning, Education, Higher Education, Service Industry',
#        'Medical Device', 'Alternative Medicine, Health Care',
#        'Internet, Software',
#        'Dental, Elder Care, Health Care, Home Health Care, Personal Health',
#        'Financial Services, Insurance, Private Social Networking',
#        'Consumer Electronics, E-Commerce, E-Commerce Platforms, Electronics, Shipping, Shopping',
#        'CleanTech', 'Advertising, Internet, Marketing',
#        'Human Resources, Security, Training',
#        'Consumer Lending, Finance, FinTech',
#        'Marketing, Social Media, Video', 'Banking', 'Food Processing',
#        'Apps', 'Marketing',
#        'Apps, B2B, Freight Service, Logistics, SaaS, Shipping, Supply Chain Management, Transportation',
#        'Digital Entertainment, Fantasy Sports, Gaming, Sports',
#        'Automotive, Last Mile Transportation, Peer to Peer, Ride Sharing',
#        'Commercial, E-Learning, Education',
#        'Continuing Education, EdTech, Education, Skill Assessment',
#        'Smart Cities, Telecommunications', 'Internet of Things, Robotics',
#        'Apps, Home Services, Information Services, Information Technology',
#        'Medical, Tourism', 'Career Planning, Education, Internet',
#        'Fashion, Graphic Design, Wearables',
#        'Communities, Leisure, Mobile Apps, Software',
#        'Automotive, Rental, Sharing Economy',
#        'Energy, Environmental Consulting, Renewable Energy, Solar',
#        'Information Technology, SaaS, Security',
#        'Crowdfunding, Financial Services, Internet',
#        'Customer Service, Information Technology, Internet, Sales Automation',
#        'Advertising, Artificial Intelligence, Digital Media, iOS, Location Based Services, News, Video, Video on Demand, Video Streaming',
#        'Credit Cards, Payments, Property Insurance, Property Management, Rental Property',
#        'Beauty, Cosmetics, Health Care, Service Industry',
#        'EdTech, Education, Mobile, Tutoring', 'Social Media, Sports',
#        'Biopharma', 'E-Commerce, E-Commerce Platforms, Retail',
#        'E-Commerce, Fashion, Shopping',
#        'Digital Entertainment, Mobile, PC Games',
#        'Finance, Financial Services, Small and Medium Businesses',
#        'Artificial Intelligence, Energy, Oil and Gas',
#        'Computer, FinTech, Risk Management, Software',
#        'Apps, Financial Services, FinTech',
#        "Child Care, Health Care, Hospital, Medical, Women's",
#        'Agriculture, Mobile',
#        'Finance, FinTech, Payments, Property Development, Rental',
#        'Information Services, Information Technology, Mobile, Software',
#        'Apps, Fitness, Health Care, mHealth',
#        'Food and Beverage, Food Delivery', 'Apps, Payments, Retail',
#        'Health Insurance, Insurance, Life Insurance',
#        'Rental, Taxi Service, Travel',
#        'E-Commerce, E-Commerce Platforms, Internet, Retail',
#        'Financial Services, Professional Services',
#        'Customer Service, Messaging, Mobile Apps, Personalization',
#        'Gaming, iOS, Sports',
#        'E-Commerce, E-Commerce Platforms, Internet, Mobile Apps, Social Media',
#        'Search Engine',
#        'Battery, Electric Vehicle, Energy, Renewable Energy, Transportation',
#        'Agriculture, Farmers Market, Farming',
#        'Artificial Intelligence, Drones, Navigation, Packaging Services, Robotics',
#        'Fitness, GreenTech, Internet of Things, Mobile Apps, Ride Sharing, Transportation',
#        'Mobile, Software, Travel', 'Cosmetics',
#        'Consulting, Cyber Security, Network Security',
#        'eSports, Gaming, Video Games', 'Fashion, Jewelry',
#        'B2B, Medical Device', 'Consumer Goods, Manufacturing',
#        'Biotechnology, Health Care, Wellness',
#        'Health Care, Hospital, Medical, Robotics',
#        'E-Commerce, Fitness, Health Care',
#        'Financial Services, Venture Capital', 'Accounting, Apps, FinTech',
#        'Apps, Mobile, Transportation', 'Reading Apps',
#        'Energy, Renewable Energy, Solar',
#        'Banking, Financial Services, FinTech', 'Apps, Education, Retail',
#        'Electric Vehicle',
#        'Automotive, Battery, Electric Vehicle, Manufacturing, Mechanical Design',
#        'Automotive, E-Commerce, Marketplace', 'Agriculture',
#        'Apps, Information Services, Information Technology',
#        'B2B, Marketplace', 'Packaging Services',
#        'Computer, Furniture, Software',
#        'Food Delivery, Hospitality, Reservations, Restaurants, Search Engine',
#        'Collaboration, Communities, Coworking, Real Estate',
#        'Accounting, Banking, Finance',
#        'Cloud Computing, Enterprise Software, Network Hardware, Network Security, SaaS',
#        'Information Services, Internet, Logistics, Supply Chain Management, Transportation',
#        'Automotive, E-Commerce, Information Services',
#        'Delivery, Logistics, Transportation',
#        'Automotive, E-Commerce Platforms, Marketplace',
#        'Last Mile Transportation, Railroad, Transportation, Travel',
#        'Cooking, E-Commerce, Food and Beverage, Food Delivery, Online Portals',
#        'FinTech, Mobile, Mobile Payments, Payments, Retail Technology',
#        'Online Games, Software',
#        'Online Portals, Property Management, Rental',
#        'E-Commerce, Food and Beverage, Tea',
#        'Music, Social Network, Video',
#        'Health Care, Pharmaceutical, Wellness',
#        'Delivery Service, Food and Beverage, Food Delivery',
#        'Hospitality, Information Technology, Travel Accommodations',
#        'Biotechnology, Diabetes, Health Care',
#        'Autonomous Vehicles, Last Mile Transportation, Recreational Vehicles, Rental',
#        'Finance, Financial Exchanges, Financial Services, Micro Lending',
#        'Analytics, Apps, Market Research',
#        'E-Commerce, E-Commerce Platforms, Furniture, Home Decor, Internet',
#        'Apps, Mobile, Mobile Apps, Software',
#        'News, Publishing, Social Media',
#        'Industrial, Industrial Automation',
#        'Internet, Mobile Apps, Social Network',
#        'Health Care, Health Diagnostics, Internet of Things, Life Science, Machine Learning, Medical, Medical Device',
#        'E-Commerce, Furniture, Interior Design', 'Apps, Events, News',
#        'Artificial Intelligence, Human Resources, Information Services, Information Technology',
#        'Logistics, Railroad, Transportation',
#        'Dating, Private Social Networking',
#        'Artificial Intelligence, Machine Learning, PaaS',
#        'Consumer, Furniture, Home Decor, Home Improvement',
#        'Apps, E-Commerce, Internet, Mobile, Ride Sharing, Transportation',
#        'Health Care, Health Insurance', 'Energy, Natural Resources',
#        'E-Commerce, Education, Health Care',
#        'Apps, Health Care, Pharmaceutical',
#        'Internet, Knowledge Management',
#        'Credit, Finance, FinTech, Lending, Sales Automation',
#        'Banking, Financial Services, Internet',
#        'E-Commerce, Health Care, Retail',
#        'Child Care, Information Technology',
#        'Financial Services, Micro Lending',
#        'E-Commerce, Retail, Shopping',
#        'Food and Beverage, Snack Food, Tea',
#        'Delivery Service, E-Commerce, Logistics',
#        'Fashion, Lifestyle, Rental', 'Fantasy Sports, Mobile, Sports',
#        'Beauty, Fashion, Wellness', 'Food and Beverage, Restaurants, Tea',
#        'Fitness, Sporting Goods, Sports',
#        'Food and Beverage, Food Processing, Manufacturing',
#        'E-Learning, Internet', 'Eyewear, Internet',
#        'Information Technology, Mobile, News, Operating Systems, Social Media, Social News',
#        'FinTech, Internet, Payments, Service Industry',
#        'B2B, Business Development, Internet, Marketplace',
#        'Food and Beverage, Food Delivery, Internet',
#        'Biotechnology, Health Care, Pharmaceutical'], dtype=object)

# %% [markdown]
# The "Sector" column in the first dataset does not have specific words, unlike the "Sector" column of other datasets. It will be necessary to keep only the relevant word that best describes the sector of each company.
#
# It can be summarized that the first word on each row on the "Sector" column best describes the sector. As a result, the first word on each row on the "Sector" column will be kept while other words will be dropped.

# %%
# Splitting the "Sector" column values by comma and selecting only the first word

df1["Sector"] = df1["Sector"].str.split(',').str[0]
df1
# Out:
#          Company/Brand HeadQuarter                  Sector    Amount($)
# 0      Thecollegefever   Bengaluru         Brand Marketing       250000
# 1      Happy Cow Dairy      Mumbai             Agriculture  ₹40,000,000
# 2           Myloancare     Gurgaon                  Credit  ₹65,000,000
# 3          Payme India       Noida      Financial Services      2000000
# 4             Eunimart   Hyderabad    E-Commerce Platforms            —
# ..                 ...         ...                     ...          ...
# 521              Udaan   Bengaluru                     B2B    225000000
# 522  Happyeasygo Group     Haryana                 Tourism            —
# 523             Mombay      Mumbai       Food and Beverage         7500
# 524         Droni Tech      Mumbai  Information Technology  ₹35,000,000
# 525            Netmeds     Chennai           Biotechnology     35000000
#
# [525 rows x 4 columns]

# %%
# Inspecting the "Sector" column again

df1["Sector"].unique()
# Out:
# array(['Brand Marketing', 'Agriculture', 'Credit', 'Financial Services',
#        'E-Commerce Platforms', 'Cloud Infrastructure', 'Internet',
#        'Market Research', 'Information Services', 'Mobile Payments',
#        'B2B', 'Apps', 'Food Delivery', 'Industrial Automation',
#        'Automotive', 'Finance', 'Accounting', 'Artificial Intelligence',
#        'Internet of Things', 'Air Transportation', 'Food and Beverage',
#        'Autonomous Vehicles', 'Enterprise Software', 'Logistics',
#        'Insurance', 'Information Technology', 'Blockchain', 'Education',
#        'E-Commerce', 'Renewable Energy', 'E-Learning', 'Clean Energy',
#        'Transportation', 'Fitness', 'Hospitality',
#        'Media and Entertainment', 'Broadcasting', 'EdTech', 'Health Care',
#        '—', 'Sports', 'Big Data', 'Cloud Computing', 'Food Processing',
#        'Trading Platform', 'Consumer Goods', 'Wellness', 'Fashion',
#        'Consulting', 'Biotechnology', 'Communities', 'Consumer',
#        'Consumer Applications', 'Mobile', 'Advertising', 'Marketplace',
#        'Aerospace', 'Home Decor', 'Energy', 'Digital Marketing',
#        'Creative Agency', 'Consumer Lending', 'Health Diagnostics',
#        'Banking', 'Embedded Systems', 'Beauty', 'AgTech', 'Credit Cards',
#        'Software', 'Manufacturing', 'Hospital', 'Events', '3D Printing',
#        'Digital Entertainment', 'Funding Platform', 'Classifieds',
#        'Enterprise Resource Planning (ERP)', 'Audio', 'Government',
#        'Digital Media', 'Business Intelligence', 'Children', 'Rental',
#        'Travel', 'Wealth Management', 'Veterinary', 'Tourism',
#        'Consumer Electronics', 'Analytics', 'Facilities Support Services',
#        'Medical', 'Music Streaming', 'Retail', 'Business Development',
#        'Human Resources', 'Customer Service', 'Training',
#        'Dietary Supplements', 'Collaboration', 'Nanotechnology',
#        'File Sharing', 'Crowdfunding', 'Catering', 'Computer', 'Android',
#        'Delivery', 'Environmental Consulting', 'Commercial Real Estate',
#        'Delivery Service', 'Basketball', 'Fraud Detection',
#        'Cryptocurrency', 'Wedding', 'Crowdsourcing', 'Farming',
#        'Business Travel', 'Career Planning', 'Medical Device',
#        'Alternative Medicine', 'Dental', 'CleanTech', 'Marketing',
#        'Commercial', 'Continuing Education', 'Smart Cities',
#        'Social Media', 'Biopharma', 'Child Care', 'Health Insurance',
#        'Gaming', 'Search Engine', 'Battery', 'Cosmetics', 'eSports',
#        'Reading Apps', 'Electric Vehicle', 'Packaging Services',
#        'Last Mile Transportation', 'Cooking', 'FinTech', 'Online Games',
#        'Online Portals', 'Music', 'News', 'Industrial', 'Dating',
#        'Fantasy Sports', 'Eyewear'], dtype=object)

# %%
# Replacing the dash symbol in the "Sector" column with N/A

df1["Sector"]= df1["Sector"].replace('—','N/A')
df1["Sector"].unique()
# Out:
# array(['Brand Marketing', 'Agriculture', 'Credit', 'Financial Services',
#        'E-Commerce Platforms', 'Cloud Infrastructure', 'Internet',
#        'Market Research', 'Information Services', 'Mobile Payments',
#        'B2B', 'Apps', 'Food Delivery', 'Industrial Automation',
#        'Automotive', 'Finance', 'Accounting', 'Artificial Intelligence',
#        'Internet of Things', 'Air Transportation', 'Food and Beverage',
#        'Autonomous Vehicles', 'Enterprise Software', 'Logistics',
#        'Insurance', 'Information Technology', 'Blockchain', 'Education',
#        'E-Commerce', 'Renewable Energy', 'E-Learning', 'Clean Energy',
#        'Transportation', 'Fitness', 'Hospitality',
#        'Media and Entertainment', 'Broadcasting', 'EdTech', 'Health Care',
#        'N/A', 'Sports', 'Big Data', 'Cloud Computing', 'Food Processing',
#        'Trading Platform', 'Consumer Goods', 'Wellness', 'Fashion',
#        'Consulting', 'Biotechnology', 'Communities', 'Consumer',
#        'Consumer Applications', 'Mobile', 'Advertising', 'Marketplace',
#        'Aerospace', 'Home Decor', 'Energy', 'Digital Marketing',
#        'Creative Agency', 'Consumer Lending', 'Health Diagnostics',
#        'Banking', 'Embedded Systems', 'Beauty', 'AgTech', 'Credit Cards',
#        'Software', 'Manufacturing', 'Hospital', 'Events', '3D Printing',
#        'Digital Entertainment', 'Funding Platform', 'Classifieds',
#        'Enterprise Resource Planning (ERP)', 'Audio', 'Government',
#        'Digital Media', 'Business Intelligence', 'Children', 'Rental',
#        'Travel', 'Wealth Management', 'Veterinary', 'Tourism',
#        'Consumer Electronics', 'Analytics', 'Facilities Support Services',
#        'Medical', 'Music Streaming', 'Retail', 'Business Development',
#        'Human Resources', 'Customer Service', 'Training',
#        'Dietary Supplements', 'Collaboration', 'Nanotechnology',
#        'File Sharing', 'Crowdfunding', 'Catering', 'Computer', 'Android',
#        'Delivery', 'Environmental Consulting', 'Commercial Real Estate',
#        'Delivery Service', 'Basketball', 'Fraud Detection',
#        'Cryptocurrency', 'Wedding', 'Crowdsourcing', 'Farming',
#        'Business Travel', 'Career Planning', 'Medical Device',
#        'Alternative Medicine', 'Dental', 'CleanTech', 'Marketing',
#        'Commercial', 'Continuing Education', 'Smart Cities',
#        'Social Media', 'Biopharma', 'Child Care', 'Health Insurance',
#        'Gaming', 'Search Engine', 'Battery', 'Cosmetics', 'eSports',
#        'Reading Apps', 'Electric Vehicle', 'Packaging Services',
#        'Last Mile Transportation', 'Cooking', 'FinTech', 'Online Games',
#        'Online Portals', 'Music', 'News', 'Industrial', 'Dating',
#        'Fantasy Sports', 'Eyewear'], dtype=object)

# %%
# Inspecting the "Amounts ($)" column

df1["Amount($)"].unique()
# Out:
# array(['250000', '₹40,000,000', '₹65,000,000', '2000000', '—', '1600000',
#        '₹16,000,000', '₹50,000,000', '₹100,000,000', '150000', '1100000',
#        '₹500,000', '6000000', '650000', '₹35,000,000', '₹64,000,000',
#        '₹20,000,000', '1000000', '5000000', '4000000', '₹30,000,000',
#        '2800000', '1700000', '1300000', '₹5,000,000', '₹12,500,000',
#        '₹15,000,000', '500000', '₹104,000,000', '₹45,000,000', '13400000',
#        '₹25,000,000', '₹26,400,000', '₹8,000,000', '₹60,000', '9000000',
#        '100000', '20000', '120000', '₹34,000,000', '₹342,000,000',
#        '$143,145', '₹600,000,000', '$742,000,000', '₹1,000,000,000',
#        '₹2,000,000,000', '$3,980,000', '$10,000', '₹100,000',
#        '₹250,000,000', '$1,000,000,000', '$7,000,000', '$35,000,000',
#        '₹550,000,000', '$28,500,000', '$2,000,000', '₹240,000,000',
#        '₹120,000,000', '$2,400,000', '$30,000,000', '₹2,500,000,000',
#        '$23,000,000', '$150,000', '$11,000,000', '₹44,000,000',
#        '$3,240,000', '₹60,000,000', '$540,000,000', '₹650,000,000',
#        '₹1,600,000,000', '$900,000', '$10,000,000', '$1,500,000',
#        '₹70,000,000', '$1,000,000', '$5,000,000', '$14,000,000',
#        '₹102,500,000', '$100,000,000', '₹1,200,000', '₹5,200,000,000',
#        '$800,000', '$1,041,000', '$100,000', '$15,000', '1400000',
#        '1200000', '2200000', '1800000', '3600000', '₹9,500,000', '300000',
#        '6830000', '200000', '₹150,000,000', '4300000', '364846', '400000',
#        '1500000', '₹7,000,000', '₹1,400,000', '₹10,000,000',
#        '₹22,500,000', '13200000', '50000', '₹140,200,000', '3000000',
#        '1250000', '180000', '₹19,200,000', '₹103,000,000', '4200000',
#        '175000', '1450000', '₹200,000', '4500000', '600000',
#        '₹16,600,000', '₹12,000,000', '15000000', '₹33,000,000', '125000',
#        '130000', '₹34,900,000', '₹72,000,000', '17200000', '₹32,000,000',
#        '3500000', '₹135,000,000', '12000000', '$40,000,000', '$1,100,000',
#        '$50,000,000', '₹1,540,000,000', '$3,000,000', '$6,000,000',
#        '₹140,000,000', '$41,900,000', '₹1,410,000,000', '$3,530,000',
#        '$200,000', '$3,300,000', '₹580,000,000', '₹36,000,000',
#        '₹340,000,000', '$210,000,000', '$37,680,000', '$250,000',
#        '$20,000', '₹510,000,000', '₹2,200,000,000', '22000000', '70000',
#        '10000000', '₹15,392,000,000', '₹20,000,000,000', '₹4,000,000,000',
#        '185000000', '65000000', '₹165,000,000', '700000', '30000000',
#        '₹210,000,000', '210000000', '₹2,029,600,000', '75000000',
#        '₹80,000,000', '1760000', '2700000', '₹280,000,000',
#        '₹800,000,000', '750000', '2500000', '80000000', '25000000',
#        '₹730,000,000', '₹400,000,000', '3700000', '5600000',
#        '₹260,000,000', '99230000', '70000000', '40000', '550000',
#        '50000000', '365000000', '₹8,750,000', '₹78,000,000', '28000000',
#        '₹264,000,000', '100000000', '₹1,130,000,000', '₹810,000,000',
#        '₹1,400,000,000', '14900000', '225000000', '7500', '35000000'],
#       dtype=object)

# %% [markdown]
# The cells of the "Amounts ($)" colummn of the dataset has amounts in rupees, amounts in dollars, and dash symbols. The rupee amounts will be converted to dollars since the amounts in other datasets are also in dollars. The average exchange rate of rupees to dollars in 2018 will be used to ensure accurate conversion.
#
# The rupee amounts alone need to be converted and the presence of the rupee symbol in the amounts suggest that the datatype would be string. There is need to change the datatypes to float to make the conversion possible. We will first remove all the non-numerical values then applying .astype("int64"). The non-numerical values are the rupee symbol and the comma symbol. While removing them, we will use the lambda function to ensure that NaN values are not returned.

# %%
# Define the average exchange rate in 2018
exchange_rate = 0.0146  # That is, 1 Rupee = 0.0146 Dollar

# Select the rows with rupee amounts
rupee_rows = df1["Amount($)"].str.contains('₹') # Note that only the rupee amounts should be converted 

# Remove the non-numerical values and change the datatype to integer
df1.loc[rupee_rows, "Amount($)"] = df1.loc[rupee_rows, "Amount($)"].apply(lambda x: x.replace('₹', '').replace(',', '')
                                if isinstance(x, str) else x).astype("int64")

# Convert the rupee amounts to dollars
df1.loc[rupee_rows, "Amount($)"] = df1.loc[rupee_rows, "Amount($)"] * exchange_rate

df1
# Out:
#          Company/Brand HeadQuarter                  Sector  Amount($)
# 0      Thecollegefever   Bengaluru         Brand Marketing     250000
# 1      Happy Cow Dairy      Mumbai             Agriculture   584000.0
# 2           Myloancare     Gurgaon                  Credit   949000.0
# 3          Payme India       Noida      Financial Services    2000000
# 4             Eunimart   Hyderabad    E-Commerce Platforms          —
# ..                 ...         ...                     ...        ...
# 521              Udaan   Bengaluru                     B2B  225000000
# 522  Happyeasygo Group     Haryana                 Tourism          —
# 523             Mombay      Mumbai       Food and Beverage       7500
# 524         Droni Tech      Mumbai  Information Technology   511000.0
# 525            Netmeds     Chennai           Biotechnology   35000000
#
# [525 rows x 4 columns]

# %% [markdown]
# # Handling the dash symbols

# %%
# Counting the number of cells containing the dash symbol

(df1["Amount($)"] == '—').sum()
# Out:
# 148

# %% [markdown]
# It will be assumed that the funding amounts received by these 148 companies/brands were lost during the data collection process or were undisclosed. The dash symbols will be replaced with 0, to easily change the column datatype to integer.

# %%
# Replacing the dash symbol with zero and investigating the column again

df1["Amount($)"] = df1["Amount($)"].replace('—', 0, regex=True)
df1["Amount($)"].unique()
# Out:
# array(['250000', 584000.0, 949000.0, '2000000', 0, '1600000', 233600.0,
#        730000.0, 1460000.0, '150000', '1100000', 7300.0, '6000000',
#        '650000', 511000.0, 934400.0, 292000.0, '1000000', '5000000',
#        '4000000', 438000.0, '2800000', '1700000', '1300000', 73000.0,
#        182500.0, 219000.0, '500000', 1518400.0, 657000.0, '13400000',
#        365000.0, 385440.0, 116800.0, 876.0, '9000000', '100000', '20000',
#        '120000', 496400.0, 4993200.0, '$143,145', 8760000.0,
#        '$742,000,000', 14600000.0, 29200000.0, '$3,980,000', '$10,000',
#        1460.0, 3650000.0, '$1,000,000,000', '$7,000,000', '$35,000,000',
#        8030000.0, '$28,500,000', '$2,000,000', 3504000.0, 1752000.0,
#        '$2,400,000', '$30,000,000', 36500000.0, '$23,000,000', '$150,000',
#        '$11,000,000', 642400.0, '$3,240,000', 876000.0, '$540,000,000',
#        9490000.0, 23360000.0, '$900,000', '$10,000,000', '$1,500,000',
#        1022000.0, '$1,000,000', '$5,000,000', '$14,000,000', 1496500.0,
#        '$100,000,000', 17520.0, 75920000.0, '$800,000', '$1,041,000',
#        '$100,000', '$15,000', '1400000', '1200000', '2200000', '1800000',
#        '3600000', 138700.0, '300000', '6830000', '200000', 2190000.0,
#        '4300000', '364846', '400000', '1500000', 102200.0, 20440.0,
#        146000.0, 328500.0, '13200000', '50000', 2046920.0, '3000000',
#        '1250000', '180000', 280320.0, 1503800.0, '4200000', '175000',
#        '1450000', 2920.0, '4500000', '600000', 242360.0, 175200.0,
#        '15000000', 481800.0, '125000', '130000', 509540.0, 1051200.0,
#        '17200000', 467200.0, '3500000', 1971000.0, '12000000',
#        '$40,000,000', '$1,100,000', '$50,000,000', 22484000.0,
#        '$3,000,000', '$6,000,000', 2044000.0, '$41,900,000', 20586000.0,
#        '$3,530,000', '$200,000', '$3,300,000', 8468000.0, 525600.0,
#        4964000.0, '$210,000,000', '$37,680,000', '$250,000', '$20,000',
#        7446000.0, 32120000.0, '22000000', '70000', '10000000',
#        224723200.0, 292000000.0, 58400000.0, '185000000', '65000000',
#        2409000.0, '700000', '30000000', 3066000.0, '210000000',
#        29632160.0, '75000000', 1168000.0, '1760000', '2700000', 4088000.0,
#        11680000.0, '750000', '2500000', '80000000', '25000000',
#        10658000.0, 5840000.0, '3700000', '5600000', 3796000.0, '99230000',
#        '70000000', '40000', '550000', '50000000', '365000000', 127750.0,
#        1138800.0, '28000000', 3854400.0, '100000000', 16498000.0,
#        11826000.0, 20440000.0, '14900000', '225000000', '7500',
#        '35000000'], dtype=object)

# %% [markdown]
# Some cells still have the dollar and comma symbols which are non-numeric characters. These non-numeric characters need to be removed.

# %%
# Removing the dollar and commma symbols in the entire Amount($) column

df1["Amount($)"] = df1["Amount($)"].replace(['\$', ','], '', regex=True)
df1["Amount($)"].unique()
# Out:
# array(['250000', 584000.0, 949000.0, '2000000', 0, '1600000', 233600.0,
#        730000.0, 1460000.0, '150000', '1100000', 7300.0, '6000000',
#        '650000', 511000.0, 934400.0, 292000.0, '1000000', '5000000',
#        '4000000', 438000.0, '2800000', '1700000', '1300000', 73000.0,
#        182500.0, 219000.0, '500000', 1518400.0, 657000.0, '13400000',
#        365000.0, 385440.0, 116800.0, 876.0, '9000000', '100000', '20000',
#        '120000', 496400.0, 4993200.0, '143145', 8760000.0, '742000000',
#        14600000.0, 29200000.0, '3980000', '10000', 1460.0, 3650000.0,
#        '1000000000', '7000000', '35000000', 8030000.0, '28500000',
#        3504000.0, 1752000.0, '2400000', '30000000', 36500000.0,
#        '23000000', '11000000', 642400.0, '3240000', 876000.0, '540000000',
#        9490000.0, 23360000.0, '900000', '10000000', '1500000', 1022000.0,
#        '14000000', 1496500.0, '100000000', 17520.0, 75920000.0, '800000',
#        '1041000', '15000', '1400000', '1200000', '2200000', '1800000',
#        '3600000', 138700.0, '300000', '6830000', '200000', 2190000.0,
#        '4300000', '364846', '400000', 102200.0, 20440.0, 146000.0,
#        328500.0, '13200000', '50000', 2046920.0, '3000000', '1250000',
#        '180000', 280320.0, 1503800.0, '4200000', '175000', '1450000',
#        2920.0, '4500000', '600000', 242360.0, 175200.0, '15000000',
#        481800.0, '125000', '130000', 509540.0, 1051200.0, '17200000',
#        467200.0, '3500000', 1971000.0, '12000000', '40000000', '50000000',
#        22484000.0, 2044000.0, '41900000', 20586000.0, '3530000',
#        '3300000', 8468000.0, 525600.0, 4964000.0, '210000000', '37680000',
#        7446000.0, 32120000.0, '22000000', '70000', 224723200.0,
#        292000000.0, 58400000.0, '185000000', '65000000', 2409000.0,
#        '700000', 3066000.0, 29632160.0, '75000000', 1168000.0, '1760000',
#        '2700000', 4088000.0, 11680000.0, '750000', '2500000', '80000000',
#        '25000000', 10658000.0, 5840000.0, '3700000', '5600000', 3796000.0,
#        '99230000', '70000000', '40000', '550000', '365000000', 127750.0,
#        1138800.0, '28000000', 3854400.0, 16498000.0, 11826000.0,
#        20440000.0, '14900000', '225000000', '7500'], dtype=object)

# %%
# Converting the datatype of the Amount($) column to integer

df1["Amount($)"] = df1["Amount($)"].astype("int64")
df1["Amount($)"].unique()
# Out:
# array([    250000,     584000,     949000,    2000000,          0,
#           1600000,     233600,     730000,    1460000,     150000,
#           1100000,       7300,    6000000,     650000,     511000,
#            934400,     292000,    1000000,    5000000,    4000000,
#            438000,    2800000,    1700000,    1300000,      73000,
#            182500,     219000,     500000,    1518400,     657000,
#          13400000,     365000,     385440,     116800,        876,
#           9000000,     100000,      20000,     120000,     496400,
#           4993200,     143145,    8760000,  742000000,   14600000,
#          29200000,    3980000,      10000,       1460,    3650000,
#        1000000000,    7000000,   35000000,    8030000,   28500000,
#           3504000,    1752000,    2400000,   30000000,   36500000,
#          23000000,   11000000,     642400,    3240000,     876000,
#         540000000,    9490000,   23360000,     900000,   10000000,
#           1500000,    1022000,   14000000,    1496500,  100000000,
#             17520,   75920000,     800000,    1041000,      15000,
#           1400000,    1200000,    2200000,    1800000,    3600000,
#            138700,     300000,    6830000,     200000,    2190000,
#           4300000,     364846,     400000,     102200,      20440,
#            146000,     328500,   13200000,      50000,    2046920,
#           3000000,    1250000,     180000,     280320,    1503800,
#           4200000,     175000,    1450000,       2920,    4500000,
#            600000,     242360,     175200,   15000000,     481800,
#            125000,     130000,     509540,    1051200,   17200000,
#            467200,    3500000,    1971000,   12000000,   40000000,
#          50000000,   22484000,    2044000,   41900000,   20586000,
#           3530000,    3300000,    8468000,     525600,    4964000,
#         210000000,   37680000,    7446000,   32120000,   22000000,
#             70000,  224723200,  292000000,   58400000,  185000000,
#          65000000,    2409000,     700000,    3066000,   29632160,
#          75000000,    1168000,    1760000,    2700000,    4088000,
#          11680000,     750000,    2500000,   80000000,   25000000,
#          10658000,    5840000,    3700000,    5600000,    3796000,
#          99230000,   70000000,      40000,     550000,  365000000,
#            127750,    1138800,   28000000,    3854400,   16498000,
#          11826000,   20440000,   14900000,  225000000,       7500],
#       dtype=int64)

# %%
# Evaluating the entire dataset

df1.head()
# Out:
#      Company/Brand HeadQuarter                Sector  Amount($)
# 0  Thecollegefever   Bengaluru       Brand Marketing     250000
# 1  Happy Cow Dairy      Mumbai           Agriculture     584000
# 2       Myloancare     Gurgaon                Credit     949000
# 3      Payme India       Noida    Financial Services    2000000
# 4         Eunimart   Hyderabad  E-Commerce Platforms          0

# %%
# Confirming that there are no empty cells

df1.isna().sum()
# Out:
# Company/Brand    0
# HeadQuarter      0
# Sector           0
# Amount($)        0
# dtype: int64

# %% [markdown]
# There are no empty cells in our dateset, and the columns have been inspected and cleaned.
#
# Next is to add the "Funding Year" column.

# %%
# Creating a new column named "Funding Year" and filling it with 2018.

df1["Funding Year"] = 2018
df1.head()
# Out:
#      Company/Brand HeadQuarter                Sector  Amount($)  Funding Year
# 0  Thecollegefever   Bengaluru       Brand Marketing     250000          2018
# 1  Happy Cow Dairy      Mumbai           Agriculture     584000          2018
# 2       Myloancare     Gurgaon                Credit     949000          2018
# 3      Payme India       Noida    Financial Services    2000000          2018
# 4         Eunimart   Hyderabad  E-Commerce Platforms          0          2018

# %% [markdown]
# # Cleaning the second data set

# %%
# Evaluating the dataset

df2
# Out:
#       Company/Brand  Founded HeadQuarter                   Sector
# 0    Bombay Shaving      NaN         NaN                Ecommerce  \
# 1         Ruangguru   2014.0      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane   2014.0     Chennai          Interior design
# 4          Nu Genes   2004.0   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo   2013.0    Gurugram              Hospitality
# 86       GoMechanic   2016.0       Delhi  Automobile & Technology
# 87           Spinny   2015.0       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does
# 0          Provides a range of male grooming products  \
# 1   A learning platform that provides topic-based ...
# 2             It aims to make learning fun via games.
# 3               Provides interior designing solutions
# 4   It is a seed company engaged in production, pr...
# ..                                                ...
# 84  It connects client requirements to their suppl...
# 85                Provides rooms for comfortable stay
# 86  Find automobile repair and maintenance service...
# 87                                Online car retailer
# 88              Organised Non-Banking Finance Company
#
#                                              Founders
# 0                                  Shantanu Deshpande  \
# 1               Adamas Belva Syah Devara, Iman Usman.
# 2                                       Jatin Solanki
# 3                        Srikanth Iyer, Rama Harinath
# 4                              Narayana Reddy Punyala
# ..                                                ...
# 84                    Aaditya Sharda, Souvik Sengupta
# 85                                     Ritesh Agarwal
# 86  Amit Bhasin, Kushal Karwa, Nitin Rana, Rishabh...
# 87  Niraj Singh, Ramanshu Mahaur, Ganesh Pawar, Mo...
# 88                                     Rajendra Setia
#
#                                              Investor     Amount($)
# 0                                Sixth Sense Ventures    $6,300,000  \
# 1                                    General Atlantic  $150,000,000
# 2      Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3   Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4            Innovation in Food and Agriculture (IFA)    $6,000,000
# ..                                                ...           ...
# 84  Tiger Global, Nexus Venture Partners, Accel Pa...   $20,000,000
# 85  MyPreferred Transformation, Avendus Finance, S...  $693,000,000
# 86                                    Sequoia Capital    $5,000,000
# 87  Norwest Venture Partners, General Catalyst, Fu...   $50,000,000
# 88     TPG, Norwest Venture Partners, Evolvence India   $33,000,000
#
#             Stage
# 0             NaN
# 1        Series C
# 2   Fresh funding
# 3        Series D
# 4             NaN
# ..            ...
# 84       Series A
# 85            NaN
# 86       Series B
# 87            NaN
# 88            NaN
#
# [89 rows x 9 columns]

# %%
# Dropping the "Founded", "What it does", "Founders", "Investor" and "Stage" columns

df2 = df2.drop(["Founded", "What it does", "Founders", "Investor", "Stage"], axis =1)
df2.head()
# Out:
#     Company/Brand HeadQuarter           Sector     Amount($)
# 0  Bombay Shaving         NaN        Ecommerce    $6,300,000
# 1       Ruangguru      Mumbai           Edtech  $150,000,000
# 2        Eduisfun      Mumbai           Edtech   $28,000,000
# 3        HomeLane     Chennai  Interior design   $30,000,000
# 4        Nu Genes   Telangana         AgriTech    $6,000,000

# %%
# Checking the cell values

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  89 non-null     object
#  1   HeadQuarter    70 non-null     object
#  2   Sector         84 non-null     object
#  3   Amount($)      89 non-null     object
# dtypes: object(4)
# memory usage: 2.9+ KB

# %%
# Confirming the number of empty cells

df2.isna().sum()
# Out:
# Company/Brand     0
# HeadQuarter      19
# Sector            5
# Amount($)         0
# dtype: int64

# %% [markdown]
# There are nineteen empty cells in the "HeadQuarter" column and five empty cells in the "Sector" column. This will be handled when inspecting the columns.

# %%
# Checking for duplicate rows

df2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicate rows in the dataset.

# %% [markdown]
# # Checking the data quality

# %%
# Inspecting the "Company/Brand" column

df2["Company/Brand"].unique()
# Out:
# array(['Bombay Shaving', 'Ruangguru', 'Eduisfun', 'HomeLane', 'Nu Genes',
#        'FlytBase', 'Finly', 'Kratikal', 'Quantiphi', 'Lenskart',
#        'Cub McPaws', 'Appnomic', 'Kaleidofin', 'JobSquare', 'Open Secret',
#        'LivFin', "Byju's", 'Zest Money', 'Witblox',
#        'Azah Personal Care Pvt. Ltd.', 'SalaryFits', 'Pristyn Care',
#        'Springboard', 'DROR Labs Pvt. Ltd', 'Medlife', 'Seekify',
#        'Toffee Insurance', 'Fireflies .ai', 'HungerBox', 'Bijak',
#        'Licious', 'truMe', 'Pumpkart', 'Asteria Aerospace', 'Rivigo',
#        'HappyEasyGo', 'Zetwerk', 'Observe.AI', 'Freshokartz',
#        'Lil’ Goodness and sCool meal', 'Trell', 'VMate',
#        'Bombay Shirt Company', 'Slintel', 'MyGameMate', 'Afinoz',
#        'Rein Games', 'Ecozen', 'Box8', 'Awign Enterprises', 'Purplle',
#        'Freightwalla', 'TapChief', 'eJOHRI', 'Ninjacart', 'Binca Games',
#        'KredX', 'm.Paani', 'Origo', 'WishADish', 'Ecom Express',
#        'Stanza Living', 'PiBeam', 'Euler Motors', 'Moms Co',
#        'Cubical Labs', 'Lawyered', 'Cuemath', 'Nivesh.com', 'Zebu',
#        'Smart Institute', 'CarDekho', 'Shadowfax', 'Credr', 'Sportido',
#        'Phable', 'Sarva', 'IndyFint', 'Zolostays', 'Ola', 'Zoomcar',
#        'Froogal', 'Infra.Market', 'Oyo', 'GoMechanic', 'Spinny',
#        'Ess Kay Fincorp'], dtype=object)

# %%
# Changing the name "Fireflies .ai" to "Fireflies.ai"

df2["Company/Brand"]= df2["Company/Brand"].replace('Fireflies .ai','Fireflies.ai')
df2["Company/Brand"].unique()
# Out:
# array(['Bombay Shaving', 'Ruangguru', 'Eduisfun', 'HomeLane', 'Nu Genes',
#        'FlytBase', 'Finly', 'Kratikal', 'Quantiphi', 'Lenskart',
#        'Cub McPaws', 'Appnomic', 'Kaleidofin', 'JobSquare', 'Open Secret',
#        'LivFin', "Byju's", 'Zest Money', 'Witblox',
#        'Azah Personal Care Pvt. Ltd.', 'SalaryFits', 'Pristyn Care',
#        'Springboard', 'DROR Labs Pvt. Ltd', 'Medlife', 'Seekify',
#        'Toffee Insurance', 'Fireflies.ai', 'HungerBox', 'Bijak',
#        'Licious', 'truMe', 'Pumpkart', 'Asteria Aerospace', 'Rivigo',
#        'HappyEasyGo', 'Zetwerk', 'Observe.AI', 'Freshokartz',
#        'Lil’ Goodness and sCool meal', 'Trell', 'VMate',
#        'Bombay Shirt Company', 'Slintel', 'MyGameMate', 'Afinoz',
#        'Rein Games', 'Ecozen', 'Box8', 'Awign Enterprises', 'Purplle',
#        'Freightwalla', 'TapChief', 'eJOHRI', 'Ninjacart', 'Binca Games',
#        'KredX', 'm.Paani', 'Origo', 'WishADish', 'Ecom Express',
#        'Stanza Living', 'PiBeam', 'Euler Motors', 'Moms Co',
#        'Cubical Labs', 'Lawyered', 'Cuemath', 'Nivesh.com', 'Zebu',
#        'Smart Institute', 'CarDekho', 'Shadowfax', 'Credr', 'Sportido',
#        'Phable', 'Sarva', 'IndyFint', 'Zolostays', 'Ola', 'Zoomcar',
#        'Froogal', 'Infra.Market', 'Oyo', 'GoMechanic', 'Spinny',
#        'Ess Kay Fincorp'], dtype=object)

# %%
# Inspecting the "HeadQuarter" column

df2["HeadQuarter"].unique()
# Out:
# array([nan, 'Mumbai', 'Chennai', 'Telangana', 'Pune', 'Bangalore',
#        'Noida', 'Delhi', 'Ahmedabad', 'Gurugram', 'Haryana', 'Chandigarh',
#        'Jaipur', 'New Delhi', 'Surat', 'Uttar pradesh', 'Hyderabad',
#        'Rajasthan'], dtype=object)

# %%
# Filling the empty cells in the "HeadQuarter" column with N/A

df2["HeadQuarter"]= df2["HeadQuarter"].fillna('N/A')
df2["HeadQuarter"].unique()
# Out:
# array(['N/A', 'Mumbai', 'Chennai', 'Telangana', 'Pune', 'Bangalore',
#        'Noida', 'Delhi', 'Ahmedabad', 'Gurugram', 'Haryana', 'Chandigarh',
#        'Jaipur', 'New Delhi', 'Surat', 'Uttar pradesh', 'Hyderabad',
#        'Rajasthan'], dtype=object)

# %%
# Replacing Bangalore with Bengaluru

df2["HeadQuarter"] = df2["HeadQuarter"].replace('Bangalore', 'Bengaluru', regex=True)
df2["HeadQuarter"].unique()
# Out:
# array(['N/A', 'Mumbai', 'Chennai', 'Telangana', 'Pune', 'Bengaluru',
#        'Noida', 'Delhi', 'Ahmedabad', 'Gurugram', 'Haryana', 'Chandigarh',
#        'Jaipur', 'New Delhi', 'Surat', 'Uttar pradesh', 'Hyderabad',
#        'Rajasthan'], dtype=object)

# %%
# Replacing Uttar pradesh with Uttar Pradesh

df2["HeadQuarter"] = df2["HeadQuarter"].replace('Uttar pradesh', 'Uttar Pradesh', regex=True)
df2["HeadQuarter"].unique()
# Out:
# array(['N/A', 'Mumbai', 'Chennai', 'Telangana', 'Pune', 'Bengaluru',
#        'Noida', 'Delhi', 'Ahmedabad', 'Gurugram', 'Haryana', 'Chandigarh',
#        'Jaipur', 'New Delhi', 'Surat', 'Uttar Pradesh', 'Hyderabad',
#        'Rajasthan'], dtype=object)

# %%
# Inspecting the "Sector" column

df2["Sector"].unique()
# Out:
# array(['Ecommerce', 'Edtech', 'Interior design', 'AgriTech', 'Technology',
#        'SaaS', 'AI & Tech', 'E-commerce', 'E-commerce & AR', 'Fintech',
#        'HR tech', 'Food tech', 'Health', 'Healthcare', 'Safety tech',
#        'Pharmaceutical', 'Insurance technology', 'AI', 'Foodtech', 'Food',
#        'IoT', 'E-marketplace', 'Robotics & AI', 'Logistics', 'Travel',
#        'Manufacturing', 'Food & Nutrition', 'Social Media', nan,
#        'E-Sports', 'Cosmetics', 'B2B', 'Jewellery', 'B2B Supply Chain',
#        'Games', 'Food & tech', 'Accomodation', 'Automotive tech',
#        'Legal tech', 'Mutual Funds', 'Cybersecurity', 'Automobile',
#        'Sports', 'Healthtech', 'Yoga & wellness', 'Virtual Banking',
#        'Transportation', 'Transport & Rentals',
#        'Marketing & Customer loyalty', 'Infratech', 'Hospitality',
#        'Automobile & Technology', 'Banking'], dtype=object)

# %%
# Converting the values in "Sector" column to sentence case

df2["Sector"] = df2["Sector"].str.title()
df2["Sector"].unique()
# Out:
# array(['Ecommerce', 'Edtech', 'Interior Design', 'Agritech', 'Technology',
#        'Saas', 'Ai & Tech', 'E-Commerce', 'E-Commerce & Ar', 'Fintech',
#        'Hr Tech', 'Food Tech', 'Health', 'Healthcare', 'Safety Tech',
#        'Pharmaceutical', 'Insurance Technology', 'Ai', 'Foodtech', 'Food',
#        'Iot', 'E-Marketplace', 'Robotics & Ai', 'Logistics', 'Travel',
#        'Manufacturing', 'Food & Nutrition', 'Social Media', nan,
#        'E-Sports', 'Cosmetics', 'B2B', 'Jewellery', 'B2B Supply Chain',
#        'Games', 'Food & Tech', 'Accomodation', 'Automotive Tech',
#        'Legal Tech', 'Mutual Funds', 'Cybersecurity', 'Automobile',
#        'Sports', 'Healthtech', 'Yoga & Wellness', 'Virtual Banking',
#        'Transportation', 'Transport & Rentals',
#        'Marketing & Customer Loyalty', 'Infratech', 'Hospitality',
#        'Automobile & Technology', 'Banking'], dtype=object)

# %%
# Filling the empty cells in the "Sector" column with N/A

df2["Sector"]= df2["Sector"].fillna('N/A')
df2["Sector"].unique()
# Out:
# array(['Ecommerce', 'Edtech', 'Interior Design', 'Agritech', 'Technology',
#        'Saas', 'Ai & Tech', 'E-Commerce', 'E-Commerce & Ar', 'Fintech',
#        'Hr Tech', 'Food Tech', 'Health', 'Healthcare', 'Safety Tech',
#        'Pharmaceutical', 'Insurance Technology', 'Ai', 'Foodtech', 'Food',
#        'Iot', 'E-Marketplace', 'Robotics & Ai', 'Logistics', 'Travel',
#        'Manufacturing', 'Food & Nutrition', 'Social Media', 'N/A',
#        'E-Sports', 'Cosmetics', 'B2B', 'Jewellery', 'B2B Supply Chain',
#        'Games', 'Food & Tech', 'Accomodation', 'Automotive Tech',
#        'Legal Tech', 'Mutual Funds', 'Cybersecurity', 'Automobile',
#        'Sports', 'Healthtech', 'Yoga & Wellness', 'Virtual Banking',
#        'Transportation', 'Transport & Rentals',
#        'Marketing & Customer Loyalty', 'Infratech', 'Hospitality',
#        'Automobile & Technology', 'Banking'], dtype=object)

# %%
# Inspecting the "Amount($)" column

df2["Amount($)"].unique()
# Out:
# array(['$6,300,000', '$150,000,000', '$28,000,000', '$30,000,000',
#        '$6,000,000', 'Undisclosed', '$1,000,000', '$20,000,000',
#        '$275,000,000', '$22,000,000', '$5,000,000', '$140,500',
#        '$540,000,000', '$15,000,000', '$182,700', '$12,000,000',
#        '$11,000,000', '$15,500,000', '$1,500,000', '$5,500,000',
#        '$2,500,000', '$140,000', '$230,000,000', '$49,400,000',
#        '$32,000,000', '$26,000,000', '$150,000', '$400,000', '$2,000,000',
#        '$100,000,000', '$8,000,000', '$100,000', '$50,000,000',
#        '$120,000,000', '$4,000,000', '$6,800,000', '$36,000,000',
#        '$5,700,000', '$25,000,000', '$600,000', '$70,000,000',
#        '$60,000,000', '$220,000', '$2,800,000', '$2,100,000',
#        '$7,000,000', '$311,000,000', '$4,800,000', '$693,000,000',
#        '$33,000,000'], dtype=object)

# %%
# Removing the dollar and commma symbols in the Amount($) column

df2["Amount($)"] = df2["Amount($)"].replace(['\$', ','], '', regex=True)
df2["Amount($)"].unique()
# Out:
# array(['6300000', '150000000', '28000000', '30000000', '6000000',
#        'Undisclosed', '1000000', '20000000', '275000000', '22000000',
#        '5000000', '140500', '540000000', '15000000', '182700', '12000000',
#        '11000000', '15500000', '1500000', '5500000', '2500000', '140000',
#        '230000000', '49400000', '32000000', '26000000', '150000',
#        '400000', '2000000', '100000000', '8000000', '100000', '50000000',
#        '120000000', '4000000', '6800000', '36000000', '5700000',
#        '25000000', '600000', '70000000', '60000000', '220000', '2800000',
#        '2100000', '7000000', '311000000', '4800000', '693000000',
#        '33000000'], dtype=object)

# %%
# Replacing Undisclosed in the "Amount($)" column with zero, in order to change the datatype to integer

df2["Amount($)"] = df2["Amount($)"].replace('Undisclosed', 0, regex=True)
df2["Amount($)"].unique()
# Out:
# array(['6300000', '150000000', '28000000', '30000000', '6000000', 0,
#        '1000000', '20000000', '275000000', '22000000', '5000000',
#        '140500', '540000000', '15000000', '182700', '12000000',
#        '11000000', '15500000', '1500000', '5500000', '2500000', '140000',
#        '230000000', '49400000', '32000000', '26000000', '150000',
#        '400000', '2000000', '100000000', '8000000', '100000', '50000000',
#        '120000000', '4000000', '6800000', '36000000', '5700000',
#        '25000000', '600000', '70000000', '60000000', '220000', '2800000',
#        '2100000', '7000000', '311000000', '4800000', '693000000',
#        '33000000'], dtype=object)

# %%
# Converting the datatype of the Amount($) column to integer

df2["Amount($)"] = df2["Amount($)"].astype("int64")
df2["Amount($)"].unique()
# Out:
# array([  6300000, 150000000,  28000000,  30000000,   6000000,         0,
#          1000000,  20000000, 275000000,  22000000,   5000000,    140500,
#        540000000,  15000000,    182700,  12000000,  11000000,  15500000,
#          1500000,   5500000,   2500000,    140000, 230000000,  49400000,
#         32000000,  26000000,    150000,    400000,   2000000, 100000000,
#          8000000,    100000,  50000000, 120000000,   4000000,   6800000,
#         36000000,   5700000,  25000000,    600000,  70000000,  60000000,
#           220000,   2800000,   2100000,   7000000, 311000000,   4800000,
#        693000000,  33000000], dtype=int64)

# %%
# Evaluating the entire dataset

df2.head()
# Out:
#     Company/Brand HeadQuarter           Sector  Amount($)
# 0  Bombay Shaving         N/A        Ecommerce    6300000
# 1       Ruangguru      Mumbai           Edtech  150000000
# 2        Eduisfun      Mumbai           Edtech   28000000
# 3        HomeLane     Chennai  Interior Design   30000000
# 4        Nu Genes   Telangana         Agritech    6000000

# %%
# Confirming that there are no empty cells

df2.isna().sum()
# Out:
# Company/Brand    0
# HeadQuarter      0
# Sector           0
# Amount($)        0
# dtype: int64

# %% [markdown]
# There are no empty cells in our dateset, and the columns have been inspected and cleaned.
#
# Next is to add the "Funding Year" column.

# %%
# Creating a new column named "Funding Year" and filling it with 2019

df2["Funding Year"] = 2019
df2.head()
# Out:
#     Company/Brand HeadQuarter           Sector  Amount($)  Funding Year
# 0  Bombay Shaving         N/A        Ecommerce    6300000          2019
# 1       Ruangguru      Mumbai           Edtech  150000000          2019
# 2        Eduisfun      Mumbai           Edtech   28000000          2019
# 3        HomeLane     Chennai  Interior Design   30000000          2019
# 4        Nu Genes   Telangana         Agritech    6000000          2019

# %% [markdown]
# # Cleaning the third data set

# %%
# Evaluating the third dataset

df3.head()
# Out:
#   Company/Brand Founded HeadQuarter              Sector
# 0    Aqgromalin    2019     Chennai            AgriTech  \
# 1      Krayonnz    2019   Bangalore              EdTech
# 2  PadCare Labs    2018        Pune  Hygiene management
# 3         NCOME    2020   New Delhi              Escrow
# 4    Gramophone    2016      Indore            AgriTech
#
#                                         What it does
# 0                       Cultivating Ideas for Profit  \
# 1  An academy-guardian-scholar centric ecosystem ...
# 2   Converting bio-hazardous waste to harmless waste
# 3                       Escrow-as-a-service platform
# 4  Gramophone is an AgTech platform enabling acce...
#
#                                             Founders
# 0                    Prasanna Manogaran, Bharani C L  \
# 1                   Saurabh Dixit, Gurudutt Upadhyay
# 2                                    Ajinkya Dhariya
# 3                                      Ritesh Tiwari
# 4  Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
#
#                               Investor    Amount($)     Stage Unnamed: 9
# 0                      Angel investors     $200,000       NaN        NaN
# 1                      GSF Accelerator     $100,000  Pre-seed        NaN
# 2                       Venture Center  Undisclosed  Pre-seed        NaN
# 3  Venture Catalysts, PointOne Capital     $400,000       NaN        NaN
# 4  Siana Capital Management, Info Edge     $340,000       NaN        NaN

# %%
# Dropping the "Founded", "What it does", "Founders", "Investor" and "Stage" columns

df3 = df3.drop(["Founded", "What it does", "Founders", "Investor", "Stage"], axis =1)
df3.head()
# Out:
#   Company/Brand HeadQuarter              Sector    Amount($) Unnamed: 9
# 0    Aqgromalin     Chennai            AgriTech     $200,000        NaN
# 1      Krayonnz   Bangalore              EdTech     $100,000        NaN
# 2  PadCare Labs        Pune  Hygiene management  Undisclosed        NaN
# 3         NCOME   New Delhi              Escrow     $400,000        NaN
# 4    Gramophone      Indore            AgriTech     $340,000        NaN

# %%
# Checking the cell values

df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1055 entries, 0 to 1054
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1055 non-null   object
#  1   HeadQuarter    961 non-null    object
#  2   Sector         1042 non-null   object
#  3   Amount($)      1052 non-null   object
#  4   Unnamed: 9     2 non-null      object
# dtypes: object(5)
# memory usage: 41.3+ KB

# %%
# Confirming the number of empty cells

df3.isna().sum()
# Out:
# Company/Brand       0
# HeadQuarter        94
# Sector             13
# Amount($)           3
# Unnamed: 9       1053
# dtype: int64

# %% [markdown]
# There are ninety-four empty cells in the "HeadQuarter" column, thirteen empty cells in the "Sector" column, three empty cells in the "Amount($)" column and one thousand and fifty-three empty cells in the "Unnamed: 9" column. The empty cells in the "HeadQuarter" and "Sector" columns will be filled with N/A. This will be done when inspecting the cells.
#
# The "Unnamed: 9" column has only two cells with cell values, it is absent in other datasets, and it has no effect on our hypothesis and questions. For these reasons, this column will be dropped.

# %%
# Dropping the "Unnamed: 9" column

df3 = df3.drop(["Unnamed: 9"], axis =1)
df3.head()
# Out:
#   Company/Brand HeadQuarter              Sector    Amount($)
# 0    Aqgromalin     Chennai            AgriTech     $200,000
# 1      Krayonnz   Bangalore              EdTech     $100,000
# 2  PadCare Labs        Pune  Hygiene management  Undisclosed
# 3         NCOME   New Delhi              Escrow     $400,000
# 4    Gramophone      Indore            AgriTech     $340,000

# %%
# Confirming that there are no empty cells

df3.isna().sum()
# Out:
# Company/Brand     0
# HeadQuarter      94
# Sector           13
# Amount($)         3
# dtype: int64

# %%
# Checking for duplicate rows

df3.duplicated().sum()
# Out:
# 7

# %%
# Dropping the duplicate rows

df3 = df3.drop_duplicates()

# Confirming that the duplicate rows have been dropped

df3.duplicated().sum()
# Out:
# 0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1048 entries, 0 to 1054
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1048 non-null   object
#  1   HeadQuarter    955 non-null    object
#  2   Sector         1035 non-null   object
#  3   Amount($)      1045 non-null   object
# dtypes: object(4)
# memory usage: 40.9+ KB

# %% [markdown]
# After dropping the duplicate rows, the number of rows reduced from 1055 to 1048.

# %% [markdown]
# # Checking the data quality

# %%
# Inspecting the "Company/Brand" column

df3["Company/Brand"].unique()
# Out:
# array(['Aqgromalin', 'Krayonnz', 'PadCare Labs', 'NCOME', 'Gramophone',
#        'qZense', 'MyClassboard', 'Metvy', 'Rupeek', 'Gig India',
#        'Slurrp Farm', 'Medfin', 'MasterG', 'Brila 91', 'FoodyBuddy',
#        'Zomato', 'OurEye.ai', 'Shiprocket', 'Pine Labs',
#        'Moneyboxx Finance', 'EWar', 'SucSEED Indovation', 'TaxBuddy.com',
#        'Awign Enterprises', 'Circle of Angels', 'CoinDCX', 'Glance',
#        'VerSe Innovation', 'Voosh', 'Delhivery', 'Arya', 'Pickrr',
#        'PhonePe', 'Countingwell', 'Callify.ai', 'Hudle', 'Cover it Up',
#        'BiteSpeed', 'WakeFit', 'Sreyas Holistic Remedies', 'Fleeca India',
#        'M1xchange', 'Exotel', 'PagarBook', 'PointOne Capital', 'Ayana',
#        'Fisdom', 'Tinker Coders', 'Infinite Uptime', 'HappyLocate',
#        'Loop Health', 'NeoDocs', 'The ePlane', 'TagMango', 'The New Shop',
#        'MobiKwik', 'DebugsBunny', 'BHIVE Investech', 'Rivigo', 'ZipLoan',
#        'Swipez', 'Humus', 'Artivatic.ai', 'Prescinto', 'Toppeq',
#        'Bolo Indya', 'Bombay Play', 'FreshToHome', 'KIKO TV',
#        'Atomberg Technologies', 'DealShare', 'Smallcase', 'CueMath',
#        'Gamerji', '5C Network', 'Ethereum Push Notification Service',
#        'Mihup', 'RuralBasket', 'WayCool Foods', 'Infra.Market',
#        'Info Edge Venture', 'Clovia', 'Codingal', 'CRED',
#        'Vistaar Finance', "Let's Dive", 'Habitat', 'SAWO Labs', 'Signzy',
#        'KopyKitab', 'Kyt', 'Raskik', 'GetWork',
#        'Mobile Premier League (MPL)', 'Pravasirojgar', 'Omatra Hotels',
#        'Awign', 'NewsReach', 'Cashfree', 'Credgenics', 'GeoIQ',
#        'Country Delight', 'Quintype', 'CARS24', 'Astrogate Labs',
#        'Power Gummies', 'Cityflo', 'AlgoBulls', 'Inntot', 'Ensuredit',
#        'Shipsy', 'ERPNext', 'LightSpeedAI', 'Grip Invest', 'Unacademy',
#        'Yellow Classes', 'Plum', 'STAGE', 'Nykaa', 'Kaagaz Scanner',
#        'NIRA', 'Prolixr', "Byju's", 'DaMENSCH', 'SignalX', 'Lancify',
#        'Krimanshi', 'Instoried', 'PlayerzPot', 'Instamojo', 'Turtlemint',
#        'Arata', 'MPL', 'True Balance', 'Thrive', 'Kitchens Centre',
#        'Prescribe', 'Nepra', 'inFeedo', 'Shilpa Sciences', 'Arzooo',
#        'MindTickle', 'Slice', 'Rapawalk', "Oga Fit's", 'LAVAL',
#        'Stride Ventures', 'BlackSoil', 'Biocon', 'Clientjoy',
#        'Xpressbees', 'GalaxyCard', 'Wellness Forever', 'MoooFarm',
#        'BitClass', 'Gonuts', 'Uolo', 'Kirana King', 'Jade Forest',
#        'iKure', 'FrontRow', 'Reliance Retail', 'TUBBR', 'Ather Energy',
#        'Routematic', 'LivFin', 'Universal Sportsbiz Pvt Ltd',
#        'Lattu Kids', 'Eggoz', 'Steradian Semiconductors', 'CHARGE+ZONE',
#        'Stones2milestones', 'Udacity', 'AjnaLens', 'Gully Network',
#        'TurboHire', 'Traya', 'Charcoal Eats', 'Mitron TV', 'Svami',
#        'Dhurnia', 'Expertrons', 'Leena AI', 'Bizlog', 'Tamasha.live',
#        'Fedo', 'FabHotels', 'Freshokartz', 'FlexiLoans', 'Agrix',
#        'BharatAgri', 'FreshtoHome', 'Credable', 'Railofy',
#        'Finova Capital', 'Teachmint', 'Peel-Works', 'Janani',
#        'Finelistings', 'Wellversed', 'Jumbotail', 'Winzo', 'mCaffeine',
#        'Pocket FM', 'Snackible', 'TagZ Foods', 'Genius Teacher',
#        'Krimanshi Feeds', 'Origo', 'GetVantage', 'Betterplace', 'Biddano',
#        'InVideo', 'Hubilo', 'BASIC Home Loan', 'Ketos', 'SUGAR cosmetics',
#        'Ahaguru', 'Tekion', 'Brighteye Ventures', 'EzeRx', 'VitalTech',
#        'Ultraviolette Automotive', 'Tring', 'Rare Planet', 'GoodGamer',
#        'InnAccel', 'Tiliter', 'Slintel', 'SoOLEGAL', 'HobSpace',
#        'Supplynote', 'Hire Me Car', 'ShopUp', 'Harmonizer India',
#        'Dukaan', 'CredR', 'Satyukt', 'RACEnergy', 'TREAD', 'Anveshan',
#        'TeaMonk', 'Fleetx', 'ReNEWate', 'Tango Eye', 'Avataa Me',
#        'Arrival', 'Cover Genius', 'Phononic Vibes', 'MikeLegal', 'Clair',
#        'Gourmet Garden', 'Miko', 'Razorpay', 'Ninjacart', 'Wow! Momo',
#        'Pepper Content', 'LIVSPACE', 'Acculi Labs', 'Your MD', 'Antaios',
#        'Unnati', 'Disprz', 'Uni', 'Credit Wise Capital', 'Chargebee',
#        'Reliance Retail Ventures Ltd', 'Winuall', 'Genrobotics', 'Livve',
#        'Ergos', 'Krishitantra', 'PakkaProfile', 'Monet Networks',
#        'Unocoin', 'Pesto', 'NirogStreet', 'Bambrew', 'Omnify',
#        'Fanball XI', 'Treebo Hotels', 'GPS Renewables', 'Public',
#        'Legal Salah', 'FanPlay', 'ECOSTP', 'Coralogix', 'Equiwatt',
#        'Reliance Retail Ventures', 'Zhangmen', 'AgroWave',
#        'Sapio Analytics', 'Taimei', 'Avanse Financial Services',
#        'Industry Buying', 'Hopscotch', 'Pristyn Care', 'WoodenStreet',
#        'ACKO', 'Farmers Fresh Zone', 'Invento', 'Infurnia',
#        "AnalytIQSports's SuperCric", 'Snowflake', 'GenieTalk',
#        'Classplus', 'Mobile Premier League', 'Fourth Partner Energy',
#        'Flipkart', 'Vivriti Capital', 'InsuranceDekho', 'BestDoc',
#        'Byju’s', 'Melorra', 'Reliance', 'Inflexor Ventures', 'Pandorum',
#        'SpeakIn', 'LetsUp', 'Newsreach', 'Dream11', 'JetSynthesys',
#        'Vesta Space Technology', 'Dozee', 'Rebel Foods', 'Ketto',
#        'Suryoday', 'SucSEED', 'Strata', '3one4 Capital', 'WE-Hub',
#        'Vicara', 'Gaana', 'EM3 Agri', 'Odwen', 'Fasal', 'Trukky',
#        'BankBazaar', 'Specsmakers', 'Grinntech', 'CreditMantri',
#        'Chai Waale', 'Deepsync', 'ConnectedH', 'QShala', 'Pitstop',
#        'Customfit ai', 'Nirmata', 'Oga Fit', 'ShipsKart', 'SquadStack',
#        'Financepeer', 'Cashify', 'Etrio', 'Codeyoung', 'StayQrious',
#        'Sunstone Eduversity', 'Infilect', 'MobiGarage', 'Samunnati',
#        'WeInnovate Biosolutions', 'Yummy Corp', 'Clairvolex', 'Assiduus',
#        'Brinton', 'AFK Gaming', 'Infarm', 'Zuper', 'Origa',
#        'GullyBuy Software', 'Recordent', 'Penny', 'Onsitego', 'Precily',
#        'SmartClean', 'ClanConnect', 'Servify', 'ShareChat', 'Rephrase.ai',
#        'EkAnek', 'Cub McPaws', 'Zimyo', 'PumPumPum', 'Burgerama',
#        'Moms Co', 'DillyHub', 'FPL Technologies', 'FITTR', 'Illumnus',
#        'CashKaro', 'Newton School', 'Airmeet', 'Observe ai', 'InCred',
#        'Toppr', 'CarTrade', 'LEAD School', 'Lido Learning', 'Apna.co',
#        'Quintype Technologies', 'Dunzo', 'Entropik', 'Livspace', 'WinZO',
#        'SenseHawk', 'Eloelo', 'Aibono', 'BuildPan', 'Homelane', 'MyGlamm',
#        'Aviom', 'Flinto', 'WayCool', 'YAP', 'Big Bang Boom Solutions',
#        'GUVI', 'BluSmart', 'Cell Propulsion', 'Spoonshot', 'Pulse',
#        'Groww', 'i3 Systems', 'SOAL', 'OckyPocky', 'Hippo Video',
#        'Hasura', 'Qapita', 'Sunday', 'Gamezop', 'Phool.co',
#        'Chiratae Ventures', 'MedLife', 'IDfy', 'Bira91', 'Max wholesale',
#        'Craftsvilla', 'MechMocha', 'Mindhouse', 'DeepSync', 'Eruditus',
#        'Gradeup', 'Tracxn', 'Purple Style Labs', 'ProPhysio',
#        'Flickstree', 'Settl', 'Fanspole', 'Sarva', 'Univ.ai', 'PurohitJi',
#        'CredoLab', 'Brick&Bolt', '6Degree', 'Exprs', 'Bikayi',
#        'Virtual Forest', 'The Health company', 'TrulyMadly Matchmakers',
#        'TrueFan', 'Avail Finance', 'The Money Club', 'Virohan', 'OneCode',
#        'Verloop.io', 'Otipy', 'Evage', 'Trell', 'Captain Fresh', 'Pixxel',
#        'Habbit Health', 'SmarterBiz', 'Able Jobs', 'Vieroots',
#        'Stack Finance', 'Masai School', 'Mitron', 'Daalchini',
#        'Suno India', 'LendingKart', 'Text Mercato', 'Eden Smart Homes',
#        'GrayQuest', 'BigHaat', 'CityCash', 'HomeLane', 'HungerBox',
#        'DaveAI', 'Eduvanz', 'DocSumo', 'CUSMAT', 'Chingari',
#        'Data Sutram', 'Wobot Intelligence', 'DrinkPrime', 'Infeedo',
#        'Probus Smart Things', 'CrowdPouch', 'Hevo', 'BigSpoon Foods',
#        'DatStop', 'IPHM Services', 'Wellcure', 'VilCart', 'Firescore',
#        'BulBul', 'Pickright Technologies', 'Muse Wearables',
#        'SATYA Microcapital', 'WYN Studio', 'Entri', 'Snack Amor',
#        'MPowered', 'Leap Club', 'Gigforce', 'Vegrow', 'Finn', 'Bijnis',
#        'iNurture', 'StyleDotMe', 'Ripsey', 'ThriveFNC', 'Vedantu',
#        'Magicpin', 'Procol', 'Yumlane', 'Crio', 'Openapp',
#        'uFony Services Pvt ltd', 'Protinus Fashion Networking Pvt Ltd',
#        'Uable', 'ParkSmart', 'IncNut Digital', 'GigIndia', 'Specsmaker',
#        'Piggy Ride', 'NOTO', 'Cuemath', 'Cars24', 'Earth Energy EV',
#        'Green Cure', 'Blue Sky Analytics', 'Edhusk', 'Decentro',
#        'Zolostays', 'Frontier Markets', 'Brainwired', 'Aye Finance',
#        'Paper Boat', 'Ken42', 'Forbidden Foods', 'Universal Sportsbiz',
#        'Gobbly', 'Aerostrovilos', 'Bulk MRO', 'Inspektlabs', 'Zetwerk',
#        'ChitMonks', 'Walrus', 'Arth Designbuild', 'goDutch', 'Rusk Media',
#        'Bold Care', 'Samosa Party', 'High Street Essentials', 'Fullife',
#        'Oziva', 'Aether Biomedical', '91springboard', 'Yulu',
#        'Milkbasket', 'MergerDomo', 'GoMechanic', 'Milk Mantra', 'Myglamm',
#        'Drishti Technologies', 'Instasolv', 'GoldenPi', 'Peppermint',
#        'Jai Kisan', 'Agro2o', 'LetsTransport', 'GabbarDeals',
#        'Crimson Healthcare', 'Biomoneta', 'Edvizo', 'Drum Food',
#        'Innoviti', 'Jiffy ai', 'Postman', 'F5', 'Waycool',
#        'Myelin Foundry', 'Ameliorate Biotech', 'Hapramp', 'MyKaam',
#        'HealthPlix', 'YoloBus', 'iNurture Education', 'Pocket52',
#        'QuaQua', 'Crofarm', 'Timios', 'Wooden Street', 'Rentmojo',
#        'Credgencies', 'Knorish', 'Vahak', 'Nutrova', 'Cube Wealth',
#        'IVF Access', 'Hoi Foods', 'Ola Financial Services', 'Awifs',
#        'Swiflearn', 'Remedo', 'Blowhorn', 'Toch', 'Gram Cover',
#        'Coin DCX', 'HomeCapital', 'Euler Motors', 'Riskcovry',
#        'NWNT (No Worry No Tension Healthcare)', 'Voicezen',
#        'Credit Mantri', 'Xtracap', 'Vakilsearch', 'Khatabook',
#        'Indian School Finance Company', 'Juicy Chemistry', 'DeepTek',
#        'Stepathlon Lifestyle', 'Sindhuja Microcredit',
#        'Tesco Charge Zone', 'Intello Labs', 'SirionLabs', 'GroCurv',
#        'Refrens', 'Spyne', 'Docsapp', 'Phable', 'Generic Aadhaar', 'Nium',
#        'Mintoak', 'VestSpace', 'Blackbuck', 'Vernacular ai', 'Clover',
#        'Varthana', 'Codeninja', 'MetaMerphoSys', 'Rooter', 'Aker Foods',
#        'Sascan Meditech pvt ltd', 'DailyHunt', 'Pratilipi',
#        'Biryani By Kilo', 'Consure Medical', 'Tessol', 'News Reach',
#        'RoomSoom', 'Pedagogy', 'Medlife', 'Qin1', 'MYSUN', 'ShopX',
#        'NewsBytes', 'Wagonfly', 'Convosight', 'Fittr', 'AsknBid',
#        'Finaureus Technologies', 'Daily Ninja',
#        'Guvi Geek Network Pvt Ltd', 'LoadShare', 'Indusface', 'DMI Group',
#        'Spintly', 'Credr', 'Bijak', 'Bugworks', 'Yap', 'UzhavarBumi',
#        'Tattva', 'Pariksha', 'NoBroker', 'Box8', 'Capital Float',
#        'ITILITE', 'Morning Context', 'Aavenir', 'Savvy Co op', 'BLive',
#        'Yellow Messenger', 'Ewar', 'Setu', 'Wellthy Therapeutics',
#        'Locale ai', 'FarEye', 'Porter', 'SugarBox', 'Big Basket', 'Amica',
#        'Fingerlix', 'Plop', 'Zupee', 'DeHaat', 'Swiggy', 'Akna Medical',
#        'RaRa Delivery', 'JusPay', 'Obviously AI', 'Fingpay', 'Recko',
#        'Furlenco', 'Mera Cashier', 'Camp K12', 'MedGenome', 'Samadhan',
#        'SaScan', 'CureFit', 'Nimesa', 'Design X', 'Driftly Electric',
#        'Imstrong', 'Rupifi', 'SnackAmor', 'Zealthy', 'NuNu TV', 'QTalk',
#        'Shadez', 'Excess2Sell', 'Stanplus', 'Univariety', 'Peel Works',
#        'CoreStack', 'Agnikul', 'Fintso', 'Smart Coin', 'ZunRoof',
#        'Shop101', 'OM Bhakti', 'Lal10', 'Anaxee Digital Runner',
#        'CollegeKhabri', 'Ola Electric', 'Multi Living', 'FamPay',
#        'UnboxRobotics Labs', 'Karbon Card', 'Innerchef', 'Epigamia',
#        'StyleNook', 'Callido Learning', 'Soxytoes', 'Salesken',
#        'Leap Finance', 'Sleepy Owl', 'Tricog', 'GogoBus',
#        'Spaciya Consultants', 'Bounce', 'Neeman', 'Chqbook', 'SMEcorner',
#        'Oda Class', 'Spinny', 'goStops', 'Umeed Housing', 'Vogo',
#        'Flick Stree', 'Qure ai', 'MinionLabs', 'Josh Talks',
#        'PhoneParLoan', 'RailYatri', 'Pepper', 'iMerit', 'BharatPe',
#        'Invideo', 'AvalonMeta', 'Near Store', 'ElecTorq',
#        'Prayaan Capital', 'Sanfe', 'Go Desi', 'Whatfix', 'Zvesta',
#        'Digit Insurance', 'Yolo', 'SmartVizX', 'MaxWholesale',
#        'Carbon Clean', 'Genius Corner', 'PlanetSpark', 'CamCom', 'Simsim',
#        'Shuttl', 'HooLiv', 'ClassMonitor', 'Friyey', 'Oga', 'CYFIRMA',
#        'Paytm money', 'Nova Credit', 'CodingNinjas', 'HempStreet',
#        'MoEngage', 'Chaayos', 'PetPooja', 'Altor', 'Pepperfry',
#        'FirstCry', 'Byju', 'WorkIndia', 'Qyuki', 'Leap India', 'Picxy',
#        'NEETprep', 'Dot Pvt. Ltd', 'Kuku FM', 'SuperMoney', 'AlphaVector',
#        'Fox Capital', 'Tribe Theory', 'Embibe', 'Oye! Rickshaw',
#        'Seal Professional', 'Sprinng Foods', '1MG', 'Aagey', 'Doubtnut',
#        'AdonMo', 'Kisan Network', 'Unotech', 'CureSkin', 'WizKlub',
#        'Interviewbit', 'MoneyTap', 'Uniplatform Tech', 'INdwealth',
#        'Bizongo', 'AppsFlyer', 'Konfinity', 'Nupay', 'LogiNext',
#        'Samosa Singh', 'Crysta', 'Eupheus Learning', 'Park+', 'Goodmylk',
#        'SmartKarrot', 'Skylo', 'Tea Trunk', 'Zoomcar', 'Samya AI',
#        'Kristal AI', 'Invento Robotics', 'Sabse Sasta Dukaan',
#        'Fitphilia', 'Medicus', 'Monech', 'Teach Us', 'Dealberg',
#        'Phenom People', 'Extra Edge', 'Capital Quotient', 'Karfa',
#        'Zinier', 'ProEves', 'Toddle', 'Aesthetic Nutrition',
#        'TechnifyBiz', 'Wysh', 'Keito', 'Klub', 'Aadhar', 'IncubateHub',
#        'Rage Coffee', 'Skilancer', 'Harappa Education', 'Rheo',
#        'Axio Biosolutions', 'Techbooze', 'PayMart', 'Testbook',
#        'FabAlley', 'HaikuJAM', 'Mamaearth', 'Rentomojo', 'Generico',
#        'HighRadius', 'Chai Kings', 'Shiksha', 'Super Surfaces', 'Quicko',
#        'Satin Creditcare', 'XpressBees', 'FarmERP', 'Wealth Bucket',
#        'Fashor', 'Leverage Edu', 'EpiFi', 'Purplle', 'Pando'],
#       dtype=object)

# %%
# Inspecting the "HeadQuarter" column

df3["HeadQuarter"].unique()
# Out:
# array(['Chennai', 'Bangalore', 'Pune', 'New Delhi', 'Indore', 'Hyderabad',
#        'Gurgaon', 'Belgaum', 'Noida', 'Mumbai', 'Andheri', 'Jaipur',
#        'Ahmedabad', 'Kolkata', 'Tirunelveli, Tamilnadu', 'Thane', nan,
#        'Singapore', 'Gurugram', 'Gujarat', 'Haryana', 'Kerala', 'Jodhpur',
#        'Jaipur, Rajastan', 'Delhi', 'Frisco, Texas, United States',
#        'California', 'Dhingsara, Haryana', 'New York, United States',
#        'Patna', 'San Francisco, California, United States',
#        'San Francisco, United States', 'San Ramon, California',
#        'Paris, Ile-de-France, France', 'Plano, Texas, United States',
#        'Sydney', 'San Francisco Bay Area, Silicon Valley, West Coast',
#        'Bangaldesh', 'London, England, United Kingdom',
#        'Sydney, New South Wales, Australia', 'Milano, Lombardia, Italy',
#        'Palmwoods, Queensland, Australia', 'France',
#        'San Francisco Bay Area, West Coast, Western US',
#        'Trivandrum, Kerala, India', 'Cochin', 'Samastipur, Bihar',
#        'Irvine, California, United States', 'Tumkur, Karnataka',
#        'Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom',
#        'Shanghai, China', 'Jiaxing, Zhejiang, China', 'Rajastan', 'Kochi',
#        'Ludhiana', 'Dehradun', 'San Franciscao', 'San Francisco',
#        'Tangerang, Jawa Barat, Indonesia', 'Berlin', 'Seattle', 'Riyadh',
#        'Seoul', 'New York', 'Bangkok', 'Kanpur', 'Chandigarh', 'Warangal',
#        'Hyderebad', 'Odisha', 'Bihar', 'Goa', 'Tamil Nadu',
#        'Uttar Pradesh', 'Bhopal', 'Banglore', 'Coimbatore', 'Bengaluru'],
#       dtype=object)

# %% [markdown]
# Some cells in the "HeadQuarter" column contain the name of the city, state, and country. Since only the name of the city is required and it is the first name before the first comma on the cells, the first name on each cell will be kept and the rest of the names removed.

# %%
# Splitting the "HeadQuarter" column values by comma and selecting only the first word (name of the city)

df3["HeadQuarter"] = df3["HeadQuarter"].str.split(',').str[0]
df3["HeadQuarter"].unique()
# Out:
# array(['Chennai', 'Bangalore', 'Pune', 'New Delhi', 'Indore', 'Hyderabad',
#        'Gurgaon', 'Belgaum', 'Noida', 'Mumbai', 'Andheri', 'Jaipur',
#        'Ahmedabad', 'Kolkata', 'Tirunelveli', 'Thane', nan, 'Singapore',
#        'Gurugram', 'Gujarat', 'Haryana', 'Kerala', 'Jodhpur', 'Delhi',
#        'Frisco', 'California', 'Dhingsara', 'New York', 'Patna',
#        'San Francisco', 'San Ramon', 'Paris', 'Plano', 'Sydney',
#        'San Francisco Bay Area', 'Bangaldesh', 'London', 'Milano',
#        'Palmwoods', 'France', 'Trivandrum', 'Cochin', 'Samastipur',
#        'Irvine', 'Tumkur', 'Newcastle Upon Tyne', 'Shanghai', 'Jiaxing',
#        'Rajastan', 'Kochi', 'Ludhiana', 'Dehradun', 'San Franciscao',
#        'Tangerang', 'Berlin', 'Seattle', 'Riyadh', 'Seoul', 'Bangkok',
#        'Kanpur', 'Chandigarh', 'Warangal', 'Hyderebad', 'Odisha', 'Bihar',
#        'Goa', 'Tamil Nadu', 'Uttar Pradesh', 'Bhopal', 'Banglore',
#        'Coimbatore', 'Bengaluru'], dtype=object)

# %%
# Filling the empty cells in the "HeadQuarter" column with N/A

df3["HeadQuarter"] = df3["HeadQuarter"].fillna('N/A')
df3["HeadQuarter"].unique()
# Out:
# array(['Chennai', 'Bangalore', 'Pune', 'New Delhi', 'Indore', 'Hyderabad',
#        'Gurgaon', 'Belgaum', 'Noida', 'Mumbai', 'Andheri', 'Jaipur',
#        'Ahmedabad', 'Kolkata', 'Tirunelveli', 'Thane', 'N/A', 'Singapore',
#        'Gurugram', 'Gujarat', 'Haryana', 'Kerala', 'Jodhpur', 'Delhi',
#        'Frisco', 'California', 'Dhingsara', 'New York', 'Patna',
#        'San Francisco', 'San Ramon', 'Paris', 'Plano', 'Sydney',
#        'San Francisco Bay Area', 'Bangaldesh', 'London', 'Milano',
#        'Palmwoods', 'France', 'Trivandrum', 'Cochin', 'Samastipur',
#        'Irvine', 'Tumkur', 'Newcastle Upon Tyne', 'Shanghai', 'Jiaxing',
#        'Rajastan', 'Kochi', 'Ludhiana', 'Dehradun', 'San Franciscao',
#        'Tangerang', 'Berlin', 'Seattle', 'Riyadh', 'Seoul', 'Bangkok',
#        'Kanpur', 'Chandigarh', 'Warangal', 'Hyderebad', 'Odisha', 'Bihar',
#        'Goa', 'Tamil Nadu', 'Uttar Pradesh', 'Bhopal', 'Banglore',
#        'Coimbatore', 'Bengaluru'], dtype=object)

# %%
# Replacing Bangalore and Banglore with Bengaluru

df3["HeadQuarter"] = df3["HeadQuarter"].replace(['Bangalore', 'Banglore'], 'Bengaluru', regex=True)
df3["HeadQuarter"].unique()
# Out:
# array(['Chennai', 'Bengaluru', 'Pune', 'New Delhi', 'Indore', 'Hyderabad',
#        'Gurgaon', 'Belgaum', 'Noida', 'Mumbai', 'Andheri', 'Jaipur',
#        'Ahmedabad', 'Kolkata', 'Tirunelveli', 'Thane', 'N/A', 'Singapore',
#        'Gurugram', 'Gujarat', 'Haryana', 'Kerala', 'Jodhpur', 'Delhi',
#        'Frisco', 'California', 'Dhingsara', 'New York', 'Patna',
#        'San Francisco', 'San Ramon', 'Paris', 'Plano', 'Sydney',
#        'San Francisco Bay Area', 'Bangaldesh', 'London', 'Milano',
#        'Palmwoods', 'France', 'Trivandrum', 'Cochin', 'Samastipur',
#        'Irvine', 'Tumkur', 'Newcastle Upon Tyne', 'Shanghai', 'Jiaxing',
#        'Rajastan', 'Kochi', 'Ludhiana', 'Dehradun', 'San Franciscao',
#        'Tangerang', 'Berlin', 'Seattle', 'Riyadh', 'Seoul', 'Bangkok',
#        'Kanpur', 'Chandigarh', 'Warangal', 'Hyderebad', 'Odisha', 'Bihar',
#        'Goa', 'Tamil Nadu', 'Uttar Pradesh', 'Bhopal', 'Coimbatore'],
#       dtype=object)

# %%
# Inspecting the "Sector" column

df3["Sector"].unique()
# Out:
# array(['AgriTech', 'EdTech', 'Hygiene management', 'Escrow',
#        'Networking platform', 'FinTech', 'Crowdsourcing',
#        'Food & Bevarages', 'HealthTech', 'Fashion startup',
#        'Food Industry', 'Food Delivery', 'Virtual auditing startup',
#        'E-commerce', 'Gaming', 'Work fulfillment', 'AI startup',
#        'Telecommunication', 'Logistics', 'Tech Startup', 'Sports',
#        'Retail', 'Medtech', 'Tyre management', 'Cloud company',
#        'Software company', 'Venture capitalist', 'Renewable player',
#        'IoT startup', 'SaaS startup', 'Aero company', 'Marketing company',
#        'Retail startup', 'Co-working Startup', 'Finance company',
#        'Tech company', 'Solar Monitoring Company',
#        'Video sharing platform', 'Gaming startup',
#        'Video streaming platform', 'Consumer appliances',
#        'Blockchain startup', 'Conversational AI platform', 'Real Estate',
#        'SaaS platform', 'AI platform', 'Fusion beverages', 'HR Tech',
#        'Job portal', 'Hospitality', 'Digital Media', 'Dairy startup',
#        'Content management', 'Spacetech', 'Transportation',
#        'Trading platform', 'AI Company', 'Photonics startup',
#        'Entertainment', 'Cosmetics', 'Scanning app', 'Skincare startup',
#        'Food and Beverages', 'Biotechnology company', 'FoodTech',
#        'Proptech', 'CleanTech', 'Fitness startup', 'Healthcare',
#        'PaaS startup', 'Beverages', 'Social Media', 'Automobiles',
#        'Deeptech', 'EV startup', 'AR/VR startup', 'Recruitment startup',
#        'QSR startup', 'Video platform', 'Edtech', 'Fertility tech',
#        'Luxury car startup', 'FM', 'Food', 'Nutrition sector',
#        'Tech platform', 'Video', 'Retail Tech', 'HeathTech',
#        'Sles and marketing', 'LegalTech', 'Car Service',
#        'Bike marketplace', 'Agri tech', 'Reatil startup', 'AR platform',
#        'Consumer Goods', 'Content marketplace', 'Interior Design',
#        'Rental space', 'Soil-Tech', 'Ayurveda tech',
#        'Packaging solution startup', 'Cleantech', 'Sanitation solutions',
#        'HealthCare', 'Home Design', 'InsureTech', 'AI Startup',
#        'Solar solution', 'Jewellery startup',
#        'Multinational conglomerate company', 'Deeptech startup',
#        'Social Network', 'Publication', 'Tech', 'Fashion', 'Finance',
#        'Venture capital', 'Entreprenurship', 'Food devlivery',
#        'Warehouse', 'Online financial service', 'Eyeglasses',
#        'Battery design', 'Online credit management startup', 'Beverage',
#        'TravelTech', 'Agriculture', 'Startup laboratory',
#        'Personal care startup', 'Customer service company',
#        'SaaS\xa0\xa0startup', 'Marketing startup', 'Service industry',
#        'Social media', 'AI', 'Jewellery', 'AR startup', 'HR Tech startup',
#        'Automotive Startup', 'Food Startup', 'EdTech Startup',
#        'Car Trade', 'EdtTech', 'Manufacturing', 'AI Platform',
#        'Automation', 'Solar SaaS', 'WL & RAC protection',
#        'Social commerce', 'Home interior services', 'Agritech startup',
#        'API platform', 'Deep Tech', 'Electricity', 'Automotive company',
#        'FMCG', 'Insurance Tech', 'Video personalization',
#        'Software Company', 'Biomaterial startup', 'Health', 'IT',
#        'Craft Beer', 'Healthtech', 'Education', 'Investment',
#        'Linguistic Spiritual', 'Construction', 'Battery manufacturer',
#        'Nano Distribution Network', 'AI health', 'Dating app', 'Media',
#        'Fintech', 'Healthcare/Edtech', 'Social Commerce',
#        'Agritech/Commerce', 'Mobility tech', 'Social e-commerce',
#        'Food & Logistics', 'SpaceTech', 'Nutrition Tech', 'HR', 'IoT',
#        nan, 'Agritech', 'Interior design', 'Foodtech', 'AR/VR',
#        'Appliance', 'HR tech', 'Food tech', 'Mental Health', 'Ecommerce',
#        'Solar Solution', 'SaaS', 'Automobile', 'B2B marketplace',
#        'Fashion Tech', 'Nutrition tech', 'Health & Wellness',
#        'Cloud Kitchen', 'IoT/Automobile', 'Eye Wear', 'Digital tech',
#        'Data Intelligence', 'Co-living', 'Food & Beverages', 'Automotive',
#        'B2B', 'Defense tech', 'Marketplace', 'Construction tech',
#        'Nutrition', 'Coworking', 'Micro-mobiity', 'Auto-tech', 'Beauty',
#        'Robotics', 'Yoga & wellness', 'Logitech', 'Med Tech',
#        'Life sciences', 'Retail Aggregator', 'Deep Tech AI', 'Biotech',
#        'Blockchain', 'HrTech', 'Mobility/Transport', 'Travel', 'Rental',
#        'AI & Debt', 'SaaS/Edtech', 'Transport', 'Co-working', 'Insurtech',
#        'Cryptocurrency', 'Automotive tech', 'Legal', 'Fitness', 'EV',
#        'Supply chain, Agritech', 'Pharma', 'Insurance technology',
#        'Foodtech & Logistics', 'Housing', 'Pharmaceutical',
#        'Data Analytics', 'Investment Tech', 'Financial Services',
#        'Biopharma', 'Dairy', 'Beauty & wellness', 'Travel & SaaS',
#        'Tourism & EV', 'Media Tech', 'Location Analytics', 'E store',
#        'Data Science', 'Insurance', 'Health and Fitness', 'Technology',
#        'Interior & decor', 'eMobility', 'Automation tech',
#        'Media & Networking', 'E-market', 'AI & Data science',
#        'Travel tech', 'Automotive and Rentals', 'E-tail', 'Accomodation',
#        'AI & Media', 'Machine Learning', 'Content Marktplace',
#        'Visual Media', 'Hygiene', 'VR & SaaS', 'Sales & Services',
#        'AI & Deep learning', 'Housing & Rentals', 'Estore', 'Marketing',
#        'E tailor', 'E-mobility', 'Ad-tech', 'Neo-banking',
#        'Transport Automation', 'Techonology', 'Transport & Rentals',
#        'AI Robotics', 'Preschool Daycare', 'Food diet', 'B2B Agritech',
#        'E-connect', 'Tech hub', 'Consultancy', 'Pharmacy', 'Deisgning',
#        'Taxation', 'Automobile Technology'], dtype=object)

# %%
# Filling the empty cells in the "Sector" column with N/A

df3["Sector"] = df3["Sector"].fillna('N/A')
df3["Sector"].unique()
# Out:
# array(['AgriTech', 'EdTech', 'Hygiene management', 'Escrow',
#        'Networking platform', 'FinTech', 'Crowdsourcing',
#        'Food & Bevarages', 'HealthTech', 'Fashion startup',
#        'Food Industry', 'Food Delivery', 'Virtual auditing startup',
#        'E-commerce', 'Gaming', 'Work fulfillment', 'AI startup',
#        'Telecommunication', 'Logistics', 'Tech Startup', 'Sports',
#        'Retail', 'Medtech', 'Tyre management', 'Cloud company',
#        'Software company', 'Venture capitalist', 'Renewable player',
#        'IoT startup', 'SaaS startup', 'Aero company', 'Marketing company',
#        'Retail startup', 'Co-working Startup', 'Finance company',
#        'Tech company', 'Solar Monitoring Company',
#        'Video sharing platform', 'Gaming startup',
#        'Video streaming platform', 'Consumer appliances',
#        'Blockchain startup', 'Conversational AI platform', 'Real Estate',
#        'SaaS platform', 'AI platform', 'Fusion beverages', 'HR Tech',
#        'Job portal', 'Hospitality', 'Digital Media', 'Dairy startup',
#        'Content management', 'Spacetech', 'Transportation',
#        'Trading platform', 'AI Company', 'Photonics startup',
#        'Entertainment', 'Cosmetics', 'Scanning app', 'Skincare startup',
#        'Food and Beverages', 'Biotechnology company', 'FoodTech',
#        'Proptech', 'CleanTech', 'Fitness startup', 'Healthcare',
#        'PaaS startup', 'Beverages', 'Social Media', 'Automobiles',
#        'Deeptech', 'EV startup', 'AR/VR startup', 'Recruitment startup',
#        'QSR startup', 'Video platform', 'Edtech', 'Fertility tech',
#        'Luxury car startup', 'FM', 'Food', 'Nutrition sector',
#        'Tech platform', 'Video', 'Retail Tech', 'HeathTech',
#        'Sles and marketing', 'LegalTech', 'Car Service',
#        'Bike marketplace', 'Agri tech', 'Reatil startup', 'AR platform',
#        'Consumer Goods', 'Content marketplace', 'Interior Design',
#        'Rental space', 'Soil-Tech', 'Ayurveda tech',
#        'Packaging solution startup', 'Cleantech', 'Sanitation solutions',
#        'HealthCare', 'Home Design', 'InsureTech', 'AI Startup',
#        'Solar solution', 'Jewellery startup',
#        'Multinational conglomerate company', 'Deeptech startup',
#        'Social Network', 'Publication', 'Tech', 'Fashion', 'Finance',
#        'Venture capital', 'Entreprenurship', 'Food devlivery',
#        'Warehouse', 'Online financial service', 'Eyeglasses',
#        'Battery design', 'Online credit management startup', 'Beverage',
#        'TravelTech', 'Agriculture', 'Startup laboratory',
#        'Personal care startup', 'Customer service company',
#        'SaaS\xa0\xa0startup', 'Marketing startup', 'Service industry',
#        'Social media', 'AI', 'Jewellery', 'AR startup', 'HR Tech startup',
#        'Automotive Startup', 'Food Startup', 'EdTech Startup',
#        'Car Trade', 'EdtTech', 'Manufacturing', 'AI Platform',
#        'Automation', 'Solar SaaS', 'WL & RAC protection',
#        'Social commerce', 'Home interior services', 'Agritech startup',
#        'API platform', 'Deep Tech', 'Electricity', 'Automotive company',
#        'FMCG', 'Insurance Tech', 'Video personalization',
#        'Software Company', 'Biomaterial startup', 'Health', 'IT',
#        'Craft Beer', 'Healthtech', 'Education', 'Investment',
#        'Linguistic Spiritual', 'Construction', 'Battery manufacturer',
#        'Nano Distribution Network', 'AI health', 'Dating app', 'Media',
#        'Fintech', 'Healthcare/Edtech', 'Social Commerce',
#        'Agritech/Commerce', 'Mobility tech', 'Social e-commerce',
#        'Food & Logistics', 'SpaceTech', 'Nutrition Tech', 'HR', 'IoT',
#        'N/A', 'Agritech', 'Interior design', 'Foodtech', 'AR/VR',
#        'Appliance', 'HR tech', 'Food tech', 'Mental Health', 'Ecommerce',
#        'Solar Solution', 'SaaS', 'Automobile', 'B2B marketplace',
#        'Fashion Tech', 'Nutrition tech', 'Health & Wellness',
#        'Cloud Kitchen', 'IoT/Automobile', 'Eye Wear', 'Digital tech',
#        'Data Intelligence', 'Co-living', 'Food & Beverages', 'Automotive',
#        'B2B', 'Defense tech', 'Marketplace', 'Construction tech',
#        'Nutrition', 'Coworking', 'Micro-mobiity', 'Auto-tech', 'Beauty',
#        'Robotics', 'Yoga & wellness', 'Logitech', 'Med Tech',
#        'Life sciences', 'Retail Aggregator', 'Deep Tech AI', 'Biotech',
#        'Blockchain', 'HrTech', 'Mobility/Transport', 'Travel', 'Rental',
#        'AI & Debt', 'SaaS/Edtech', 'Transport', 'Co-working', 'Insurtech',
#        'Cryptocurrency', 'Automotive tech', 'Legal', 'Fitness', 'EV',
#        'Supply chain, Agritech', 'Pharma', 'Insurance technology',
#        'Foodtech & Logistics', 'Housing', 'Pharmaceutical',
#        'Data Analytics', 'Investment Tech', 'Financial Services',
#        'Biopharma', 'Dairy', 'Beauty & wellness', 'Travel & SaaS',
#        'Tourism & EV', 'Media Tech', 'Location Analytics', 'E store',
#        'Data Science', 'Insurance', 'Health and Fitness', 'Technology',
#        'Interior & decor', 'eMobility', 'Automation tech',
#        'Media & Networking', 'E-market', 'AI & Data science',
#        'Travel tech', 'Automotive and Rentals', 'E-tail', 'Accomodation',
#        'AI & Media', 'Machine Learning', 'Content Marktplace',
#        'Visual Media', 'Hygiene', 'VR & SaaS', 'Sales & Services',
#        'AI & Deep learning', 'Housing & Rentals', 'Estore', 'Marketing',
#        'E tailor', 'E-mobility', 'Ad-tech', 'Neo-banking',
#        'Transport Automation', 'Techonology', 'Transport & Rentals',
#        'AI Robotics', 'Preschool Daycare', 'Food diet', 'B2B Agritech',
#        'E-connect', 'Tech hub', 'Consultancy', 'Pharmacy', 'Deisgning',
#        'Taxation', 'Automobile Technology'], dtype=object)

# %%
# Inspecting the "Amount($)" column

df3["Amount($)"].unique()
# Out:
# array(['$200,000', '$100,000', 'Undisclosed', '$400,000', '$340,000',
#        '$600,000', '$45,000,000', '$1,000,000', '$2,000,000',
#        '$1,200,000', '$660,000,000', '$120,000', '$7,500,000',
#        '$5,000,000', '$500,000', '$3,000,000', '$10,000,000',
#        '$145,000,000', '$100,000,000', nan, '$21,000,000', '$4,000,000',
#        '$20,000,000', '$560,000', '$275,000', '$4,500,000', '$15,000,000',
#        '$390,000,000', '$7,000,000', '$5,100,000', '$700,000,000',
#        '$2,300,000', '$700,000', '$19,000,000', '$9,000,000',
#        '$40,000,000', '$750,000', '$1,500,000', '$7,800,000',
#        '$50,000,000', '$80,000,000', '$30,000,000', '$1,700,000',
#        '$2,500,000', '$40,000', '$33,000,000', '$35,000,000', '$300,000',
#        '$25,000,000', '$3,500,000', '$200,000,000', '$6,000,000',
#        '$1,300,000', '$4,100,000', '$575,000', '$800,000', '$28,000,000',
#        '$18,000,000', '$3,200,000', '$900,000', '$250,000', '$4,700,000',
#        '$75,000,000', '$8,000,000', '$121,000,000', '$55,000,000',
#        '$3,300,000', '$11,000,000', '$16,000,000', '$5,400,000',
#        '$150,000,000', '$4,200,000', '$22,000,000', '$52,000,000',
#        '$1,100,000', '$118,000,000', '$1,600,000', '$18,500,000',
#        '$70,000,000,000', '$800,000,000', '$400,000,000', '$150,000',
#        '$176,000,000', '$60,000,000', '$470,000', '$240,000',
#        '$3,000,000,000', '$74,000,000', '$62,000,000', '$2,100,000',
#        '$500,000,000', '$12,500,000', '$2,200,000,000', '$5,060,000',
#        '$225,000,000', '$24,700,000', '$7,700,000', '$1,90,67,328',
#        '$51,000,000', '$115,000', '$54,000', '$20,000', '$803,146',
#        '$238,000', '$10,220,000', '$1,020,000', '$12,000,000',
#        '$13,400,000', '$170,000,000', '$2,900,000', '$543,000',
#        '$90,000,000', '$3,400,000', '$23,000,000', '$8,090,000',
#        '$1,030,000', '$5,040,000', '$360,000', '$1,400,000', '$650,000',
#        '$54,000,000', '$42,500,000', '$11,370,000', '$325,000',
#        '$410,000', '$450,000', '$682,000', '$4,050,000', '$1,050,000',
#        '$1,080,000', '$4,300,000', '$6,800,000', '$2,110,000',
#        '$887,000, $23,000,000', '$764,000', '$603,000', '$409,000',
#        '$292,000', '$286,000', '$136,000', '$800,000,000 to $850,000,000',
#        '$546,000', '$887,000', '$43,000', '$40,900', '$2,200,000',
#        '$5,660,000', '$350,000', '$110,000', '$122,000,000',
#        '$11,635,000', '$2,800,000', '$1,065,000', '$669,000',
#        '$16,076,000', '$649,600', '$6,700,000', '$220,000', '$266,500',
#        '$2,879,000', '$26,500,000', '$351,000', '$ 8,700,000',
#        '$46,761,000', '$175,000', '9.600,000', '$11,241,000', '$804,000',
#        '$1,340,000', '$467,000', '$133,000', '$3,823,000', '$934,000',
#        '$293,000', '$198,000', '$927,000', '$971,000', '$3,060,000',
#        '$1,862,000', '$232,000', '$2,888,000', '$1,328,000',
#        '$15,500,000', '$56,000,000', '$2,250,000', '$16,753,000',
#        '$3,700,000', '$1,470,000', '$530,000', '$267,000', '$3,344,000',
#        '$7,200,000', '$2,743,000', '$6,082,000', '$6,609,000',
#        '$27,700,000', '$5,940,000', '$3,964,000', '$5,500,000',
#        '$197,000', '$4,327,000', '$459,000', '$3,937,000', '$1,313,500',
#        '$229,800', '$5,305,000', '$264,000', '$1,750,000', '$5,967,000',
#        '$2,980,000', 'Undiclsosed', '$323,000', '$1,326,000',
#        '$27,000,000', '$5,200,000', '$2,530,000', '$792,000',
#        '$11,363,000', '$1,715,000', '$329,000', '$5,271,000',
#        '$8,700,000', '$3,226,000', '$5,900,000', '$44,000,000',
#        '$3,879,000', '$13,000,000', '$8,800,000', '$9,500,000',
#        '$920,000', '$35,600,000', '$9,400,000', '$790,000', '$480,000',
#        '$160,000', '$8,200,000', '$4,257,000', '$1,410,000', '$349,800',
#        '$786,000', '$2,004,000', '$123,000,000', '$248,000',
#        '$24,000,000', '$14,259,000', '$24,500,000', '$3,800,000',
#        '$18,370,000', '$68,525,000', '$4,800,000', '$1,834,000',
#        '$23,850,000', '$43,000,000', '$21,600,000', '$4,598,000',
#        '$13,137,000', '$115,000,000', '$3,900,000', '$670,000',
#        '42.23,000', '$8,500,000', '$3,148,000', '$2,600,000', '25,58,000',
#        '$4,049,500', '$10,500,000', '$6,500,000', '$43,700,000',
#        '$13,800,000', '$306,900', '$420,000', '$627,300', '$113,000,000',
#        '$32,000,000', '$110,000,000', '$1,397,000', '$448,500',
#        '$7,975,700', '$330,000', '$5,600,000', '$1,402,000',
#        '$21,500,000', '$296,000,000', '$4,900,000', '$1,402,400',
#        '$12,618,300', '$9,900,000', '$982,530', '$70,185,200',
#        '$210,000,000', '$84,000,000', '$39,000,000', '$2,700,000',
#        '$1,403,400', '$105,000,000', '$103,000,000', '$281,300',
#        '$12,700', '$25,000', '$97,500,000', '$507,000', 'Undislosed',
#        '$8,400,000', '$18,300,000', '$125,000,000', '$181,000',
#        '$280,000', '$14,700,000', '$13,200,000', '$8,043,000'],
#       dtype=object)

# %%
# Replacing Undisclosed, Undiclsosed and Undislosed in the "Amount($)" column with zero

df3["Amount($)"] = df3["Amount($)"].replace(['Undisclosed', 'Undiclsosed', 'Undislosed'], 0, regex=True)
df3["Amount($)"].unique()
# Out:
# array(['$200,000', '$100,000', 0, '$400,000', '$340,000', '$600,000',
#        '$45,000,000', '$1,000,000', '$2,000,000', '$1,200,000',
#        '$660,000,000', '$120,000', '$7,500,000', '$5,000,000', '$500,000',
#        '$3,000,000', '$10,000,000', '$145,000,000', '$100,000,000', nan,
#        '$21,000,000', '$4,000,000', '$20,000,000', '$560,000', '$275,000',
#        '$4,500,000', '$15,000,000', '$390,000,000', '$7,000,000',
#        '$5,100,000', '$700,000,000', '$2,300,000', '$700,000',
#        '$19,000,000', '$9,000,000', '$40,000,000', '$750,000',
#        '$1,500,000', '$7,800,000', '$50,000,000', '$80,000,000',
#        '$30,000,000', '$1,700,000', '$2,500,000', '$40,000',
#        '$33,000,000', '$35,000,000', '$300,000', '$25,000,000',
#        '$3,500,000', '$200,000,000', '$6,000,000', '$1,300,000',
#        '$4,100,000', '$575,000', '$800,000', '$28,000,000', '$18,000,000',
#        '$3,200,000', '$900,000', '$250,000', '$4,700,000', '$75,000,000',
#        '$8,000,000', '$121,000,000', '$55,000,000', '$3,300,000',
#        '$11,000,000', '$16,000,000', '$5,400,000', '$150,000,000',
#        '$4,200,000', '$22,000,000', '$52,000,000', '$1,100,000',
#        '$118,000,000', '$1,600,000', '$18,500,000', '$70,000,000,000',
#        '$800,000,000', '$400,000,000', '$150,000', '$176,000,000',
#        '$60,000,000', '$470,000', '$240,000', '$3,000,000,000',
#        '$74,000,000', '$62,000,000', '$2,100,000', '$500,000,000',
#        '$12,500,000', '$2,200,000,000', '$5,060,000', '$225,000,000',
#        '$24,700,000', '$7,700,000', '$1,90,67,328', '$51,000,000',
#        '$115,000', '$54,000', '$20,000', '$803,146', '$238,000',
#        '$10,220,000', '$1,020,000', '$12,000,000', '$13,400,000',
#        '$170,000,000', '$2,900,000', '$543,000', '$90,000,000',
#        '$3,400,000', '$23,000,000', '$8,090,000', '$1,030,000',
#        '$5,040,000', '$360,000', '$1,400,000', '$650,000', '$54,000,000',
#        '$42,500,000', '$11,370,000', '$325,000', '$410,000', '$450,000',
#        '$682,000', '$4,050,000', '$1,050,000', '$1,080,000', '$4,300,000',
#        '$6,800,000', '$2,110,000', '$887,000, $23,000,000', '$764,000',
#        '$603,000', '$409,000', '$292,000', '$286,000', '$136,000',
#        '$800,000,000 to $850,000,000', '$546,000', '$887,000', '$43,000',
#        '$40,900', '$2,200,000', '$5,660,000', '$350,000', '$110,000',
#        '$122,000,000', '$11,635,000', '$2,800,000', '$1,065,000',
#        '$669,000', '$16,076,000', '$649,600', '$6,700,000', '$220,000',
#        '$266,500', '$2,879,000', '$26,500,000', '$351,000', '$ 8,700,000',
#        '$46,761,000', '$175,000', '9.600,000', '$11,241,000', '$804,000',
#        '$1,340,000', '$467,000', '$133,000', '$3,823,000', '$934,000',
#        '$293,000', '$198,000', '$927,000', '$971,000', '$3,060,000',
#        '$1,862,000', '$232,000', '$2,888,000', '$1,328,000',
#        '$15,500,000', '$56,000,000', '$2,250,000', '$16,753,000',
#        '$3,700,000', '$1,470,000', '$530,000', '$267,000', '$3,344,000',
#        '$7,200,000', '$2,743,000', '$6,082,000', '$6,609,000',
#        '$27,700,000', '$5,940,000', '$3,964,000', '$5,500,000',
#        '$197,000', '$4,327,000', '$459,000', '$3,937,000', '$1,313,500',
#        '$229,800', '$5,305,000', '$264,000', '$1,750,000', '$5,967,000',
#        '$2,980,000', '$323,000', '$1,326,000', '$27,000,000',
#        '$5,200,000', '$2,530,000', '$792,000', '$11,363,000',
#        '$1,715,000', '$329,000', '$5,271,000', '$8,700,000', '$3,226,000',
#        '$5,900,000', '$44,000,000', '$3,879,000', '$13,000,000',
#        '$8,800,000', '$9,500,000', '$920,000', '$35,600,000',
#        '$9,400,000', '$790,000', '$480,000', '$160,000', '$8,200,000',
#        '$4,257,000', '$1,410,000', '$349,800', '$786,000', '$2,004,000',
#        '$123,000,000', '$248,000', '$24,000,000', '$14,259,000',
#        '$24,500,000', '$3,800,000', '$18,370,000', '$68,525,000',
#        '$4,800,000', '$1,834,000', '$23,850,000', '$43,000,000',
#        '$21,600,000', '$4,598,000', '$13,137,000', '$115,000,000',
#        '$3,900,000', '$670,000', '42.23,000', '$8,500,000', '$3,148,000',
#        '$2,600,000', '25,58,000', '$4,049,500', '$10,500,000',
#        '$6,500,000', '$43,700,000', '$13,800,000', '$306,900', '$420,000',
#        '$627,300', '$113,000,000', '$32,000,000', '$110,000,000',
#        '$1,397,000', '$448,500', '$7,975,700', '$330,000', '$5,600,000',
#        '$1,402,000', '$21,500,000', '$296,000,000', '$4,900,000',
#        '$1,402,400', '$12,618,300', '$9,900,000', '$982,530',
#        '$70,185,200', '$210,000,000', '$84,000,000', '$39,000,000',
#        '$2,700,000', '$1,403,400', '$105,000,000', '$103,000,000',
#        '$281,300', '$12,700', '$25,000', '$97,500,000', '$507,000',
#        '$8,400,000', '$18,300,000', '$125,000,000', '$181,000',
#        '$280,000', '$14,700,000', '$13,200,000', '$8,043,000'],
#       dtype=object)

# %%
# Filling the empty cells in the "Amount($)" column with zero

df3["Amount($)"] = df3["Amount($)"].fillna(0)
df3["Amount($)"].unique()
# Out:
# array(['$200,000', '$100,000', 0, '$400,000', '$340,000', '$600,000',
#        '$45,000,000', '$1,000,000', '$2,000,000', '$1,200,000',
#        '$660,000,000', '$120,000', '$7,500,000', '$5,000,000', '$500,000',
#        '$3,000,000', '$10,000,000', '$145,000,000', '$100,000,000',
#        '$21,000,000', '$4,000,000', '$20,000,000', '$560,000', '$275,000',
#        '$4,500,000', '$15,000,000', '$390,000,000', '$7,000,000',
#        '$5,100,000', '$700,000,000', '$2,300,000', '$700,000',
#        '$19,000,000', '$9,000,000', '$40,000,000', '$750,000',
#        '$1,500,000', '$7,800,000', '$50,000,000', '$80,000,000',
#        '$30,000,000', '$1,700,000', '$2,500,000', '$40,000',
#        '$33,000,000', '$35,000,000', '$300,000', '$25,000,000',
#        '$3,500,000', '$200,000,000', '$6,000,000', '$1,300,000',
#        '$4,100,000', '$575,000', '$800,000', '$28,000,000', '$18,000,000',
#        '$3,200,000', '$900,000', '$250,000', '$4,700,000', '$75,000,000',
#        '$8,000,000', '$121,000,000', '$55,000,000', '$3,300,000',
#        '$11,000,000', '$16,000,000', '$5,400,000', '$150,000,000',
#        '$4,200,000', '$22,000,000', '$52,000,000', '$1,100,000',
#        '$118,000,000', '$1,600,000', '$18,500,000', '$70,000,000,000',
#        '$800,000,000', '$400,000,000', '$150,000', '$176,000,000',
#        '$60,000,000', '$470,000', '$240,000', '$3,000,000,000',
#        '$74,000,000', '$62,000,000', '$2,100,000', '$500,000,000',
#        '$12,500,000', '$2,200,000,000', '$5,060,000', '$225,000,000',
#        '$24,700,000', '$7,700,000', '$1,90,67,328', '$51,000,000',
#        '$115,000', '$54,000', '$20,000', '$803,146', '$238,000',
#        '$10,220,000', '$1,020,000', '$12,000,000', '$13,400,000',
#        '$170,000,000', '$2,900,000', '$543,000', '$90,000,000',
#        '$3,400,000', '$23,000,000', '$8,090,000', '$1,030,000',
#        '$5,040,000', '$360,000', '$1,400,000', '$650,000', '$54,000,000',
#        '$42,500,000', '$11,370,000', '$325,000', '$410,000', '$450,000',
#        '$682,000', '$4,050,000', '$1,050,000', '$1,080,000', '$4,300,000',
#        '$6,800,000', '$2,110,000', '$887,000, $23,000,000', '$764,000',
#        '$603,000', '$409,000', '$292,000', '$286,000', '$136,000',
#        '$800,000,000 to $850,000,000', '$546,000', '$887,000', '$43,000',
#        '$40,900', '$2,200,000', '$5,660,000', '$350,000', '$110,000',
#        '$122,000,000', '$11,635,000', '$2,800,000', '$1,065,000',
#        '$669,000', '$16,076,000', '$649,600', '$6,700,000', '$220,000',
#        '$266,500', '$2,879,000', '$26,500,000', '$351,000', '$ 8,700,000',
#        '$46,761,000', '$175,000', '9.600,000', '$11,241,000', '$804,000',
#        '$1,340,000', '$467,000', '$133,000', '$3,823,000', '$934,000',
#        '$293,000', '$198,000', '$927,000', '$971,000', '$3,060,000',
#        '$1,862,000', '$232,000', '$2,888,000', '$1,328,000',
#        '$15,500,000', '$56,000,000', '$2,250,000', '$16,753,000',
#        '$3,700,000', '$1,470,000', '$530,000', '$267,000', '$3,344,000',
#        '$7,200,000', '$2,743,000', '$6,082,000', '$6,609,000',
#        '$27,700,000', '$5,940,000', '$3,964,000', '$5,500,000',
#        '$197,000', '$4,327,000', '$459,000', '$3,937,000', '$1,313,500',
#        '$229,800', '$5,305,000', '$264,000', '$1,750,000', '$5,967,000',
#        '$2,980,000', '$323,000', '$1,326,000', '$27,000,000',
#        '$5,200,000', '$2,530,000', '$792,000', '$11,363,000',
#        '$1,715,000', '$329,000', '$5,271,000', '$8,700,000', '$3,226,000',
#        '$5,900,000', '$44,000,000', '$3,879,000', '$13,000,000',
#        '$8,800,000', '$9,500,000', '$920,000', '$35,600,000',
#        '$9,400,000', '$790,000', '$480,000', '$160,000', '$8,200,000',
#        '$4,257,000', '$1,410,000', '$349,800', '$786,000', '$2,004,000',
#        '$123,000,000', '$248,000', '$24,000,000', '$14,259,000',
#        '$24,500,000', '$3,800,000', '$18,370,000', '$68,525,000',
#        '$4,800,000', '$1,834,000', '$23,850,000', '$43,000,000',
#        '$21,600,000', '$4,598,000', '$13,137,000', '$115,000,000',
#        '$3,900,000', '$670,000', '42.23,000', '$8,500,000', '$3,148,000',
#        '$2,600,000', '25,58,000', '$4,049,500', '$10,500,000',
#        '$6,500,000', '$43,700,000', '$13,800,000', '$306,900', '$420,000',
#        '$627,300', '$113,000,000', '$32,000,000', '$110,000,000',
#        '$1,397,000', '$448,500', '$7,975,700', '$330,000', '$5,600,000',
#        '$1,402,000', '$21,500,000', '$296,000,000', '$4,900,000',
#        '$1,402,400', '$12,618,300', '$9,900,000', '$982,530',
#        '$70,185,200', '$210,000,000', '$84,000,000', '$39,000,000',
#        '$2,700,000', '$1,403,400', '$105,000,000', '$103,000,000',
#        '$281,300', '$12,700', '$25,000', '$97,500,000', '$507,000',
#        '$8,400,000', '$18,300,000', '$125,000,000', '$181,000',
#        '$280,000', '$14,700,000', '$13,200,000', '$8,043,000'],
#       dtype=object)

# %%
# Removing the dollar and commma symbols in the Amount($) column

df3["Amount($)"] = df3["Amount($)"].replace(['\$', ','], '', regex=True)
df3["Amount($)"].unique()
# Out:
# array(['200000', '100000', 0, '400000', '340000', '600000', '45000000',
#        '1000000', '2000000', '1200000', '660000000', '120000', '7500000',
#        '5000000', '500000', '3000000', '10000000', '145000000',
#        '100000000', '21000000', '4000000', '20000000', '560000', '275000',
#        '4500000', '15000000', '390000000', '7000000', '5100000',
#        '700000000', '2300000', '700000', '19000000', '9000000',
#        '40000000', '750000', '1500000', '7800000', '50000000', '80000000',
#        '30000000', '1700000', '2500000', '40000', '33000000', '35000000',
#        '300000', '25000000', '3500000', '200000000', '6000000', '1300000',
#        '4100000', '575000', '800000', '28000000', '18000000', '3200000',
#        '900000', '250000', '4700000', '75000000', '8000000', '121000000',
#        '55000000', '3300000', '11000000', '16000000', '5400000',
#        '150000000', '4200000', '22000000', '52000000', '1100000',
#        '118000000', '1600000', '18500000', '70000000000', '800000000',
#        '400000000', '150000', '176000000', '60000000', '470000', '240000',
#        '3000000000', '74000000', '62000000', '2100000', '500000000',
#        '12500000', '2200000000', '5060000', '225000000', '24700000',
#        '7700000', '19067328', '51000000', '115000', '54000', '20000',
#        '803146', '238000', '10220000', '1020000', '12000000', '13400000',
#        '170000000', '2900000', '543000', '90000000', '3400000',
#        '23000000', '8090000', '1030000', '5040000', '360000', '1400000',
#        '650000', '54000000', '42500000', '11370000', '325000', '410000',
#        '450000', '682000', '4050000', '1050000', '1080000', '4300000',
#        '6800000', '2110000', '887000 23000000', '764000', '603000',
#        '409000', '292000', '286000', '136000', '800000000 to 850000000',
#        '546000', '887000', '43000', '40900', '2200000', '5660000',
#        '350000', '110000', '122000000', '11635000', '2800000', '1065000',
#        '669000', '16076000', '649600', '6700000', '220000', '266500',
#        '2879000', '26500000', '351000', ' 8700000', '46761000', '175000',
#        '9.600000', '11241000', '804000', '1340000', '467000', '133000',
#        '3823000', '934000', '293000', '198000', '927000', '971000',
#        '3060000', '1862000', '232000', '2888000', '1328000', '15500000',
#        '56000000', '2250000', '16753000', '3700000', '1470000', '530000',
#        '267000', '3344000', '7200000', '2743000', '6082000', '6609000',
#        '27700000', '5940000', '3964000', '5500000', '197000', '4327000',
#        '459000', '3937000', '1313500', '229800', '5305000', '264000',
#        '1750000', '5967000', '2980000', '323000', '1326000', '27000000',
#        '5200000', '2530000', '792000', '11363000', '1715000', '329000',
#        '5271000', '8700000', '3226000', '5900000', '44000000', '3879000',
#        '13000000', '8800000', '9500000', '920000', '35600000', '9400000',
#        '790000', '480000', '160000', '8200000', '4257000', '1410000',
#        '349800', '786000', '2004000', '123000000', '248000', '24000000',
#        '14259000', '24500000', '3800000', '18370000', '68525000',
#        '4800000', '1834000', '23850000', '43000000', '21600000',
#        '4598000', '13137000', '115000000', '3900000', '670000',
#        '42.23000', '8500000', '3148000', '2600000', '2558000', '4049500',
#        '10500000', '6500000', '43700000', '13800000', '306900', '420000',
#        '627300', '113000000', '32000000', '110000000', '1397000',
#        '448500', '7975700', '330000', '5600000', '1402000', '21500000',
#        '296000000', '4900000', '1402400', '12618300', '9900000', '982530',
#        '70185200', '210000000', '84000000', '39000000', '2700000',
#        '1403400', '105000000', '103000000', '281300', '12700', '25000',
#        '97500000', '507000', '8400000', '18300000', '125000000', '181000',
#        '280000', '14700000', '13200000', '8043000'], dtype=object)

# %% [markdown]
# At this point, the "Amount($)" column datatype could still not be converted to integer because of the presence of non-integer values. There is need to identify these non-integer values. To do this, a boolean mask will be created to identify the non-integer values. This boolean mask will be used to create a new DataFrame with only the non-integer values. Before creating the boolean mask, the entire column will first be converted to a string to ensure a more accurate DataFrame result.

# %%
# Creating a boolean mask to identify non-integer values in Amount($) column
non_int_mask = df3["Amount($)"].apply(lambda x: not str(x).isdigit())

# Creating a new DataFrame with only the non-integer values
non_int_df3_amounts = df3[non_int_mask]
non_int_df3_amounts
# Out:
#           Company/Brand HeadQuarter           Sector               Amount($)
# 465        True Balance    Gurugram          Finance         887000 23000000
# 472            Eruditus      Mumbai        Education  800000000 to 850000000
# 548              BulBul     Gurgaon  Social commerce                 8700000
# 552  SATYA Microcapital       Delhi          Fintech                9.600000
# 834          Peel Works      Mumbai             SaaS                42.23000

# %% [markdown]
# Having identified the non-integer values, they will be worked on and changed to integer values.

# %%
# Replacing the amounts "887000 23000000" and 800000000 to 850000000 with their avaerage respectively

df3["Amount($)"].replace("887000 23000000", np.mean([887000, 23000000]), inplace = True, regex=True)
df3["Amount($)"].replace("800000000 to 850000000", np.mean([800000000, 850000000]), inplace = True, regex=True)

# %%
# Checking the datatype of 8700000 in Amount($)

type(df3["Amount($)"][548]) # 8700000 has a row header of 548
# Out:
# str

# %% [markdown]
# Since the datatype of 8700000 is a string, it will be converted to an integer easily when converting the entire column to integer.

# %%
# Removing the decimal points in 9.600000 and 42.23000

df3['Amount($)'].replace('9.600000','9600000', inplace= True,regex=True)
df3['Amount($)'].replace('42.23000','4223000',inplace =True, regex=True)

# %%
# Converting the datatype of the Amount($) column to integer

df3["Amount($)"] = df3["Amount($)"].astype("int64")
df3["Amount($)"].unique()
# Out:
# array([     200000,      100000,           0,      400000,      340000,
#             600000,    45000000,     1000000,     2000000,     1200000,
#          660000000,      120000,     7500000,     5000000,      500000,
#            3000000,    10000000,   145000000,   100000000,    21000000,
#            4000000,    20000000,      560000,      275000,     4500000,
#           15000000,   390000000,     7000000,     5100000,   700000000,
#            2300000,      700000,    19000000,     9000000,    40000000,
#             750000,     1500000,     7800000,    50000000,    80000000,
#           30000000,     1700000,     2500000,       40000,    33000000,
#           35000000,      300000,    25000000,     3500000,   200000000,
#            6000000,     1300000,     4100000,      575000,      800000,
#           28000000,    18000000,     3200000,      900000,      250000,
#            4700000,    75000000,     8000000,   121000000,    55000000,
#            3300000,    11000000,    16000000,     5400000,   150000000,
#            4200000,    22000000,    52000000,     1100000,   118000000,
#            1600000,    18500000, 70000000000,   800000000,   400000000,
#             150000,   176000000,    60000000,      470000,      240000,
#         3000000000,    74000000,    62000000,     2100000,   500000000,
#           12500000,  2200000000,     5060000,   225000000,    24700000,
#            7700000,    19067328,    51000000,      115000,       54000,
#              20000,      803146,      238000,    10220000,     1020000,
#           12000000,    13400000,   170000000,     2900000,      543000,
#           90000000,     3400000,    23000000,     8090000,     1030000,
#            5040000,      360000,     1400000,      650000,    54000000,
#           42500000,    11370000,      325000,      410000,      450000,
#             682000,     4050000,     1050000,     1080000,     4300000,
#            6800000,     2110000,    11943500,      764000,      603000,
#             409000,      292000,      286000,      136000,   825000000,
#             546000,      887000,       43000,       40900,     2200000,
#            5660000,      350000,      110000,   122000000,    11635000,
#            2800000,     1065000,      669000,    16076000,      649600,
#            6700000,      220000,      266500,     2879000,    26500000,
#             351000,     8700000,    46761000,      175000,     9600000,
#           11241000,      804000,     1340000,      467000,      133000,
#            3823000,      934000,      293000,      198000,      927000,
#             971000,     3060000,     1862000,      232000,     2888000,
#            1328000,    15500000,    56000000,     2250000,    16753000,
#            3700000,     1470000,      530000,      267000,     3344000,
#            7200000,     2743000,     6082000,     6609000,    27700000,
#            5940000,     3964000,     5500000,      197000,     4327000,
#             459000,     3937000,     1313500,      229800,     5305000,
#             264000,     1750000,     5967000,     2980000,      323000,
#            1326000,    27000000,     5200000,     2530000,      792000,
#           11363000,     1715000,      329000,     5271000,     3226000,
#            5900000,    44000000,     3879000,    13000000,     8800000,
#            9500000,      920000,    35600000,     9400000,      790000,
#             480000,      160000,     8200000,     4257000,     1410000,
#             349800,      786000,     2004000,   123000000,      248000,
#           24000000,    14259000,    24500000,     3800000,    18370000,
#           68525000,     4800000,     1834000,    23850000,    43000000,
#           21600000,     4598000,    13137000,   115000000,     3900000,
#             670000,     4223000,     8500000,     3148000,     2600000,
#            2558000,     4049500,    10500000,     6500000,    43700000,
#           13800000,      306900,      420000,      627300,   113000000,
#           32000000,   110000000,     1397000,      448500,     7975700,
#             330000,     5600000,     1402000,    21500000,   296000000,
#            4900000,     1402400,    12618300,     9900000,      982530,
#           70185200,   210000000,    84000000,    39000000,     2700000,
#            1403400,   105000000,   103000000,      281300,       12700,
#              25000,    97500000,      507000,     8400000,    18300000,
#          125000000,      181000,      280000,    14700000,    13200000,
#            8043000], dtype=int64)

# %%
# Evaluating the entire dataset

df3.head()
# Out:
#   Company/Brand HeadQuarter              Sector  Amount($)
# 0    Aqgromalin     Chennai            AgriTech     200000
# 1      Krayonnz   Bengaluru              EdTech     100000
# 2  PadCare Labs        Pune  Hygiene management          0
# 3         NCOME   New Delhi              Escrow     400000
# 4    Gramophone      Indore            AgriTech     340000

# %%
# Confirming that there are no empty cells

df3.isna().sum()
# Out:
# Company/Brand    0
# HeadQuarter      0
# Sector           0
# Amount($)        0
# dtype: int64

# %% [markdown]
# There are no empty cells in our dateset, and the columns have been inspected and cleaned.
#
# Next is to add the "Funding Year" column.

# %%
# Creating a new column named "Funding Year" and filling it with 2020

df3["Funding Year"] = 2020
df3.head()
# Out:
#   Company/Brand HeadQuarter              Sector  Amount($)  Funding Year
# 0    Aqgromalin     Chennai            AgriTech     200000          2020
# 1      Krayonnz   Bengaluru              EdTech     100000          2020
# 2  PadCare Labs        Pune  Hygiene management          0          2020
# 3         NCOME   New Delhi              Escrow     400000          2020
# 4    Gramophone      Indore            AgriTech     340000          2020

# %% [markdown]
# # Cleaning the fourth data set

# %%
# Evaluating the fourth dataset

df4.head()
# Out:
#     Company/Brand  Founded HeadQuarter          Sector
# 0  Unbox Robotics   2019.0   Bangalore      AI startup  \
# 1          upGrad   2015.0      Mumbai          EdTech
# 2     Lead School   2012.0      Mumbai          EdTech
# 3         Bizongo   2015.0      Mumbai  B2B E-commerce
# 4        FypMoney   2021.0    Gurugram         FinTech
#
#                                         What it does
# 0  Unbox Robotics builds on-demand AI-driven ware...  \
# 1     UpGrad is an online higher education platform.
# 2  LEAD School offers technology based school tra...
# 3  Bizongo is a business-to-business online marke...
# 4  FypMoney is Digital NEO Bank for Teenagers, em...
#
#                                             Founders
# 0                        Pramod Ghadge, Shahid Memon  \
# 1  Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                         Smita Deorah, Sumeet Mehta
# 3            Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                      Kapil Banwari
#
#                                         Investor     Amount($)         Stage
# 0                    BEENEXT, Entrepreneur First    $1,200,000  Pre-series A
# 1       Unilazer Ventures, IIFL Asset Management  $120,000,000           NaN
# 2               GSV Ventures, Westbridge Capital   $30,000,000      Series D
# 3                         CDC Group, IDG Capital   $51,000,000      Series C
# 4  Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000          Seed

# %%
# Dropping the "Founded", "What it does", "Founders", "Investor" and "Stage" columns

df4 = df4.drop(["Founded", "What it does", "Founders", "Investor", "Stage"], axis =1)
df4.head()
# Out:
#     Company/Brand HeadQuarter          Sector     Amount($)
# 0  Unbox Robotics   Bangalore      AI startup    $1,200,000
# 1          upGrad      Mumbai          EdTech  $120,000,000
# 2     Lead School      Mumbai          EdTech   $30,000,000
# 3         Bizongo      Mumbai  B2B E-commerce   $51,000,000
# 4        FypMoney    Gurugram         FinTech    $2,000,000

# %%
# Checking the cell values

df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1209 non-null   object
#  1   HeadQuarter    1208 non-null   object
#  2   Sector         1209 non-null   object
#  3   Amount($)      1206 non-null   object
# dtypes: object(4)
# memory usage: 37.9+ KB

# %%
# Confirming the number of empty cells

df4.isna().sum()
# Out:
# Company/Brand    0
# HeadQuarter      1
# Sector           0
# Amount($)        3
# dtype: int64

# %% [markdown]
# The "HeadQuarter" column has one empty cell which will be filled with N/A when inspecting the column. While the Amount($) column has three empty cells which will be filled with zero when inspecting the column.

# %%
# Checking for duplicate rows

df4.duplicated().sum()
# Out:
# 31

# %% [markdown]
# The dataset has thirty-one duplicate rows

# %%
# Dropping the duplicate row

df4 = df4.drop_duplicates()

# Confirming that the duplicate rows have been dropped

df4.duplicated().sum()
# Out:
# 0

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1178 entries, 0 to 1208
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1178 non-null   object
#  1   HeadQuarter    1177 non-null   object
#  2   Sector         1178 non-null   object
#  3   Amount($)      1175 non-null   object
# dtypes: object(4)
# memory usage: 46.0+ KB

# %% [markdown]
# After dropping the duplicate rows, the number of rows reduced from 1209 to 1178.

# %% [markdown]
# # Checking the data quality

# %%
# Inspecting the "Company/Brand" column

df4["Company/Brand"].unique()
# Out:
# array(['Unbox Robotics', 'upGrad', 'Lead School', ..., 'Gigforce',
#        'Vahdam', 'WeRize'], dtype=object)

# %%
# Inspecting the "HeadQuarter" column

df4["HeadQuarter"].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurugram', 'New Delhi', 'Hyderabad',
#        'Jaipur', 'Ahmadabad', 'Chennai', nan,
#        'Small Towns, Andhra Pradesh', 'Goa', 'Rajsamand', 'Ranchi',
#        'Faridabad, Haryana', 'Gujarat', 'Pune', 'Thane', 'Computer Games',
#        'Cochin', 'Noida', 'Chandigarh', 'Gurgaon', 'Vadodara',
#        'Food & Beverages', 'Pharmaceuticals\t#REF!', 'Gurugram\t#REF!',
#        'Kolkata', 'Ahmedabad', 'Mohali', 'Haryana', 'Indore', 'Powai',
#        'Ghaziabad', 'Nagpur', 'West Bengal', 'Patna', 'Samsitpur',
#        'Lucknow', 'Telangana', 'Silvassa', 'Thiruvananthapuram',
#        'Faridabad', 'Roorkee', 'Ambernath', 'Panchkula', 'Surat',
#        'Coimbatore', 'Andheri', 'Mangalore', 'Telugana', 'Bhubaneswar',
#        'Kottayam', 'Beijing', 'Panaji', 'Satara', 'Orissia', 'Jodhpur',
#        'New York', 'Santra', 'Mountain View, CA', 'Trivandrum',
#        'Jharkhand', 'Kanpur', 'Bhilwara', 'Guwahati',
#        'Online Media\t#REF!', 'Kochi', 'London',
#        'Information Technology & Services', 'The Nilgiris', 'Gandhinagar'],
#       dtype=object)

# %%
# Filling the empty cells in the "HeadQuarter" column with N/A

df4["HeadQuarter"]= df4["HeadQuarter"].fillna('N/A')
df4["HeadQuarter"].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurugram', 'New Delhi', 'Hyderabad',
#        'Jaipur', 'Ahmadabad', 'Chennai', 'N/A',
#        'Small Towns, Andhra Pradesh', 'Goa', 'Rajsamand', 'Ranchi',
#        'Faridabad, Haryana', 'Gujarat', 'Pune', 'Thane', 'Computer Games',
#        'Cochin', 'Noida', 'Chandigarh', 'Gurgaon', 'Vadodara',
#        'Food & Beverages', 'Pharmaceuticals\t#REF!', 'Gurugram\t#REF!',
#        'Kolkata', 'Ahmedabad', 'Mohali', 'Haryana', 'Indore', 'Powai',
#        'Ghaziabad', 'Nagpur', 'West Bengal', 'Patna', 'Samsitpur',
#        'Lucknow', 'Telangana', 'Silvassa', 'Thiruvananthapuram',
#        'Faridabad', 'Roorkee', 'Ambernath', 'Panchkula', 'Surat',
#        'Coimbatore', 'Andheri', 'Mangalore', 'Telugana', 'Bhubaneswar',
#        'Kottayam', 'Beijing', 'Panaji', 'Satara', 'Orissia', 'Jodhpur',
#        'New York', 'Santra', 'Mountain View, CA', 'Trivandrum',
#        'Jharkhand', 'Kanpur', 'Bhilwara', 'Guwahati',
#        'Online Media\t#REF!', 'Kochi', 'London',
#        'Information Technology & Services', 'The Nilgiris', 'Gandhinagar'],
#       dtype=object)

# %%
# Replacing 'Small Towns, Andhra Pradesh' with 'Andhra Pradesh'

df4["HeadQuarter"] = df4["HeadQuarter"].replace('Small Towns, Andhra Pradesh', 'Andhra Pradesh', regex=True)
df4["HeadQuarter"].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurugram', 'New Delhi', 'Hyderabad',
#        'Jaipur', 'Ahmadabad', 'Chennai', 'N/A', 'Andhra Pradesh', 'Goa',
#        'Rajsamand', 'Ranchi', 'Faridabad, Haryana', 'Gujarat', 'Pune',
#        'Thane', 'Computer Games', 'Cochin', 'Noida', 'Chandigarh',
#        'Gurgaon', 'Vadodara', 'Food & Beverages',
#        'Pharmaceuticals\t#REF!', 'Gurugram\t#REF!', 'Kolkata',
#        'Ahmedabad', 'Mohali', 'Haryana', 'Indore', 'Powai', 'Ghaziabad',
#        'Nagpur', 'West Bengal', 'Patna', 'Samsitpur', 'Lucknow',
#        'Telangana', 'Silvassa', 'Thiruvananthapuram', 'Faridabad',
#        'Roorkee', 'Ambernath', 'Panchkula', 'Surat', 'Coimbatore',
#        'Andheri', 'Mangalore', 'Telugana', 'Bhubaneswar', 'Kottayam',
#        'Beijing', 'Panaji', 'Satara', 'Orissia', 'Jodhpur', 'New York',
#        'Santra', 'Mountain View, CA', 'Trivandrum', 'Jharkhand', 'Kanpur',
#        'Bhilwara', 'Guwahati', 'Online Media\t#REF!', 'Kochi', 'London',
#        'Information Technology & Services', 'The Nilgiris', 'Gandhinagar'],
#       dtype=object)

# %% [markdown]
# Some cell values are inappropriate for the "HeadQuarter" column. This will be handled by examining the rows involved.

# %%
# Identifying the rows that have 'Computer Games' on the "HeadQuarter" Column

df4.loc[df4["HeadQuarter"] == 'Computer Games']
# Out:
#    Company/Brand     HeadQuarter          Sector Amount($)
# 98       FanPlay  Computer Games  Computer Games  Upsparks

# %% [markdown]
# This row does not have accurate information on the columns. Having previously dropped some columns on the dataset, it is important to reload the original dataset with a different variable name to see all the information on this row for all the original columns.

# %%
# loading the original dataset using a different variable name

ddf4 = pd.read_csv('startup_funding2021.csv')

# %%
# Finding the row on the original dataset with 'Computer Games' in the "HeadQuarters" column

ddf4.loc[ddf4["HeadQuarter"] == 'Computer Games']
# Out:
#     Company/Brand  Founded     HeadQuarter          Sector
# 98        FanPlay   2020.0  Computer Games  Computer Games  \
# 111       FanPlay   2020.0  Computer Games  Computer Games
#
#                                           What it does Founders
# 98   A real money game app specializing in trivia g...   YC W21  \
# 111  A real money game app specializing in trivia g...   YC W21
#
#                         Investor Amount($)     Stage
# 98   Pritesh Kumar, Bharat Gupta  Upsparks  $1200000
# 111  Pritesh Kumar, Bharat Gupta  Upsparks  $1200000

# %% [markdown]
# This row is one of the duplicated rows, and the duplicate row had been dropped.
#
# The "HeadQuarter" value is unknown and will be filled with 'N/A'. The "Sector" value is 'Computer Games', while the Amount value is $1200000.

# %%
# Filling in the correct values in the row with 'Computer Games' in the "HeadQuarters" column

df4.loc[df4["Company/Brand"] == "FanPlay", ["HeadQuarter","Amount($)"]] = ['N/A','$1200000',]
df4.loc[df4["Company/Brand"] == "FanPlay"]
# Out:
#    Company/Brand HeadQuarter          Sector Amount($)
# 98       FanPlay         N/A  Computer Games  $1200000

# %%
# Identifying the rows that have 'Food & Beverages' on the "HeadQuarter" Column

df4.loc[df4["HeadQuarter"] == 'Food & Beverages']
# Out:
#     Company/Brand       HeadQuarter     Sector Amount($)
# 241    MasterChow  Food & Beverages  Hauz Khas   $461000

# %% [markdown]
# The "HeadQuarter" value is 'Hauz Khas'. While the "Sector" value is 'Food & Beverages'.

# %%
# Filling in the correct values for the "HeadQuarters" column and the "Sector" column

df4.loc[df4["Company/Brand"] == "MasterChow", ['HeadQuarter',"Sector"]] = ['Hauz Khas','Food & Beverages']
df4.loc[df4["Company/Brand"] == "MasterChow"]
# Out:
#     Company/Brand HeadQuarter            Sector Amount($)
# 241    MasterChow   Hauz Khas  Food & Beverages   $461000

# %%
# Identifying the rows that have 'Pharmaceuticals\t#REF!' on the "HeadQuarter" Column

df4.loc[df4["HeadQuarter"] == 'Pharmaceuticals\t#REF!']
# Out:
#           Company/Brand             HeadQuarter
# 242  Fullife Healthcare  Pharmaceuticals\t#REF!  \
#
#                                                 Sector Amount($)
# 242  Primary Business is Development and Manufactur...  Series C

# %%
# Finding the row on the original dataset with 'Pharmaceuticals\t#REF!' in the "HeadQuarters" column

ddf4.loc[ddf4["HeadQuarter"] == 'Pharmaceuticals\t#REF!']
# Out:
#           Company/Brand  Founded             HeadQuarter
# 242  Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!  \
# 256  Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
#
#                                                 Sector  What it does
# 242  Primary Business is Development and Manufactur...  Varun Khanna  \
# 256  Primary Business is Development and Manufactur...  Varun Khanna
#
#                                Founders   Investor Amount($) Stage
# 242  Morgan Stanley Private Equity Asia  $22000000  Series C   NaN
# 256  Morgan Stanley Private Equity Asia  $22000000  Series C   NaN

# %% [markdown]
# This row is one of the duplicated rows, and the duplicate row had been dropped.
#
# The "HeadQuarter" value is unknown and will be filled with 'N/A'. The "Sector" value is 'Pharmaceuticals', while the Amount value is $22000000.

# %%
# Filling in the correct values in the row with 'Pharmaceuticals\t#REF!' in the "HeadQuarters" column

df4.loc[df4["Company/Brand"] == "Fullife Healthcare", ["HeadQuarter", "Sector", "Amount($)"]] = ['N/A', 'Pharmaceuticals', '$22000000',]
df4.loc[df4["Company/Brand"] == "Fullife Healthcare"]
# Out:
#           Company/Brand HeadQuarter           Sector  Amount($)
# 242  Fullife Healthcare         N/A  Pharmaceuticals  $22000000

# %%
# Identifying the rows that have 'Gurugram\t#REF!' on the "HeadQuarter" Column

df4.loc[df4["HeadQuarter"] == 'Gurugram\t#REF!']
# Out:
#     Company/Brand      HeadQuarter
# 257       MoEVing  Gurugram\t#REF!  \
#
#                                                 Sector Amount($)
# 257  MoEVing is India's only Electric Mobility focu...      Seed

# %%
# Finding the row on the original dataset with 'Gurugram\t#REF!' in the "HeadQuarters" column

ddf4.loc[ddf4["HeadQuarter"] == 'Gurugram\t#REF!']
# Out:
#     Company/Brand  Founded      HeadQuarter
# 257       MoEVing   2021.0  Gurugram\t#REF!  \
#
#                                                 Sector
# 257  MoEVing is India's only Electric Mobility focu...  \
#
#                     What it does
# 257  Vikash Mishra, Mragank Jain  \
#
#                                            Founders  Investor Amount($) Stage
# 257  Anshuman Maheshwary, Dr Srihari Raju Kalidindi  $5000000      Seed   NaN

# %% [markdown]
# The "HeadQuarter" value is 'Gurugram', the "Sector" value is unknown and will be filled with 'N/A' and the "Amount" column value is $5000000.

# %%
# Filling in the correct values in the row with 'Gurugram\t#REF!' in the "HeadQuarters" column

df4.loc[df4["Company/Brand"] == "MoEVing", ["HeadQuarter", "Sector", "Amount($)"]] = ['Gurugram',  'N/A', ' $5000000']
df4.loc[df4["Company/Brand"] == "MoEVing"]
# Out:
#     Company/Brand HeadQuarter Sector  Amount($)
# 257       MoEVing    Gurugram    N/A   $5000000

# %%
# Identifying the rows that have 'Online Media\t#REF!' on the "HeadQuarter" Column

df4.loc[df4["HeadQuarter"] == 'Online Media\t#REF!']
# Out:
#      Company/Brand          HeadQuarter
# 1100      Sochcast  Online Media\t#REF!  \
#
#                                                  Sector Amount($)
# 1100  Sochcast is an Audio experiences company that ...       NaN

# %%
# Finding the row on the original dataset with 'Online Media\t#REF!' in the "HeadQuarters" column

ddf4.loc[ddf4["HeadQuarter"] == 'Online Media\t#REF!']
# Out:
#      Company/Brand  Founded          HeadQuarter
# 1100      Sochcast   2020.0  Online Media\t#REF!  \
#
#                                                  Sector
# 1100  Sochcast is an Audio experiences company that ...  \
#
#                                            What it does
# 1100  CA Harvinderjit Singh Bhatia, Garima Surana, A...  \
#
#                                      Founders      Investor Amount($) Stage
# 1100  Vinners, Raj Nayak, Amritaanshu Agrawal  $Undisclosed       NaN   NaN

# %% [markdown]
# The "HeadQuarter" value is unknown and will be filled with 'N/A', the "Sector" value is Online Media, and the "Amount" column value is undisclosed and will be filled with zero

# %%
# Filling in the correct values in the row with 'Online Media\t#REF!' in the "HeadQuarters" column

df4.loc[df4["Company/Brand"] == "Sochcast", ["HeadQuarter", "Sector", "Amount($)"]] = ['N/A',  ' Online Media', '0']
df4.loc[df4["Company/Brand"] == "Sochcast"]
# Out:
#      Company/Brand HeadQuarter         Sector Amount($)
# 1100      Sochcast         N/A   Online Media         0

# %%
# Identifying the rows that have 'Information Technology & Services' on the "HeadQuarter" Column

df4.loc[df4["HeadQuarter"] == 'Information Technology & Services']
# Out:
#      Company/Brand                        HeadQuarter
# 1176          Peak  Information Technology & Services  \
#
#                               Sector  Amount($)
# 1176  Manchester, Greater Manchester  $75000000

# %%
# Filling in the correct values in the row with 'Computer Games' in the "HeadQuarters" column

df4.loc[df4["Company/Brand"] == "Peak", ["HeadQuarter","Sector"]] = ['Manchester','Information Technology & Services']
df4.loc[df4["Company/Brand"] == "Peak"]
# Out:
#      Company/Brand HeadQuarter                             Sector  Amount($)
# 1176          Peak  Manchester  Information Technology & Services  $75000000

# %%
# Inspecting the "HeadQuarter" column again

df4["HeadQuarter"].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurugram', 'New Delhi', 'Hyderabad',
#        'Jaipur', 'Ahmadabad', 'Chennai', 'N/A', 'Andhra Pradesh', 'Goa',
#        'Rajsamand', 'Ranchi', 'Faridabad, Haryana', 'Gujarat', 'Pune',
#        'Thane', 'Cochin', 'Noida', 'Chandigarh', 'Gurgaon', 'Vadodara',
#        'Hauz Khas', 'Kolkata', 'Ahmedabad', 'Mohali', 'Haryana', 'Indore',
#        'Powai', 'Ghaziabad', 'Nagpur', 'West Bengal', 'Patna',
#        'Samsitpur', 'Lucknow', 'Telangana', 'Silvassa',
#        'Thiruvananthapuram', 'Faridabad', 'Roorkee', 'Ambernath',
#        'Panchkula', 'Surat', 'Coimbatore', 'Andheri', 'Mangalore',
#        'Telugana', 'Bhubaneswar', 'Kottayam', 'Beijing', 'Panaji',
#        'Satara', 'Orissia', 'Jodhpur', 'New York', 'Santra',
#        'Mountain View, CA', 'Trivandrum', 'Jharkhand', 'Kanpur',
#        'Bhilwara', 'Guwahati', 'Kochi', 'London', 'Manchester',
#        'The Nilgiris', 'Gandhinagar'], dtype=object)

# %%
# Replacing Bangalore with Bengaluru

df4["HeadQuarter"] = df4["HeadQuarter"].replace('Bangalore', 'Bengaluru', regex=True)
df4["HeadQuarter"].unique()
# Out:
# array(['Bengaluru', 'Mumbai', 'Gurugram', 'New Delhi', 'Hyderabad',
#        'Jaipur', 'Ahmadabad', 'Chennai', 'N/A', 'Andhra Pradesh', 'Goa',
#        'Rajsamand', 'Ranchi', 'Faridabad, Haryana', 'Gujarat', 'Pune',
#        'Thane', 'Cochin', 'Noida', 'Chandigarh', 'Gurgaon', 'Vadodara',
#        'Hauz Khas', 'Kolkata', 'Ahmedabad', 'Mohali', 'Haryana', 'Indore',
#        'Powai', 'Ghaziabad', 'Nagpur', 'West Bengal', 'Patna',
#        'Samsitpur', 'Lucknow', 'Telangana', 'Silvassa',
#        'Thiruvananthapuram', 'Faridabad', 'Roorkee', 'Ambernath',
#        'Panchkula', 'Surat', 'Coimbatore', 'Andheri', 'Mangalore',
#        'Telugana', 'Bhubaneswar', 'Kottayam', 'Beijing', 'Panaji',
#        'Satara', 'Orissia', 'Jodhpur', 'New York', 'Santra',
#        'Mountain View, CA', 'Trivandrum', 'Jharkhand', 'Kanpur',
#        'Bhilwara', 'Guwahati', 'Kochi', 'London', 'Manchester',
#        'The Nilgiris', 'Gandhinagar'], dtype=object)

# %%
# Inspecting the "Sector" column

df4["Sector"].unique()
# Out:
# array(['AI startup', 'EdTech', 'B2B E-commerce', 'FinTech',
#        'Home services', 'HealthTech', 'Tech Startup', 'E-commerce',
#        'B2B service', 'Helathcare', 'Renewable Energy', 'Electronics',
#        'IT startup', 'Food & Beverages', 'Aeorspace', 'Deep Tech',
#        'Dating', 'Gaming', 'Robotics', 'Retail', 'Food', 'Oil and Energy',
#        'AgriTech', 'Telecommuncation', 'Milk startup', 'AI Chatbot', 'IT',
#        'Logistics', 'Hospitality', 'Fashion', 'Marketing',
#        'Transportation', 'LegalTech', 'Food delivery', 'Automotive',
#        'SaaS startup', 'Fantasy sports', 'Video communication',
#        'Social Media', 'Skill development', 'Rental', 'Recruitment',
#        'HealthCare', 'Sports', 'Computer Games', 'Consumer Goods',
#        'Information Technology', 'Apparel & Fashion',
#        'Logistics & Supply Chain', 'Healthtech', 'Healthcare',
#        'SportsTech', 'HRTech', 'Wine & Spirits',
#        'Mechanical & Industrial Engineering', 'Spiritual',
#        'Financial Services', 'Industrial Automation', 'Health',
#        'Lifestyle', 'IoT', 'Banking', 'Computer software', 'Tech startup',
#        'Digital mortgage', 'Information Technology & Services',
#        'Furniture', 'B2B marketplace', 'Healtcare', 'Location Analytics',
#        'Media', 'Consumer Electronics', 'Tobacco', 'Deeptech',
#        'Insuretech', 'MLOps platform', 'Venture Capital', 'Pet care',
#        'Drone', 'Wholesale', 'Construction', 'E-learning',
#        'Consumer Services', 'Venture Capital & Private Equity',
#        'Health, Wellness & Fitness', 'OTT', 'Education Management',
#        'Computer Software', 'Insurance', 'Software Startup',
#        'Computer & Network Security', 'Capital Markets', 'Social network',
#        'Hospital & Health Care', 'Music', 'Pharmaceuticals', 'N/A',
#        'Cosmetics', 'Mobility', 'Social media', 'Real Estate',
#        'Digital platform', 'B2B Ecommerce', 'Online Media',
#        'Social commerce', 'Mobile Games', 'Food Production', 'Podcast',
#        'HeathTech', 'Battery', 'Content publishing', 'Water purification',
#        'Content commerce', 'Innovation Management', 'Software company',
#        'Automation', 'Food Industry', 'Celebrity Engagement',
#        'Trading platform', 'Personal Care', 'Cannabis startup',
#        'Blogging', 'Consulting', 'BioTechnology', 'B2B Marketplace',
#        'Health care', 'Social audio', 'Fashion and lifestyle',
#        'Delivery service', 'B2B Manufacturing', 'Home Decor', 'Solar',
#        'TaaS startup', 'EV startup', 'HR Tech', 'Blockchain startup',
#        'Food and Beverages', 'Beverages', 'Manufacturing startup',
#        'Cryptocurrency', 'Vehicle repair startup', 'Advisory firm',
#        'Legaltech', 'Pollution control equiptment', 'Fashion & Lifestyle',
#        'Blockchain', 'Fitness', 'D2C', 'Automobile',
#        'Environmental Services', 'Merchandise', 'Facilities Services',
#        'Marketing & Advertising', 'Human Resources', 'Eyewear',
#        'D2C Business', 'Biotechnology', 'Farming', 'NFT Marketplace',
#        'Internet', 'SpaceTech', 'Consumer software', 'Social community',
#        'Fishery', 'Renewables & Environment', 'Online storytelling',
#        'Aviation', 'IT company', 'Environmental service',
#        'Job discovery platform', 'D2C Fashion', 'Heathcare', 'CRM',
#        'Software', 'Nutrition', 'D2C startup', 'Innovation management',
#        'Community platform', 'Venture capitalist', 'Networking',
#        'Commercial Real Estate', 'AR startup', 'Consumer service',
#        'Consumer goods', 'MarTech', 'Advertisement', 'Content creation',
#        'Augmented reality', 'Rental space', 'Bike Rental',
#        'Beauty products', 'Tourism', 'FemTech', 'Cultural', 'Co-working',
#        'InsureTech', 'Supply chain platform', 'Social platform',
#        'CleanTech', 'Real estate', 'AI company', 'Sports startup',
#        'Matrimony', 'Crypto', 'Clothing', 'Analytics', 'Finance',
#        'IoT platform', 'Commerce', 'Defense & Space', 'Entertainment',
#        'Business Supplies & Equipment', 'NFT', 'Oil & Energy', 'EV',
#        'Company-as-a-Service', 'Textiles',
#        'Professional Training & Coaching', 'Maritime',
#        'Housing Marketplace', 'Furniture Rental', 'Telecommunications',
#        'Equity Management', 'Cloud kitchen', 'Nanotechnology',
#        'Community', 'Higher Education', 'B2B',
#        'Mechanical Or Industrial Engineering', 'D2C jewellery',
#        'Sales and Distribution', 'SaaS', 'Information Services',
#        'Translation & Localization', 'Investment Banking', 'Femtech',
#        'sports', 'Foootwear', 'Legal Services', 'Veterinary',
#        'Arts & Crafts', 'Investment Management', 'Education',
#        'Management Consulting', 'B2B startup', ' Online Media', 'Design',
#        'B2B Travel', 'Interior Design', 'Product studio',
#        'Aviation & Aerospace', 'Staffing & Recruiting'], dtype=object)

# %%
# Replacing Helathcare with Healthcare

df4["Sector"] = df4["Sector"].replace('Helathcare', 'Healthcare', regex=True)

# %%
# Replacing Aeorspace with Aerospace

df4["Sector"] = df4["Sector"].replace('Aeorspace', 'Aerospace', regex=True)

# %%
# Inspecting the "Amount($)" column

df4["Amount($)"].unique()
# Out:
# array(['$1,200,000', '$120,000,000', '$30,000,000', '$51,000,000',
#        '$2,000,000', '$188,000,000', '$200,000', 'Undisclosed',
#        '$1,000,000', '$3,000,000', '$100,000', '$700,000', '$9,000,000',
#        '$40,000,000', '$49,000,000', '$400,000', '$300,000',
#        '$25,000,000', '$160,000,000', '$150,000', '$1,800,000',
#        '$5,000,000', '$850,000', '$53,000,000', '$500,000', '$1,100,000',
#        '$6,000,000', '$800,000', '$10,000,000', '$21,000,000',
#        '$7,500,000', '$26,000,000', '$7,400,000', '$1,500,000',
#        '$600,000', '$800,000,000', '$17,000,000', '$3,500,000',
#        '$15,000,000', '$215,000,000', '$2,500,000', '$350,000,000',
#        '$5,500,000', '$83,000,000', '$110,000,000', '$500,000,000',
#        '$65,000,000', '$150,000,000,000', '$300,000,000', '$2,200,000',
#        '$35,000,000', '$140,000,000', '$4,000,000', '$13,000,000', nan,
#        '$Undisclosed', '$2000000', '$800000', '$6000000', '$2500000',
#        '$9500000', '$13000000', '$5000000', '$8000000', '$1000000',
#        '$1200000', '$200000', '$12000000', '$1500000', '$1700000',
#        '$5500000', '$400000', '$150000000', '$4000000', '$100000000',
#        '$500000', '$15000000', '$10000000', '$40000000', '$225000000',
#        '$6700000', '$1300000', '$20000000', '$250000', '$21000000',
#        '$52000000', '$3800000', '$17500000', '$42000000', '$2300000',
#        '$7000000', '$30000000', '$450000000', '$28000000', '$300000',
#        '$3500000', '$8500000', '$25000000', '$3000000', '$37000000',
#        '$370000000', '$700000', '$16000000', '$100000', '$44000000',
#        '$770000', '$125000000', '$35000000', '$50000000', '$4900000',
#        '$145000000', '$22000000', '$70000000', '$6600000', '$32000000',
#        '$24000000', '$725000', '$461000', ' $5000000', '$96000000',
#        '$60000000', '$500000000', '$266000000', '$4500000', '$325000000',
#        '$6500000', '$1600000', '$225000', '$85000000', '$235000',
#        '$260000', '$2900000', '$53000000', '$1100000', '$150000',
#        '$86000000', '$130000', '$$100,00', '$111000000', '$265000',
#        '$76000000', '$100,000,000', '$75,000,000', '$3,800,000',
#        '$12,000,000', '$1,600,000', '$260,000', '$1,000,000,000',
#        '$18,000,000', '$20,000,000', '$350,000', '$95,000,000',
#        '$4,100,000', '$5,200,000', '$8,000,000', '$1,400,000',
#        '$2,600,000', '$900,000', '$250,000', '$16,000,000', '$7,000,000',
#        '$11,000,000', '$50,000,000', '$14,300,000', '$81,000,000',
#        '$1,300,000', '$8,200,000', '$280,000,000', '$70,000,000',
#        '$720,000', '$600000', '$9000000', '$1800000', '$330000',
#        '$undisclosed', '$200000000', '$36000000', '$67000000',
#        '$10200000', '$220000000', '$108000000', '$75000000', '$450000',
#        '$660000000', 'ah! Ventures', '$45000000', '$3200000', '$370000',
#        'Pre-series A', 'ITO Angel Network, LetsVenture', '$48000000',
#        '$3600000', '$11000000', '$192000000', '$65000000', '$1400000',
#        '$1900000', '$41000000', '$144000000', '$5200000', '$270000000',
#        '$140000', '$250000000', '$320000', '$350000000', '$4800000',
#        '$38000000', '$125000', '$26000000', '$64000000', '$620000',
#        '$900000', 'JITO Angel Network, LetsVenture', '$2600000',
#        '$1,250,000', '$400,000,000', '$1,700,000', '$27,000,000',
#        '$234,000,000', '$460,000,000', '$13,500,000', '$5,100,000',
#        '$195,000,000', '$125,000', '$45,000,000', '$200,000,000',
#        '$7,300,000', '$6,300,000', '$12,500,000', '$24,000,000',
#        '$140,000', '$16,500,000', '$340,000', '$43,000,000',
#        '$150,000,000', '$3300000', '$92000000', '$17000000', '$135000000',
#        '$$1,55,000', '$2100000', '$840000000', '$248000000', '$4300000',
#        '$570000', '$2200000', '$4700000', '$300000000', '$260000000',
#        '$140000000', '$175000000', '$19000000', '$810000', '$7500000',
#        '$600000000', '$90000000', '$5700000', '$6750000', '$78000000',
#        '$5400000', '$115000000', '$255000000', '$18000000', '$570000000',
#        '$550000', '$2700000', '$4200000', '0', '$31000000', '$540000',
#        '$14000000', '$340000', '$', '$6200000', 'Seed', '$750000',
#        '$6300000', '$23000000', '$55000000'], dtype=object)

# %%
# Removing the dollar and comma symbols in the Amount($) column

df4["Amount($)"] = df4["Amount($)"].replace(['\$', ','], '', regex=True)
df4["Amount($)"].unique()
# Out:
# array(['1200000', '120000000', '30000000', '51000000', '2000000',
#        '188000000', '200000', 'Undisclosed', '1000000', '3000000',
#        '100000', '700000', '9000000', '40000000', '49000000', '400000',
#        '300000', '25000000', '160000000', '150000', '1800000', '5000000',
#        '850000', '53000000', '500000', '1100000', '6000000', '800000',
#        '10000000', '21000000', '7500000', '26000000', '7400000',
#        '1500000', '600000', '800000000', '17000000', '3500000',
#        '15000000', '215000000', '2500000', '350000000', '5500000',
#        '83000000', '110000000', '500000000', '65000000', '150000000000',
#        '300000000', '2200000', '35000000', '140000000', '4000000',
#        '13000000', nan, '9500000', '8000000', '12000000', '1700000',
#        '150000000', '100000000', '225000000', '6700000', '1300000',
#        '20000000', '250000', '52000000', '3800000', '17500000',
#        '42000000', '2300000', '7000000', '450000000', '28000000',
#        '8500000', '37000000', '370000000', '16000000', '44000000',
#        '770000', '125000000', '50000000', '4900000', '145000000',
#        '22000000', '70000000', '6600000', '32000000', '24000000',
#        '725000', '461000', ' 5000000', '96000000', '60000000',
#        '266000000', '4500000', '325000000', '6500000', '1600000',
#        '225000', '85000000', '235000', '260000', '2900000', '86000000',
#        '130000', '10000', '111000000', '265000', '76000000', '75000000',
#        '1000000000', '18000000', '350000', '95000000', '4100000',
#        '5200000', '1400000', '2600000', '900000', '11000000', '14300000',
#        '81000000', '8200000', '280000000', '720000', '330000',
#        'undisclosed', '200000000', '36000000', '67000000', '10200000',
#        '220000000', '108000000', '450000', '660000000', 'ah! Ventures',
#        '45000000', '3200000', '370000', 'Pre-series A',
#        'ITO Angel Network LetsVenture', '48000000', '3600000',
#        '192000000', '1900000', '41000000', '144000000', '270000000',
#        '140000', '250000000', '320000', '4800000', '38000000', '125000',
#        '64000000', '620000', 'JITO Angel Network LetsVenture', '1250000',
#        '400000000', '27000000', '234000000', '460000000', '13500000',
#        '5100000', '195000000', '7300000', '6300000', '12500000',
#        '16500000', '340000', '43000000', '3300000', '92000000',
#        '135000000', '155000', '2100000', '840000000', '248000000',
#        '4300000', '570000', '4700000', '260000000', '175000000',
#        '19000000', '810000', '600000000', '90000000', '5700000',
#        '6750000', '78000000', '5400000', '115000000', '255000000',
#        '570000000', '550000', '2700000', '4200000', '0', '31000000',
#        '540000', '14000000', '', '6200000', 'Seed', '750000', '23000000',
#        '55000000'], dtype=object)

# %%
# Creating a boolean mask to identify non-integer values in Amount($) column
non_int_mask = df4["Amount($)"].apply(lambda x: not str(x).isdigit())

# Creating a new DataFrame with only the non-integer values
non_int_df4_amounts = df4[non_int_mask]

# %%
# Inspecting the values in the "Amount($)" column of the non-integer DataFrame

non_int_df4_amounts["Amount($)"].unique()
# Out:
# array(['Undisclosed', nan, ' 5000000', 'undisclosed', 'ah! Ventures',
#        'Pre-series A', 'ITO Angel Network LetsVenture',
#        'JITO Angel Network LetsVenture', '', 'Seed'], dtype=object)

# %%
# Replacing 'Undisclosed', 'undisclosed' and '' with zero

df4["Amount($)"] = df4["Amount($)"].replace(['Undisclosed', 'undisclosed', ''], 0, regex=True)

# %%
# Filling the empty cells in the "Amount($)" column with zero

df4["Amount($)"] = df4["Amount($)"].fillna(0)
df4["Amount($)"].unique()
# Out:
# array(['1200000', '120000000', '30000000', '51000000', '2000000',
#        '188000000', '200000', 0, '1000000', '3000000', '100000', '700000',
#        '9000000', '40000000', '49000000', '400000', '300000', '25000000',
#        '160000000', '150000', '1800000', '5000000', '850000', '53000000',
#        '500000', '1100000', '6000000', '800000', '10000000', '21000000',
#        '7500000', '26000000', '7400000', '1500000', '600000', '800000000',
#        '17000000', '3500000', '15000000', '215000000', '2500000',
#        '350000000', '5500000', '83000000', '110000000', '500000000',
#        '65000000', '150000000000', '300000000', '2200000', '35000000',
#        '140000000', '4000000', '13000000', '9500000', '8000000',
#        '12000000', '1700000', '150000000', '100000000', '225000000',
#        '6700000', '1300000', '20000000', '250000', '52000000', '3800000',
#        '17500000', '42000000', '2300000', '7000000', '450000000',
#        '28000000', '8500000', '37000000', '370000000', '16000000',
#        '44000000', '770000', '125000000', '50000000', '4900000',
#        '145000000', '22000000', '70000000', '6600000', '32000000',
#        '24000000', '725000', '461000', ' 5000000', '96000000', '60000000',
#        '266000000', '4500000', '325000000', '6500000', '1600000',
#        '225000', '85000000', '235000', '260000', '2900000', '86000000',
#        '130000', '10000', '111000000', '265000', '76000000', '75000000',
#        '1000000000', '18000000', '350000', '95000000', '4100000',
#        '5200000', '1400000', '2600000', '900000', '11000000', '14300000',
#        '81000000', '8200000', '280000000', '720000', '330000',
#        '200000000', '36000000', '67000000', '10200000', '220000000',
#        '108000000', '450000', '660000000', 'ah! Ventures', '45000000',
#        '3200000', '370000', 'Pre-series A',
#        'ITO Angel Network LetsVenture', '48000000', '3600000',
#        '192000000', '1900000', '41000000', '144000000', '270000000',
#        '140000', '250000000', '320000', '4800000', '38000000', '125000',
#        '64000000', '620000', 'JITO Angel Network LetsVenture', '1250000',
#        '400000000', '27000000', '234000000', '460000000', '13500000',
#        '5100000', '195000000', '7300000', '6300000', '12500000',
#        '16500000', '340000', '43000000', '3300000', '92000000',
#        '135000000', '155000', '2100000', '840000000', '248000000',
#        '4300000', '570000', '4700000', '260000000', '175000000',
#        '19000000', '810000', '600000000', '90000000', '5700000',
#        '6750000', '78000000', '5400000', '115000000', '255000000',
#        '570000000', '550000', '2700000', '4200000', '0', '31000000',
#        '540000', '14000000', '6200000', 'Seed', '750000', '23000000',
#        '55000000'], dtype=object)

# %%
# Replacing ' 5000000' with 5000000

df4["Amount($)"] = df4["Amount($)"].replace(' 5000000', 5000000, regex=True)

# %%
# Identifying the rows that have 'ah! Ventures' on the "Amount($)" Column on the original dataset

ddf4.loc[ddf4["Amount($)"] == 'ah! Ventures']
# Out:
#     Company/Brand  Founded HeadQuarter  Sector
# 538   Little Leap   2020.0   New Delhi  EdTech  \
#
#                             What it does
# 538  Soft Skills that make Smart Leaders  \
#
#                                               Founders      Investor
# 538  Holistic Development Programs for children in ...  Vishal Gupta  \
#
#         Amount($)    Stage
# 538  ah! Ventures  $300000

# %%
# Filling in the correct values in the row with 'ah! Ventures' in the "Amount($)" column of df4

df4.loc[df4["Company/Brand"] == "Little Leap", "Amount($)"] = 300000
df4.loc[df4["Company/Brand"] == "Little Leap"]
# Out:
#     Company/Brand HeadQuarter  Sector Amount($)
# 538   Little Leap   New Delhi  EdTech    300000

# %%
# Identifying the rows that have 'Pre-series A' on the "Amount($)" Column on the original dataset

ddf4.loc[ddf4["Amount($)"] == 'Pre-series A']
# Out:
#     Company/Brand  Founded HeadQuarter  Sector
# 545     AdmitKard   2016.0       Noida  EdTech  \
#
#                                           What it does
# 545  A tech solution for end to end career advisory...  \
#
#                                              Founders  Investor     Amount($)
# 545  Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!  $1000000  Pre-series A  \
#
#     Stage
# 545   NaN

# %%
# Filling in the correct values in the row with 'Pre-series A' in the "Amount($)" column of df4

df4.loc[df4["Company/Brand"] == "AdmitKard", "Amount($)"] = 1000000
df4.loc[df4["Company/Brand"] == "AdmitKard"]
# Out:
#     Company/Brand HeadQuarter  Sector Amount($)
# 545     AdmitKard       Noida  EdTech   1000000

# %%
# Creating another boolean mask to identify the remaining non-integer values in Amount($) column
non_int_mask1 = df4["Amount($)"].apply(lambda x: not str(x).isdigit())

# Creating a new DataFrame with only the non-integer values
non_int_df4_amounts1 = df4[non_int_mask1]
non_int_df4_amounts1
# Out:
#          Company/Brand HeadQuarter                    Sector
# 551              BHyve      Mumbai           Human Resources  \
# 677   Saarthi Pedagogy   Ahmadabad                    EdTech
# 1148         Godamwale      Mumbai  Logistics & Supply Chain
#
#                            Amount($)
# 551    ITO Angel Network LetsVenture
# 677   JITO Angel Network LetsVenture
# 1148                            Seed

# %%
# Identifying the rows that have 'ITO Angel Network LetsVenture' on df4

df4.loc[df4["Amount($)"] == 'ITO Angel Network LetsVenture']
# Out:
#     Company/Brand HeadQuarter           Sector                      Amount($)
# 551         BHyve      Mumbai  Human Resources  ITO Angel Network LetsVenture

# %%
# Identifying the rows that have 'BHyve' on the "Company/Brand" Column on the original dataset

ddf4.loc[ddf4["Company/Brand"] == 'BHyve']
# Out:
#     Company/Brand  Founded HeadQuarter           Sector
# 551         BHyve   2020.0      Mumbai  Human Resources  \
#
#                                           What it does           Founders
# 551  A Future of Work Platform for diffusing Employ...  Backed by 100x.VC  \
#
#                             Investor                       Amount($)    Stage
# 551  Omkar Pandharkame, Ketaki Ogale  ITO Angel Network, LetsVenture  $300000

# %%
# Filling in the correct values in the row with 'ITO Angel Network LetsVenture' in the "Amount($)" column of df4

df4.loc[df4["Company/Brand"] == "BHyve", "Amount($)"] = 300000
df4.loc[df4["Company/Brand"] == "BHyve"]
# Out:
#     Company/Brand HeadQuarter           Sector Amount($)
# 551         BHyve      Mumbai  Human Resources    300000

# %%
# Identifying the rows that have 'JITO Angel Network LetsVenture' on df4

df4.loc[df4["Amount($)"] == 'JITO Angel Network LetsVenture']
# Out:
#         Company/Brand HeadQuarter  Sector                       Amount($)
# 677  Saarthi Pedagogy   Ahmadabad  EdTech  JITO Angel Network LetsVenture

# %%
# Identifying the rows that have 'BHyve' on the "Company/Brand" Column on the original dataset

ddf4.loc[ddf4["Company/Brand"] == 'Saarthi Pedagogy']
# Out:
#         Company/Brand  Founded HeadQuarter  Sector
# 677  Saarthi Pedagogy   2015.0   Ahmadabad  EdTech  \
#
#                                           What it does  Founders
# 677  India's fastest growing Pedagogy company, serv...  Pedagogy  \
#
#            Investor                        Amount($)     Stage
# 677  Sushil Agarwal  JITO Angel Network, LetsVenture  $1000000

# %%
# Filling in the correct values in the row with 'JITO Angel Network LetsVenture' in the "Amount($)" column of df4

df4.loc[df4["Company/Brand"] == "Saarthi Pedagogy", "Amount($)"] = 1000000
df4.loc[df4["Company/Brand"] == "Saarthi Pedagogy"]
# Out:
#         Company/Brand HeadQuarter  Sector Amount($)
# 677  Saarthi Pedagogy   Ahmadabad  EdTech   1000000

# %%
# Identifying the rows that have 'Seed' on the "Amount($)" Column on the original dataset

ddf4.loc[ddf4["Amount($)"] == 'Seed']
# Out:
#      Company/Brand  Founded      HeadQuarter
# 257        MoEVing   2021.0  Gurugram\t#REF!  \
# 1148     Godamwale   2016.0           Mumbai
#
#                                                  Sector
# 257   MoEVing is India's only Electric Mobility focu...  \
# 1148                           Logistics & Supply Chain
#
#                                            What it does
# 257                         Vikash Mishra, Mragank Jain  \
# 1148  Godamwale is tech enabled integrated logistics...
#
#                                             Founders        Investor
# 257   Anshuman Maheshwary, Dr Srihari Raju Kalidindi        $5000000  \
# 1148       Basant Kumar, Vivek Tiwari, Ranbir Nandan  1000000\t#REF!
#
#      Amount($) Stage
# 257       Seed   NaN
# 1148      Seed   NaN

# %%
# Filling in the correct values in the rows with 'Seed' in the "Amount($)" column of df4

df4.loc[df4["Company/Brand"] == "MoEVing", "Amount($)"] = 5000000
df4.loc[df4["Company/Brand"] == "Godamwale", "Amount($)"] = 1000000

# %%
# Converting the datatype of the Amount($) column to integer

df4["Amount($)"] = df4["Amount($)"].astype("int64")
df4["Amount($)"].unique()
# Out:
# array([     1200000,    120000000,     30000000,     51000000,
#             2000000,    188000000,       200000,            0,
#             1000000,      3000000,       100000,       700000,
#             9000000,     40000000,     49000000,       400000,
#              300000,     25000000,    160000000,       150000,
#             1800000,      5000000,       850000,     53000000,
#              500000,      1100000,      6000000,       800000,
#            10000000,     21000000,      7500000,     26000000,
#             7400000,      1500000,       600000,    800000000,
#            17000000,      3500000,     15000000,    215000000,
#             2500000,    350000000,      5500000,     83000000,
#           110000000,    500000000,     65000000, 150000000000,
#           300000000,      2200000,     35000000,    140000000,
#             4000000,     13000000,      9500000,      8000000,
#            12000000,      1700000,    150000000,    100000000,
#           225000000,      6700000,      1300000,     20000000,
#              250000,     52000000,      3800000,     17500000,
#            42000000,      2300000,      7000000,    450000000,
#            28000000,      8500000,     37000000,    370000000,
#            16000000,     44000000,       770000,    125000000,
#            50000000,      4900000,    145000000,     22000000,
#            70000000,      6600000,     32000000,     24000000,
#              725000,       461000,     96000000,     60000000,
#           266000000,      4500000,    325000000,      6500000,
#             1600000,       225000,     85000000,       235000,
#              260000,      2900000,     86000000,       130000,
#               10000,    111000000,       265000,     76000000,
#            75000000,   1000000000,     18000000,       350000,
#            95000000,      4100000,      5200000,      1400000,
#             2600000,       900000,     11000000,     14300000,
#            81000000,      8200000,    280000000,       720000,
#              330000,    200000000,     36000000,     67000000,
#            10200000,    220000000,    108000000,       450000,
#           660000000,     45000000,      3200000,       370000,
#            48000000,      3600000,    192000000,      1900000,
#            41000000,    144000000,    270000000,       140000,
#           250000000,       320000,      4800000,     38000000,
#              125000,     64000000,       620000,      1250000,
#           400000000,     27000000,    234000000,    460000000,
#            13500000,      5100000,    195000000,      7300000,
#             6300000,     12500000,     16500000,       340000,
#            43000000,      3300000,     92000000,    135000000,
#              155000,      2100000,    840000000,    248000000,
#             4300000,       570000,      4700000,    260000000,
#           175000000,     19000000,       810000,    600000000,
#            90000000,      5700000,      6750000,     78000000,
#             5400000,    115000000,    255000000,    570000000,
#              550000,      2700000,      4200000,     31000000,
#              540000,     14000000,      6200000,       750000,
#            23000000,     55000000], dtype=int64)

# %%
# Evaluating the entire dataset

df4.head()
# Out:
#     Company/Brand HeadQuarter          Sector  Amount($)
# 0  Unbox Robotics   Bengaluru      AI startup    1200000
# 1          upGrad      Mumbai          EdTech  120000000
# 2     Lead School      Mumbai          EdTech   30000000
# 3         Bizongo      Mumbai  B2B E-commerce   51000000
# 4        FypMoney    Gurugram         FinTech    2000000

# %%
# Confirming that there are no empty cells

df4.isna().sum()
# Out:
# Company/Brand    0
# HeadQuarter      0
# Sector           0
# Amount($)        0
# dtype: int64

# %% [markdown]
# There are no empty cells in our dateset, and the columns have been inspected and cleaned.
#
# Next is to add the "Funding Year" column.

# %%
# Creating a new column named "Funding Year" and filling it with 2021

df4["Funding Year"] = 2021
df4.head()
# Out:
#     Company/Brand HeadQuarter          Sector  Amount($)  Funding Year
# 0  Unbox Robotics   Bengaluru      AI startup    1200000          2021
# 1          upGrad      Mumbai          EdTech  120000000          2021
# 2     Lead School      Mumbai          EdTech   30000000          2021
# 3         Bizongo      Mumbai  B2B E-commerce   51000000          2021
# 4        FypMoney    Gurugram         FinTech    2000000          2021

# %% [markdown]
# # Merging the datasets

# %%
# Using pd.concat to merge

sets = [df1, df2, df3, df4]
df = pd.concat(sets)
df
# Out:
#         Company/Brand HeadQuarter                 Sector  Amount($)
# 0     Thecollegefever   Bengaluru        Brand Marketing     250000  \
# 1     Happy Cow Dairy      Mumbai            Agriculture     584000
# 2          Myloancare     Gurgaon                 Credit     949000
# 3         Payme India       Noida     Financial Services    2000000
# 4            Eunimart   Hyderabad   E-Commerce Platforms          0
# ...               ...         ...                    ...        ...
# 1204         Gigforce    Gurugram  Staffing & Recruiting    3000000
# 1205           Vahdam   New Delhi       Food & Beverages   20000000
# 1206     Leap Finance   Bengaluru     Financial Services   55000000
# 1207     CollegeDekho    Gurugram                 EdTech   26000000
# 1208           WeRize   Bengaluru     Financial Services    8000000
#
#       Funding Year
# 0             2018
# 1             2018
# 2             2018
# 3             2018
# 4             2018
# ...            ...
# 1204          2021
# 1205          2021
# 1206          2021
# 1207          2021
# 1208          2021
#
# [2840 rows x 5 columns]

# %% [markdown]
# # Performing EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2840 entries, 0 to 1208
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  2840 non-null   object
#  1   HeadQuarter    2840 non-null   object
#  2   Sector         2840 non-null   object
#  3   Amount($)      2840 non-null   int64
#  4   Funding Year   2840 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 133.1+ KB

# %% [markdown]
# There are no empty cells on the dataset.

# %%
# Inspecting the "HeadQuarter" column thoroughly

df["HeadQuarter"].unique()
# Out:
# array(['Bengaluru', 'Mumbai', 'Gurgaon', 'Noida', 'Hyderabad', 'Kalkaji',
#        'Delhi', 'N/A', 'Hubli', 'New Delhi', 'Chennai', 'Mohali',
#        'Kolkata', 'Pune', 'Jodhpur', 'Kanpur', 'Ahmedabad', 'Azadpur',
#        'Haryana', 'Cochin', 'Faridabad', 'Jaipur', 'Kota', 'Anand',
#        'Bengaluru City', 'Belgaum', 'Thane', 'Margão', 'Indore', 'Alwar',
#        'Kannur', 'Trivandrum', 'Ernakulam', 'Kormangala', 'Uttar Pradesh',
#        'Andheri', 'Mylapore', 'Ghaziabad', 'Kochi', 'Powai', 'Guntur',
#        'Kalpakkam', 'Bhopal', 'Coimbatore', 'Worli', 'Alleppey',
#        'Chandigarh', 'Guindy', 'Lucknow', 'Telangana', 'Gurugram',
#        'Surat', 'Rajasthan', 'Tirunelveli', 'Singapore', 'Gujarat',
#        'Kerala', 'Frisco', 'California', 'Dhingsara', 'New York', 'Patna',
#        'San Francisco', 'San Ramon', 'Paris', 'Plano', 'Sydney',
#        'San Francisco Bay Area', 'Bangaldesh', 'London', 'Milano',
#        'Palmwoods', 'France', 'Samastipur', 'Irvine', 'Tumkur',
#        'Newcastle Upon Tyne', 'Shanghai', 'Jiaxing', 'Rajastan',
#        'Ludhiana', 'Dehradun', 'San Franciscao', 'Tangerang', 'Berlin',
#        'Seattle', 'Riyadh', 'Seoul', 'Bangkok', 'Warangal', 'Hyderebad',
#        'Odisha', 'Bihar', 'Goa', 'Tamil Nadu', 'Ahmadabad',
#        'Andhra Pradesh', 'Rajsamand', 'Ranchi', 'Faridabad, Haryana',
#        'Vadodara', 'Hauz Khas', 'Nagpur', 'West Bengal', 'Samsitpur',
#        'Silvassa', 'Thiruvananthapuram', 'Roorkee', 'Ambernath',
#        'Panchkula', 'Mangalore', 'Telugana', 'Bhubaneswar', 'Kottayam',
#        'Beijing', 'Panaji', 'Satara', 'Orissia', 'Santra',
#        'Mountain View, CA', 'Jharkhand', 'Bhilwara', 'Guwahati',
#        'Manchester', 'The Nilgiris', 'Gandhinagar'], dtype=object)

# %%
# changing 'Gurgaon' to 'Gurugram' since Gurugram is the official name.
df["HeadQuarter"] = df["HeadQuarter"].replace('Gurgaon', 'Gurugram', regex=True)

# changing 'New Delhi' to 'Delhi' since it's the same city.
df["HeadQuarter"] = df["HeadQuarter"].replace('New Delhi', 'Delhi', regex=True)

# Changing 'Bengaluru City' to 'Bengaluru', since it's the same city.
df["HeadQuarter"] = df["HeadQuarter"].replace('Bengaluru City', 'Bengaluru', regex=True)

# Changing 'Telugana' to 'Telangana', since Telangana is the offical name.
df["HeadQuarter"] = df["HeadQuarter"].replace('Telugana', 'Telangana', regex=True)

# Changing 'Faridabad, Haryana' to 'Faridabad'.
df["HeadQuarter"] = df["HeadQuarter"].replace('Faridabad, Haryana', 'Faridabad', regex=True)

# Changing 'Irvine', 'San Francisco', 'San Ramon', 'San Francisco Bay Area', 'San Franciscao' (misspelling)
# and 'Mountain View, CA' to California, since they are all in California.
df["HeadQuarter"] = df["HeadQuarter"].replace(['Irvine', 'San Francisco', 'San Ramon', 'San Francisco Bay Area', 'San Franciscao', 'Mountain View, CA'], 'California', regex=True)

# Changing 'Frisco' and 'Plano' to 'Texas', since they are both in Texas.
df["HeadQuarter"] = df["HeadQuarter"].replace(['Frisco', 'Plano'], 'Texas', regex=True)

# Changing 'Samstipur' to 'Samastipur', since Samstipur is a misspelling.
df["HeadQuarter"] = df["HeadQuarter"].replace('Samsitpur', 'Samastipur', regex=True)

# Changing 'France' to 'Paris', since the "HeadQuarter" column carries names of cities, not countries.
df["HeadQuarter"] = df["HeadQuarter"].replace('France', 'Paris', regex=True)

# Changing 'Milano' to 'Milan' the official name.
df["HeadQuarter"] = df["HeadQuarter"].replace('Milano', 'Milan', regex=True)

# Changing 'Orissia' to 'Odisha', since Odisha is the offical name.
df["HeadQuarter"] = df["HeadQuarter"].replace('Orissia', 'Odisha', regex=True)

df["HeadQuarter"].unique()
# Out:
# array(['Bengaluru', 'Mumbai', 'Gurugram', 'Noida', 'Hyderabad', 'Kalkaji',
#        'Delhi', 'N/A', 'Hubli', 'Chennai', 'Mohali', 'Kolkata', 'Pune',
#        'Jodhpur', 'Kanpur', 'Ahmedabad', 'Azadpur', 'Haryana', 'Cochin',
#        'Faridabad', 'Jaipur', 'Kota', 'Anand', 'Belgaum', 'Thane',
#        'Margão', 'Indore', 'Alwar', 'Kannur', 'Trivandrum', 'Ernakulam',
#        'Kormangala', 'Uttar Pradesh', 'Andheri', 'Mylapore', 'Ghaziabad',
#        'Kochi', 'Powai', 'Guntur', 'Kalpakkam', 'Bhopal', 'Coimbatore',
#        'Worli', 'Alleppey', 'Chandigarh', 'Guindy', 'Lucknow',
#        'Telangana', 'Surat', 'Rajasthan', 'Tirunelveli', 'Singapore',
#        'Gujarat', 'Kerala', 'Texas', 'California', 'Dhingsara',
#        'New York', 'Patna', 'Paris', 'Sydney', 'California Bay Area',
#        'Bangaldesh', 'London', 'Milan', 'Palmwoods', 'Samastipur',
#        'Tumkur', 'Newcastle Upon Tyne', 'Shanghai', 'Jiaxing', 'Rajastan',
#        'Ludhiana', 'Dehradun', 'Tangerang', 'Berlin', 'Seattle', 'Riyadh',
#        'Seoul', 'Bangkok', 'Warangal', 'Hyderebad', 'Odisha', 'Bihar',
#        'Goa', 'Tamil Nadu', 'Ahmadabad', 'Andhra Pradesh', 'Rajsamand',
#        'Ranchi', 'Vadodara', 'Hauz Khas', 'Nagpur', 'West Bengal',
#        'Silvassa', 'Thiruvananthapuram', 'Roorkee', 'Ambernath',
#        'Panchkula', 'Mangalore', 'Bhubaneswar', 'Kottayam', 'Beijing',
#        'Panaji', 'Satara', 'Santra', 'Jharkhand', 'Bhilwara', 'Guwahati',
#        'Manchester', 'The Nilgiris', 'Gandhinagar'], dtype=object)

# %%
df["HeadQuarter"] = df["HeadQuarter"].replace('California Bay Area', 'California', regex=True)

df["HeadQuarter"].unique()
# Out:
# array(['Bengaluru', 'Mumbai', 'Gurugram', 'Noida', 'Hyderabad', 'Kalkaji',
#        'Delhi', 'N/A', 'Hubli', 'Chennai', 'Mohali', 'Kolkata', 'Pune',
#        'Jodhpur', 'Kanpur', 'Ahmedabad', 'Azadpur', 'Haryana', 'Cochin',
#        'Faridabad', 'Jaipur', 'Kota', 'Anand', 'Belgaum', 'Thane',
#        'Margão', 'Indore', 'Alwar', 'Kannur', 'Trivandrum', 'Ernakulam',
#        'Kormangala', 'Uttar Pradesh', 'Andheri', 'Mylapore', 'Ghaziabad',
#        'Kochi', 'Powai', 'Guntur', 'Kalpakkam', 'Bhopal', 'Coimbatore',
#        'Worli', 'Alleppey', 'Chandigarh', 'Guindy', 'Lucknow',
#        'Telangana', 'Surat', 'Rajasthan', 'Tirunelveli', 'Singapore',
#        'Gujarat', 'Kerala', 'Texas', 'California', 'Dhingsara',
#        'New York', 'Patna', 'Paris', 'Sydney', 'Bangaldesh', 'London',
#        'Milan', 'Palmwoods', 'Samastipur', 'Tumkur',
#        'Newcastle Upon Tyne', 'Shanghai', 'Jiaxing', 'Rajastan',
#        'Ludhiana', 'Dehradun', 'Tangerang', 'Berlin', 'Seattle', 'Riyadh',
#        'Seoul', 'Bangkok', 'Warangal', 'Hyderebad', 'Odisha', 'Bihar',
#        'Goa', 'Tamil Nadu', 'Ahmadabad', 'Andhra Pradesh', 'Rajsamand',
#        'Ranchi', 'Vadodara', 'Hauz Khas', 'Nagpur', 'West Bengal',
#        'Silvassa', 'Thiruvananthapuram', 'Roorkee', 'Ambernath',
#        'Panchkula', 'Mangalore', 'Bhubaneswar', 'Kottayam', 'Beijing',
#        'Panaji', 'Satara', 'Santra', 'Jharkhand', 'Bhilwara', 'Guwahati',
#        'Manchester', 'The Nilgiris', 'Gandhinagar'], dtype=object)

# %% [markdown]
# In the HeadQuarter column, we have the names of states and also have the names of cities that are within those states in the same column. For example,  Uttar Pradesh is a state in the HeadQuarter column while Noida, Kanpur and Ghaziabad are cities in Uttar Pradesh also in the HeadQuarter column. This means that when analysing the HeadQuarter column, the true values of funding in Uttar Pradesh will not be obtained. This applies to some other states as well.
#
# To handle this challenge, the names of cities will be replaced with the names of states they are found in. Doing so will give the true information of funding in each state, which will make the analysis more valid.

# %%
# Creating a dictionary called "state-mapping" where each city is placed in the appropriate state.

state_mapping = {
    'Ahmedabad': 'Gujarat',
    'Alwar': 'Rajasthan',
    'Alleppey': 'Kerala',
    'Ambernath': 'Maharashtra',
    'Anand': 'Gujarat',
    'Andheri': 'Maharashtra',
    'Azadpur': 'Delhi',
    'Bengaluru': 'Karnataka',
    'Belgaum': 'Karnataka',
    'Bhilwara': 'Rajasthan',
    'Bhopal': 'Madhya Pradesh',
    'Bhubaneswar': 'Odisha',
    'Chennai': 'Tamil Nadu',
    'Cochin': 'Kerala',
    'Dehradun': 'Uttarakhand',
    'Dhingsara': 'Haryana',
    'Coimbatore': 'Tamil Nadu',
    'Ernakulam': 'Kerala',
    'Faridabad': 'Haryana',
    'Gandhinagar': 'Gujarat',
    'Ghaziabad': 'Uttar Pradesh',
    'Guindy': 'Tamil Nadu',
    'Gurugram': 'Haryana',
    'Guwahati': 'Assam',
    'Hauz Khas': 'Delhi',
    'Hubli': 'Karnataka',
    'Hyderabad': 'Telangana',
    'Indore': 'Madhya Pradesh',
    'Jaipur': 'Rajasthan',
    'Jodhpur': 'Rajasthan',
    'Kalkaji': 'Delhi',
    'Kalpakkam': 'Tamil Nadu',
    'Kannur': 'Kerala',
    'Kanpur': 'Uttar Pradesh',
    'Kochi': 'Kerala',
    'Kolkata': 'West Bengal',
    'Kota': 'Rajasthan',
    'Kormangala': 'Karnataka',
    'Kottayam': 'Kerala',
    'Lucknow': 'Uttar Pradesh',
    'Ludhiana': 'Punjab',
    'Margão': 'Goa',
    'Mangalore': 'Karnataka',
    'Mohali': 'Punjab',
    'Mumbai': 'Maharashtra',
    'Mylapore': 'Tamil Nadu',
    'Nagpur': 'Maharashtra',
    'Noida': 'Uttar Pradesh',
    'Panaji': 'Goa',
    'Panchkula': 'Haryana',
    'Patna': 'Bihar',
    'Powai': 'Maharashtra',
    'Pune': 'Maharashtra',
    'Rajsamand': 'Rajasthan',
    'Ranchi': 'Jharkhand',
    'Roorkee': 'Uttarakhand',
    'Samastipur': 'Bihar',
    'Santra': 'Chhattisgarh',
    'Satara': 'Maharashtra',
    'Surat': 'Gujarat',
    'Thane': 'Maharashtra',
    'The Nilgiris': 'Tamil Nadu',
    'Thiruvananthapuram': 'Kerala',
    'Tirunelveli': 'Tamil Nadu',
    'Trivandrum': 'Kerala',
    'Tumkur': 'Karnataka',
    'Vadodara': 'Gujarat',
    'Warangal': 'Telangana',
    'Worli': 'Maharashtra'
    }

# %% [markdown]
# Chandigarh is the shared capital of the states of Haryana and Punjab, while Silvassa lies between the states of Gujarat and Maharashtra. Hence they are not mapped to any state name.

# %%
# Replacing each city in the dictionary with the corresponding state name, and when a location (a state in India or a 
# location outside India) is not found in the dictionary, the location itself is returned.

df["HeadQuarter"] = [state_mapping.get(city, city) for city in df["HeadQuarter"]]
df["HeadQuarter"].unique()
# Out:
# array(['Karnataka', 'Maharashtra', 'Haryana', 'Uttar Pradesh',
#        'Telangana', 'Delhi', 'N/A', 'Tamil Nadu', 'Punjab', 'West Bengal',
#        'Rajasthan', 'Gujarat', 'Kerala', 'Goa', 'Madhya Pradesh',
#        'Guntur', 'Chandigarh', 'Singapore', 'Texas', 'California',
#        'New York', 'Bihar', 'Paris', 'Sydney', 'Bangaldesh', 'London',
#        'Milan', 'Palmwoods', 'Newcastle Upon Tyne', 'Shanghai', 'Jiaxing',
#        'Rajastan', 'Uttarakhand', 'Tangerang', 'Berlin', 'Seattle',
#        'Riyadh', 'Seoul', 'Bangkok', 'Hyderebad', 'Odisha', 'Ahmadabad',
#        'Andhra Pradesh', 'Jharkhand', 'Silvassa', 'Beijing',
#        'Chhattisgarh', 'Assam', 'Manchester'], dtype=object)

# %%
# Inspecting the "Sector" column thoroughly

df["Sector"].unique()
# Out:
# array(['Brand Marketing', 'Agriculture', 'Credit', 'Financial Services',
#        'E-Commerce Platforms', 'Cloud Infrastructure', 'Internet',
#        'Market Research', 'Information Services', 'Mobile Payments',
#        'B2B', 'Apps', 'Food Delivery', 'Industrial Automation',
#        'Automotive', 'Finance', 'Accounting', 'Artificial Intelligence',
#        'Internet of Things', 'Air Transportation', 'Food and Beverage',
#        'Autonomous Vehicles', 'Enterprise Software', 'Logistics',
#        'Insurance', 'Information Technology', 'Blockchain', 'Education',
#        'E-Commerce', 'Renewable Energy', 'E-Learning', 'Clean Energy',
#        'Transportation', 'Fitness', 'Hospitality',
#        'Media and Entertainment', 'Broadcasting', 'EdTech', 'Health Care',
#        'N/A', 'Sports', 'Big Data', 'Cloud Computing', 'Food Processing',
#        'Trading Platform', 'Consumer Goods', 'Wellness', 'Fashion',
#        'Consulting', 'Biotechnology', 'Communities', 'Consumer',
#        'Consumer Applications', 'Mobile', 'Advertising', 'Marketplace',
#        'Aerospace', 'Home Decor', 'Energy', 'Digital Marketing',
#        'Creative Agency', 'Consumer Lending', 'Health Diagnostics',
#        'Banking', 'Embedded Systems', 'Beauty', 'AgTech', 'Credit Cards',
#        'Software', 'Manufacturing', 'Hospital', 'Events', '3D Printing',
#        'Digital Entertainment', 'Funding Platform', 'Classifieds',
#        'Enterprise Resource Planning (ERP)', 'Audio', 'Government',
#        'Digital Media', 'Business Intelligence', 'Children', 'Rental',
#        'Travel', 'Wealth Management', 'Veterinary', 'Tourism',
#        'Consumer Electronics', 'Analytics', 'Facilities Support Services',
#        'Medical', 'Music Streaming', 'Retail', 'Business Development',
#        'Human Resources', 'Customer Service', 'Training',
#        'Dietary Supplements', 'Collaboration', 'Nanotechnology',
#        'File Sharing', 'Crowdfunding', 'Catering', 'Computer', 'Android',
#        'Delivery', 'Environmental Consulting', 'Commercial Real Estate',
#        'Delivery Service', 'Basketball', 'Fraud Detection',
#        'Cryptocurrency', 'Wedding', 'Crowdsourcing', 'Farming',
#        'Business Travel', 'Career Planning', 'Medical Device',
#        'Alternative Medicine', 'Dental', 'CleanTech', 'Marketing',
#        'Commercial', 'Continuing Education', 'Smart Cities',
#        'Social Media', 'Biopharma', 'Child Care', 'Health Insurance',
#        'Gaming', 'Search Engine', 'Battery', 'Cosmetics', 'eSports',
#        'Reading Apps', 'Electric Vehicle', 'Packaging Services',
#        'Last Mile Transportation', 'Cooking', 'FinTech', 'Online Games',
#        'Online Portals', 'Music', 'News', 'Industrial', 'Dating',
#        'Fantasy Sports', 'Eyewear', 'Ecommerce', 'Edtech',
#        'Interior Design', 'Agritech', 'Technology', 'Saas', 'Ai & Tech',
#        'E-Commerce & Ar', 'Fintech', 'Hr Tech', 'Food Tech', 'Health',
#        'Healthcare', 'Safety Tech', 'Pharmaceutical',
#        'Insurance Technology', 'Ai', 'Foodtech', 'Food', 'Iot',
#        'E-Marketplace', 'Robotics & Ai', 'Food & Nutrition', 'E-Sports',
#        'Jewellery', 'B2B Supply Chain', 'Games', 'Food & Tech',
#        'Accomodation', 'Automotive Tech', 'Legal Tech', 'Mutual Funds',
#        'Cybersecurity', 'Automobile', 'Healthtech', 'Yoga & Wellness',
#        'Virtual Banking', 'Transport & Rentals',
#        'Marketing & Customer Loyalty', 'Infratech',
#        'Automobile & Technology', 'AgriTech', 'Hygiene management',
#        'Escrow', 'Networking platform', 'Food & Bevarages', 'HealthTech',
#        'Fashion startup', 'Food Industry', 'Virtual auditing startup',
#        'E-commerce', 'Work fulfillment', 'AI startup',
#        'Telecommunication', 'Tech Startup', 'Medtech', 'Tyre management',
#        'Cloud company', 'Software company', 'Venture capitalist',
#        'Renewable player', 'IoT startup', 'SaaS startup', 'Aero company',
#        'Marketing company', 'Retail startup', 'Co-working Startup',
#        'Finance company', 'Tech company', 'Solar Monitoring Company',
#        'Video sharing platform', 'Gaming startup',
#        'Video streaming platform', 'Consumer appliances',
#        'Blockchain startup', 'Conversational AI platform', 'Real Estate',
#        'SaaS platform', 'AI platform', 'Fusion beverages', 'HR Tech',
#        'Job portal', 'Dairy startup', 'Content management', 'Spacetech',
#        'Trading platform', 'AI Company', 'Photonics startup',
#        'Entertainment', 'Scanning app', 'Skincare startup',
#        'Food and Beverages', 'Biotechnology company', 'FoodTech',
#        'Proptech', 'Fitness startup', 'PaaS startup', 'Beverages',
#        'Automobiles', 'Deeptech', 'EV startup', 'AR/VR startup',
#        'Recruitment startup', 'QSR startup', 'Video platform',
#        'Fertility tech', 'Luxury car startup', 'FM', 'Nutrition sector',
#        'Tech platform', 'Video', 'Retail Tech', 'HeathTech',
#        'Sles and marketing', 'LegalTech', 'Car Service',
#        'Bike marketplace', 'Agri tech', 'Reatil startup', 'AR platform',
#        'Content marketplace', 'Rental space', 'Soil-Tech',
#        'Ayurveda tech', 'Packaging solution startup', 'Cleantech',
#        'Sanitation solutions', 'HealthCare', 'Home Design', 'InsureTech',
#        'AI Startup', 'Solar solution', 'Jewellery startup',
#        'Multinational conglomerate company', 'Deeptech startup',
#        'Social Network', 'Publication', 'Tech', 'Venture capital',
#        'Entreprenurship', 'Food devlivery', 'Warehouse',
#        'Online financial service', 'Eyeglasses', 'Battery design',
#        'Online credit management startup', 'Beverage', 'TravelTech',
#        'Startup laboratory', 'Personal care startup',
#        'Customer service company', 'SaaS\xa0\xa0startup',
#        'Marketing startup', 'Service industry', 'Social media', 'AI',
#        'AR startup', 'HR Tech startup', 'Automotive Startup',
#        'Food Startup', 'EdTech Startup', 'Car Trade', 'EdtTech',
#        'AI Platform', 'Automation', 'Solar SaaS', 'WL & RAC protection',
#        'Social commerce', 'Home interior services', 'Agritech startup',
#        'API platform', 'Deep Tech', 'Electricity', 'Automotive company',
#        'FMCG', 'Insurance Tech', 'Video personalization',
#        'Software Company', 'Biomaterial startup', 'IT', 'Craft Beer',
#        'Investment', 'Linguistic Spiritual', 'Construction',
#        'Battery manufacturer', 'Nano Distribution Network', 'AI health',
#        'Dating app', 'Media', 'Healthcare/Edtech', 'Social Commerce',
#        'Agritech/Commerce', 'Mobility tech', 'Social e-commerce',
#        'Food & Logistics', 'SpaceTech', 'Nutrition Tech', 'HR', 'IoT',
#        'Interior design', 'AR/VR', 'Appliance', 'HR tech', 'Food tech',
#        'Mental Health', 'Solar Solution', 'SaaS', 'B2B marketplace',
#        'Fashion Tech', 'Nutrition tech', 'Health & Wellness',
#        'Cloud Kitchen', 'IoT/Automobile', 'Eye Wear', 'Digital tech',
#        'Data Intelligence', 'Co-living', 'Food & Beverages',
#        'Defense tech', 'Construction tech', 'Nutrition', 'Coworking',
#        'Micro-mobiity', 'Auto-tech', 'Robotics', 'Yoga & wellness',
#        'Logitech', 'Med Tech', 'Life sciences', 'Retail Aggregator',
#        'Deep Tech AI', 'Biotech', 'HrTech', 'Mobility/Transport',
#        'AI & Debt', 'SaaS/Edtech', 'Transport', 'Co-working', 'Insurtech',
#        'Automotive tech', 'Legal', 'EV', 'Supply chain, Agritech',
#        'Pharma', 'Insurance technology', 'Foodtech & Logistics',
#        'Housing', 'Data Analytics', 'Investment Tech', 'Dairy',
#        'Beauty & wellness', 'Travel & SaaS', 'Tourism & EV', 'Media Tech',
#        'Location Analytics', 'E store', 'Data Science',
#        'Health and Fitness', 'Interior & decor', 'eMobility',
#        'Automation tech', 'Media & Networking', 'E-market',
#        'AI & Data science', 'Travel tech', 'Automotive and Rentals',
#        'E-tail', 'AI & Media', 'Machine Learning', 'Content Marktplace',
#        'Visual Media', 'Hygiene', 'VR & SaaS', 'Sales & Services',
#        'AI & Deep learning', 'Housing & Rentals', 'Estore', 'E tailor',
#        'E-mobility', 'Ad-tech', 'Neo-banking', 'Transport Automation',
#        'Techonology', 'AI Robotics', 'Preschool Daycare', 'Food diet',
#        'B2B Agritech', 'E-connect', 'Tech hub', 'Consultancy', 'Pharmacy',
#        'Deisgning', 'Taxation', 'Automobile Technology', 'B2B E-commerce',
#        'Home services', 'B2B service', 'Electronics', 'IT startup',
#        'Oil and Energy', 'Telecommuncation', 'Milk startup', 'AI Chatbot',
#        'Food delivery', 'Fantasy sports', 'Video communication',
#        'Skill development', 'Recruitment', 'Computer Games',
#        'Apparel & Fashion', 'Logistics & Supply Chain', 'SportsTech',
#        'HRTech', 'Wine & Spirits', 'Mechanical & Industrial Engineering',
#        'Spiritual', 'Lifestyle', 'Computer software', 'Tech startup',
#        'Digital mortgage', 'Information Technology & Services',
#        'Furniture', 'Healtcare', 'Tobacco', 'Insuretech',
#        'MLOps platform', 'Venture Capital', 'Pet care', 'Drone',
#        'Wholesale', 'E-learning', 'Consumer Services',
#        'Venture Capital & Private Equity', 'Health, Wellness & Fitness',
#        'OTT', 'Education Management', 'Computer Software',
#        'Software Startup', 'Computer & Network Security',
#        'Capital Markets', 'Social network', 'Hospital & Health Care',
#        'Pharmaceuticals', 'Mobility', 'Digital platform', 'B2B Ecommerce',
#        'Online Media', 'Mobile Games', 'Food Production', 'Podcast',
#        'Content publishing', 'Water purification', 'Content commerce',
#        'Innovation Management', 'Celebrity Engagement', 'Personal Care',
#        'Cannabis startup', 'Blogging', 'BioTechnology', 'B2B Marketplace',
#        'Health care', 'Social audio', 'Fashion and lifestyle',
#        'Delivery service', 'B2B Manufacturing', 'Solar', 'TaaS startup',
#        'Manufacturing startup', 'Vehicle repair startup', 'Advisory firm',
#        'Legaltech', 'Pollution control equiptment', 'Fashion & Lifestyle',
#        'D2C', 'Environmental Services', 'Merchandise',
#        'Facilities Services', 'Marketing & Advertising', 'D2C Business',
#        'NFT Marketplace', 'Consumer software', 'Social community',
#        'Fishery', 'Renewables & Environment', 'Online storytelling',
#        'Aviation', 'IT company', 'Environmental service',
#        'Job discovery platform', 'D2C Fashion', 'Heathcare', 'CRM',
#        'D2C startup', 'Innovation management', 'Community platform',
#        'Networking', 'Consumer service', 'Consumer goods', 'MarTech',
#        'Advertisement', 'Content creation', 'Augmented reality',
#        'Bike Rental', 'Beauty products', 'FemTech', 'Cultural',
#        'Supply chain platform', 'Social platform', 'Real estate',
#        'AI company', 'Sports startup', 'Matrimony', 'Crypto', 'Clothing',
#        'IoT platform', 'Commerce', 'Defense & Space',
#        'Business Supplies & Equipment', 'NFT', 'Oil & Energy',
#        'Company-as-a-Service', 'Textiles',
#        'Professional Training & Coaching', 'Maritime',
#        'Housing Marketplace', 'Furniture Rental', 'Telecommunications',
#        'Equity Management', 'Cloud kitchen', 'Community',
#        'Higher Education', 'Mechanical Or Industrial Engineering',
#        'D2C jewellery', 'Sales and Distribution',
#        'Translation & Localization', 'Investment Banking', 'Femtech',
#        'sports', 'Foootwear', 'Legal Services', 'Arts & Crafts',
#        'Investment Management', 'Management Consulting', 'B2B startup',
#        ' Online Media', 'Design', 'B2B Travel', 'Product studio',
#        'Aviation & Aerospace', 'Staffing & Recruiting'], dtype=object)

# %% [markdown]
# The "Sector" column contains many similar kinds of businesses as seperate sectors. For example, 'food', 'food and beverages', 'beverages', 'food industry' etc are similar but are represented as seperate sectors in the "Sector" column. Other sectors have similar occurences. There is need to map these related sectors together.

# %%
# df.loc[df["Sector"] == 'Acccomodation', "Sector"] = 'Housing & Real Estate'
# df.loc[df["Sector"] == 'Acccomodation'. "Sector"] = 'Housing & Real Estate'

# %%
# Inspecting the "Amount($)" column thoroughly

df["Amount($)"].unique()
# Out:
# array([      250000,       584000,       949000,      2000000,
#                   0,      1600000,       233600,       730000,
#             1460000,       150000,      1100000,         7300,
#             6000000,       650000,       511000,       934400,
#              292000,      1000000,      5000000,      4000000,
#              438000,      2800000,      1700000,      1300000,
#               73000,       182500,       219000,       500000,
#             1518400,       657000,     13400000,       365000,
#              385440,       116800,          876,      9000000,
#              100000,        20000,       120000,       496400,
#             4993200,       143145,      8760000,    742000000,
#            14600000,     29200000,      3980000,        10000,
#                1460,      3650000,   1000000000,      7000000,
#            35000000,      8030000,     28500000,      3504000,
#             1752000,      2400000,     30000000,     36500000,
#            23000000,     11000000,       642400,      3240000,
#              876000,    540000000,      9490000,     23360000,
#              900000,     10000000,      1500000,      1022000,
#            14000000,      1496500,    100000000,        17520,
#            75920000,       800000,      1041000,        15000,
#             1400000,      1200000,      2200000,      1800000,
#             3600000,       138700,       300000,      6830000,
#              200000,      2190000,      4300000,       364846,
#              400000,       102200,        20440,       146000,
#              328500,     13200000,        50000,      2046920,
#             3000000,      1250000,       180000,       280320,
#             1503800,      4200000,       175000,      1450000,
#                2920,      4500000,       600000,       242360,
#              175200,     15000000,       481800,       125000,
#              130000,       509540,      1051200,     17200000,
#              467200,      3500000,      1971000,     12000000,
#            40000000,     50000000,     22484000,      2044000,
#            41900000,     20586000,      3530000,      3300000,
#             8468000,       525600,      4964000,    210000000,
#            37680000,      7446000,     32120000,     22000000,
#               70000,    224723200,    292000000,     58400000,
#           185000000,     65000000,      2409000,       700000,
#             3066000,     29632160,     75000000,      1168000,
#             1760000,      2700000,      4088000,     11680000,
#              750000,      2500000,     80000000,     25000000,
#            10658000,      5840000,      3700000,      5600000,
#             3796000,     99230000,     70000000,        40000,
#              550000,    365000000,       127750,      1138800,
#            28000000,      3854400,     16498000,     11826000,
#            20440000,     14900000,    225000000,         7500,
#             6300000,    150000000,     20000000,    275000000,
#              140500,       182700,     15500000,      5500000,
#              140000,    230000000,     49400000,     32000000,
#            26000000,      8000000,    120000000,      6800000,
#            36000000,      5700000,     60000000,       220000,
#             2100000,    311000000,      4800000,    693000000,
#            33000000,       340000,     45000000,    660000000,
#             7500000,    145000000,     21000000,       560000,
#              275000,    390000000,      5100000,    700000000,
#             2300000,     19000000,      7800000,    200000000,
#             4100000,       575000,     18000000,      3200000,
#             4700000,    121000000,     55000000,     16000000,
#             5400000,     52000000,    118000000,     18500000,
#         70000000000,    800000000,    400000000,    176000000,
#              470000,       240000,   3000000000,     74000000,
#            62000000,    500000000,     12500000,   2200000000,
#             5060000,     24700000,      7700000,     19067328,
#            51000000,       115000,        54000,       803146,
#              238000,     10220000,      1020000,    170000000,
#             2900000,       543000,     90000000,      3400000,
#             8090000,      1030000,      5040000,       360000,
#            54000000,     42500000,     11370000,       325000,
#              410000,       450000,       682000,      4050000,
#             1050000,      1080000,      2110000,     11943500,
#              764000,       603000,       409000,       286000,
#              136000,    825000000,       546000,       887000,
#               43000,        40900,      5660000,       350000,
#              110000,    122000000,     11635000,      1065000,
#              669000,     16076000,       649600,      6700000,
#              266500,      2879000,     26500000,       351000,
#             8700000,     46761000,      9600000,     11241000,
#              804000,      1340000,       467000,       133000,
#             3823000,       934000,       293000,       198000,
#              927000,       971000,      3060000,      1862000,
#              232000,      2888000,      1328000,     56000000,
#             2250000,     16753000,      1470000,       530000,
#              267000,      3344000,      7200000,      2743000,
#             6082000,      6609000,     27700000,      5940000,
#             3964000,       197000,      4327000,       459000,
#             3937000,      1313500,       229800,      5305000,
#              264000,      1750000,      5967000,      2980000,
#              323000,      1326000,     27000000,      5200000,
#             2530000,       792000,     11363000,      1715000,
#              329000,      5271000,      3226000,      5900000,
#            44000000,      3879000,     13000000,      8800000,
#             9500000,       920000,     35600000,      9400000,
#              790000,       480000,       160000,      8200000,
#             4257000,      1410000,       349800,       786000,
#             2004000,    123000000,       248000,     24000000,
#            14259000,     24500000,      3800000,     18370000,
#            68525000,      1834000,     23850000,     43000000,
#            21600000,      4598000,     13137000,    115000000,
#             3900000,       670000,      4223000,      8500000,
#             3148000,      2600000,      2558000,      4049500,
#            10500000,      6500000,     43700000,     13800000,
#              306900,       420000,       627300,    113000000,
#           110000000,      1397000,       448500,      7975700,
#              330000,      1402000,     21500000,    296000000,
#             4900000,      1402400,     12618300,      9900000,
#              982530,     70185200,     84000000,     39000000,
#             1403400,    105000000,    103000000,       281300,
#               12700,        25000,     97500000,       507000,
#             8400000,     18300000,    125000000,       181000,
#              280000,     14700000,      8043000,    188000000,
#            49000000,    160000000,       850000,     53000000,
#             7400000,     17000000,    215000000,    350000000,
#            83000000, 150000000000,    300000000,    140000000,
#            17500000,     42000000,    450000000,     37000000,
#           370000000,       770000,      6600000,       725000,
#              461000,     96000000,    266000000,    325000000,
#              225000,     85000000,       235000,       260000,
#            86000000,    111000000,       265000,     76000000,
#            95000000,     14300000,     81000000,    280000000,
#              720000,     67000000,     10200000,    220000000,
#           108000000,       370000,     48000000,    192000000,
#             1900000,     41000000,    144000000,    270000000,
#           250000000,       320000,     38000000,     64000000,
#              620000,    234000000,    460000000,     13500000,
#           195000000,      7300000,     16500000,     92000000,
#           135000000,       155000,    840000000,    248000000,
#              570000,    260000000,    175000000,       810000,
#           600000000,      6750000,     78000000,    255000000,
#           570000000,     31000000,       540000,      6200000],
#       dtype=int64)

# %%
# Evaluating the "Amount($)" column

df["Amount($)"].describe()
# Out:
# count    2.840000e+03
# mean     9.857835e+07
# std      3.106718e+09
# min      0.000000e+00
# 25%      2.000000e+05
# 50%      1.559200e+06
# 75%      8.000000e+06
# max      1.500000e+11
# Name: Amount($), dtype: float64

# %% [markdown]
# # Hypothesis Testing
#
# Null hypothesis: The sector does not influence the funding amounts received by the start-ups.
#
# Alternate hypothesis: The sector influences the funding amounts received by the start-ups.

# %%
# Create a DataFrame with sector and funding amount data
hypothesis_data = {
    "Sector": df["Sector"],
    "Amount($)": df["Amount($)"]
}
hypothesis_data_df = pd.DataFrame(hypothesis_data)

# Perform ANOVA test
grouped_data = df.groupby("Sector")["Amount($)"]
grouped_arrays = [np.array(group) for _, group in grouped_data]

f_statistic, p_value = stats.f_oneway(*grouped_arrays)

# Print the results
print("F-Statistic:", f_statistic)
print("p-value:", p_value)

# Check if the null hypothesis is rejected or not
alpha = 0.05  # Significance level
if p_value < alpha:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# F-Statistic: 0.04439448715568275
# p-value: 0.9999999999999999
# Fail to reject the null hypothesis.

# %% [markdown]
# Since the F-Statistic (0.04439448715568275) is less than the Significance Level (0.05), we fail to reject the null hypothesis. This implies that our null hypothesis is correct.

# %% [markdown]
# # Answering Questions with visualizations

# %%
df
# Out:
#         Company/Brand    HeadQuarter                 Sector  Amount($)
# 0     Thecollegefever      Karnataka        Brand Marketing     250000  \
# 1     Happy Cow Dairy    Maharashtra            Agriculture     584000
# 2          Myloancare        Haryana                 Credit     949000
# 3         Payme India  Uttar Pradesh     Financial Services    2000000
# 4            Eunimart      Telangana   E-Commerce Platforms          0
# ...               ...            ...                    ...        ...
# 1204         Gigforce        Haryana  Staffing & Recruiting    3000000
# 1205           Vahdam          Delhi       Food & Beverages   20000000
# 1206     Leap Finance      Karnataka     Financial Services   55000000
# 1207     CollegeDekho        Haryana                 EdTech   26000000
# 1208           WeRize      Karnataka     Financial Services    8000000
#
#       Funding Year
# 0             2018
# 1             2018
# 2             2018
# 3             2018
# 4             2018
# ...            ...
# 1204          2021
# 1205          2021
# 1206          2021
# 1207          2021
# 1208          2021
#
# [2840 rows x 5 columns]

# %% [markdown]
# # Questions
#
# 1. How many start-ups got funded each year?
# 2. What is the total funding amount received each year?
# 3. What are the top ten start-ups that received the most single funding?
# 4. What are the top ten start-ups that received the least funding?
# 5. What are the top ten sectors that received the most funding?
# 6. What are the top ten sectors that received the least funding?
# 7. What are the top ten headquarters that received the most funding?
# 8. What are the top ten headquarters that received the least funding?
# 9. What is the trend of funding received by the top 5 HeadQuarters from 2018 to 2021?

# %% [markdown]
# # Question 1: How many start-ups got funded each year?

# %%
# Using value_counts to calculate the number of funding received each year

Number_of_funding_each_year = df["Funding Year"].value_counts()
Number_of_funding_each_year
# Out:
# Funding Year
# 2021    1178
# 2020    1048
# 2018     525
# 2019      89
# Name: count, dtype: int64

# %%
# Creating a bar chart to illustrate the number of start-ups that got funded each year

Funding_Year_Chart = sns.barplot(x = Number_of_funding_each_year.index, y = Number_of_funding_each_year.values);
Funding_Year_Chart.set(xlabel = "Funding Year", ylabel = "Number_of_funding_each_year", title = "Number Of Start-Ups That Got Funded Each Year");

# %% [markdown]
# In 2018, 525 start-ups received funding. This number declined to 89 in 2019, which is the year with the lowest number of start-ups receiving funding. There was a sharp rise to 1048 in 2020. The number increased further to 1178 in 2021, which is the year with the highest number of start-ups receiving funding.

# %% [markdown]
# # Question 2: What is the total funding amount received each year?

# %%
# Using groupby to calculate the amount of funding received each year

Total_funding_each_year = df.groupby(["Funding Year"]).sum(numeric_only=True).reset_index()
Total_funding_each_year
# Out:
#    Funding Year     Amount($)
# 0          2018    6641523177
# 1          2019    3336433200
# 2          2020   90691243104
# 3          2021  179293326000

# %%
# Creating a bar chart to illustrate the total funding amount each year

Funding_Amount_Chart = sns.barplot(x = Total_funding_each_year["Funding Year"], y = Total_funding_each_year["Amount($)"], errorbar = None);
Funding_Amount_Chart.set(xlabel = "Funding Year", ylabel = "Amount($)", title = "Total Funding Amount Received Each Year");

# plt.title("Total Funding Amount Each Year")
# Funding_Amount_Chart = sns.barplot(y = Total_funding_each_year["Amount($)"], x = Total_funding_each_year["Funding Year"], palette='Greens_d', errorbar = None)
# Funding_Amount_Chart.set(xlabel = "Funding Year", ylabel = "Amount($)")
# plt.show()

# %% [markdown]
# In 2018, the total funding amount received was 6,641,523,177 US Dollars. This amount declined to 3,336,433,200 US Dollars in 2019, which is the year with the lowest funding amount received. There was a sharp rise to 90,691,243,104 US Dollars in 2020. The amount increased further to 179,293,326,000 US Dollars in 2021, which is the year with the highest funding amount received.

# %% [markdown]
# # Question 3: What are the top ten start-ups that received the most funding?

# %%
# The amounts received by the start-ups will be grouped by Company/Brand

Funded_Startups = df.groupby("Company/Brand").sum(numeric_only=True).reset_index()
Funded_Startups
# Out:
#                Company/Brand  Amount($)  Funding Year
# 0                        &Me          0          2018
# 1                    1Bridge    2500000          2021
# 2                     1Crowd    3500000          2018
# 3           1K Kirana Bazaar    7000000          2021
# 4                        1MG    9900000          2020
# ...                      ...        ...           ...
# 2232                  qZense     600000          2020
# 2233              saarthi.ai          0          2021
# 2234                   truMe     140000          2019
# 2235  uFony Services Pvt ltd          0          2020
# 2236                  upGrad  145000000          4042
#
# [2237 rows x 3 columns]

# %%
# Then, the top 10 highest funding amounts by start-ups will be obtained by sorting from the highest to lowest and applying .head(10)

Funded_Startups.sort_values(['Amount($)'], ascending = False, inplace=True)
Most_Funded_Startups = Funded_Startups.head(10)
Most_Funded_Startups
# Out:
#                      Company/Brand     Amount($)  Funding Year
# 70                 Alteria Capital  150000000000          2021
# 1588  Reliance Retail Ventures Ltd   70000000000          2020
# 1760                     Snowflake    3000000000          2020
# 1585                      Reliance    2200000000          2020
# 1853                        Swiggy    1956000000          8079
# 2035              VerSe Innovation    1550000000          6062
# 163                         BYJU'S    1260000000          8084
# 507                   Dream Sports    1240000000          4042
# 2188                        Zomato    1239000000         14138
# 2176                       Zetwerk     925200000         12122

# %%
# Creating a bar chart to illustrate the top 10 most funded start-ups

Most_Funded_Startups_Chart = sns.barplot(x = Most_Funded_Startups["Amount($)"], y = Most_Funded_Startups["Company/Brand"], orient = 'h', errorbar = None);
Most_Funded_Startups_Chart.set(xlabel = "Funding Amount Received", ylabel = "Company/Brand", title = "Top 10 Start-Ups That Received The Most Funding");

# %% [markdown]
# This means that Alteria Capital got the highest funding amount (150,000,000,000 US Dollars), followed by Reliance Ventures Ltd (70,000,000,000 US Dollars), Snowflake (3,000,000,000 US Dollars), Reliance (2,200,000,000 US Dollars), Swiggy(1,956,000,000 US Dollars), VerSe Innovation (1,550,000,000 US Dollars), BYJU'S (1,260,000,000 US Dollars), Dream Sports (1,240,000,000 US Dollars), Zomato (1,239,000,000 US Dollars) and Zetwerk (925,200,000 US Dollars).

# %% [markdown]
# # Question 4: What are the top ten start-ups that received the least funding?

# %%
# Sorting from the lowest to highest
Funded_Startups.sort_values(['Amount($)'], ascending = True, inplace=True)

# Selecting amounts greater than 0
Least_Funded_Startups = Funded_Startups[Funded_Startups['Amount($)']>0].head(10)
Least_Funded_Startups
# Out:
#                                  Company/Brand  Amount($)  Funding Year
# 348                           Classworks India       1460          2018
# 1303                    Next Digital Solutions       1460          2018
# 577   Enlyft Digital Solutions Private Limited       2920          2018
# 85            Antariksh Waste Ventures Pvt Ltd       7300          2018
# 1233                                    Mombay       7500          2018
# 769                                       Glii      10000          2021
# 129                                 Authmetrik      10000          2018
# 1180                                   Medicus      12700          2020
# 1879                                  Teach Us      12700          2020
# 1235                                    Monech      12700          2020

# %%
# Creating a bar chart to illustrate the top 10 least funded start-ups

Least_Funded_Startups_Chart = sns.barplot(x = Least_Funded_Startups["Amount($)"], y = Least_Funded_Startups["Company/Brand"], orient = 'h', errorbar = None);
Least_Funded_Startups_Chart.set(xlabel = "Funding Amount Received", ylabel = "Company/Brand", title = "Top 10 Start-Ups That Received The Least Funding");

# %% [markdown]
# This implies that Classworks India and Next Digital Solutions got the joint lowest funding amount (1,460 US Dollars), followed by Enlyft Digital Solutions Private Limited (1,460 US Dollars), Antariksh Waste Ventures Pvt Ltd (7,300 US Dollars) and Mombay (7,500 US Dollars). Glii and Authmetrik were next as they received (10,000 US Dollars), while Monech, Medicus and Teach Us followed with (12,700 US Dollars).

# %% [markdown]
# # Question 5: What are the top ten sectors that received the most funding?

# %%
# First, the amounts received by the start-ups will be grouped by Sector 

Funded_Sectors = df.groupby("Sector").sum(numeric_only=True).reset_index()
Funded_Sectors
# Out:
#                 Sector  Amount($)  Funding Year
# 0         Online Media          0          2021
# 1          3D Printing          0          2018
# 2                   AI   85346500         36360
# 3    AI & Data science    8000000          2020
# 4            AI & Debt          0          2020
# ..                 ...        ...           ...
# 593    Yoga & Wellness    2800000          2019
# 594    Yoga & wellness          0          4040
# 595          eMobility    1000000          2020
# 596            eSports     584000          2018
# 597             sports    2400000          8084
#
# [598 rows x 3 columns]

# %%
# Then, the top 10 highest funding amounts by sector will be obtained by sorting from the highest to lowest and applying .head(10)

Funded_Sectors.sort_values(["Amount($)"], ascending = False, inplace=True)
Most_Funded_Sectors = Funded_Sectors.head(10)
Most_Funded_Sectors
# Out:
#                                  Sector     Amount($)  Funding Year
# 268                             FinTech  153780510000        345534
# 485                              Retail   70542180000         50513
# 227                              EdTech    3716504500        295009
# 542                        Tech company    3022700000         20200
# 218                          E-commerce    2591052000        141437
# 429  Multinational conglomerate company    2200000000          2020
# 271                  Financial Services    2080802500        173727
# 56                           Automotive    2050388722        105035
# 230                              Edtech    1951624730        145433
# 282                       Food Delivery    1873076000         12110

# %%
# Creating a bar chart to illustrate the top 10 most funded sectors

Most_Funded_Sectors_Chart = sns.barplot(x = Most_Funded_Sectors["Amount($)"], y = Most_Funded_Sectors["Sector"], orient = 'h', errorbar = None);
Most_Funded_Sectors_Chart.set(xlabel = "Funding Amount Received", ylabel = "Sector", title = "Top 10 Sectors That Received The Most Funding");

# %% [markdown]
# # Question 6: What are the top ten sectors that received the least funding?

# %%
# Sorting from the lowest to highest
Funded_Sectors.sort_values(['Amount($)'], ascending = True, inplace=True)

# Selecting amounts greater than 0
Least_Funded_Sectors = Funded_Sectors[Funded_Sectors['Amount($)']>0].head(10)
Least_Funded_Sectors
# Out:
#                 Sector  Amount($)  Funding Year
# 204  Digital Marketing       1460          2018
# 585          Warehouse      54000          2020
# 362   Interior & decor     100000          2020
# 422       Milk startup     100000          2021
# 217           E-Sports     100000          2019
# 447       Oil & Energy     100000          2021
# 306         Government     100000          2018
# 383         Legal Tech     100000          2019
# 169       Credit Cards     100000          4036
# 189         Dating app     110000          2020

# %%
# Creating a bar chart to illustrate the top 10 least funded sectors

Least_Funded_Sectors_Chart = sns.barplot(x = Least_Funded_Sectors["Amount($)"], y = Least_Funded_Sectors["Sector"], orient = 'h', errorbar = None);
Least_Funded_Sectors_Chart.set(xlabel = "Funding Amount Received", ylabel = "Sector", title = "Top 10 Sectors That Received The Least Funding");

# %% [markdown]
# # Question 7: What are the top ten HeadQuarters that received the most funding?

# %%
# First, the amounts received by the start-ups will be grouped by HeadQuarters 

Funded_HeadQuarters = df.groupby("HeadQuarter").sum(numeric_only=True).reset_index()
Funded_HeadQuarters
# Out:
#             HeadQuarter     Amount($)  Funding Year
# 0             Ahmadabad       5300000         12126
# 1        Andhra Pradesh        800000          2021
# 2                 Assam             0          2021
# 3            Bangaldesh      22000000          2020
# 4               Bangkok       9000000          2020
# 5               Beijing     200000000          2021
# 6                Berlin     170000000          2020
# 7                 Bihar      38329000         10102
# 8            California    3419500000         36361
# 9            Chandigarh      24236000         20202
# 10         Chhattisgarh      15000000          2021
# 11                Delhi    4252140240        644372
# 12                  Goa       3864500         12121
# 13              Gujarat     292471300         86862
# 14               Guntur        130000          2018
# 15              Haryana    8197616180        705015
# 16            Hyderebad       1100000          2020
# 17            Jharkhand        100000          4042
# 18              Jiaxing     176000000          2020
# 19            Karnataka   23961669610       1866544
# 20               Kerala      40787520         44431
# 21               London     144200000          6061
# 22       Madhya Pradesh      18485200         34330
# 23          Maharashtra  233189364405       1195841
# 24           Manchester      75000000          2021
# 25                Milan       2300000          2020
# 26                  N/A    2027544300        242377
# 27             New York      19500000          8081
# 28  Newcastle Upon Tyne        300000          2020
# 29               Odisha      45000000          6062
# 30            Palmwoods             0          2020
# 31                Paris      16400000          4040
# 32               Punjab      20000000          6059
# 33             Rajastan       1000000          2020
# 34            Rajasthan     625383460         82807
# 35               Riyadh       1300000          2020
# 36              Seattle       1100000          2020
# 37                Seoul       1400000          2020
# 38             Shanghai     400000000          2020
# 39             Silvassa       1000000          2021
# 40            Singapore      13980000          8080
# 41               Sydney      22500000          4040
# 42           Tamil Nadu    1401925826        236334
# 43            Tangerang      12000000          2020
# 44            Telangana     420662440        161596
# 45                Texas       3000000          4040
# 46        Uttar Pradesh     596949000        201994
# 47          Uttarakhand       2000000          4041
# 48          West Bengal      70186500         46454

# %%
# Then, the top 10 highest funding amounts by HeadQuarters will be obtained by sorting from the highest to lowest and applying .head(10)

Funded_HeadQuarters.sort_values(["Amount($)"], ascending = False, inplace=True)
Most_Funded_HeadQuarters = Funded_HeadQuarters.head(10)
Most_Funded_HeadQuarters
# Out:
#       HeadQuarter     Amount($)  Funding Year
# 23    Maharashtra  233189364405       1195841
# 19      Karnataka   23961669610       1866544
# 15        Haryana    8197616180        705015
# 11          Delhi    4252140240        644372
# 8      California    3419500000         36361
# 26            N/A    2027544300        242377
# 42     Tamil Nadu    1401925826        236334
# 34      Rajasthan     625383460         82807
# 46  Uttar Pradesh     596949000        201994
# 44      Telangana     420662440        161596

# %%
# Creating a bar chart to illustrate the top 10 most funded HeadQuarters

Most_Funded_HeadQuarters_Chart = sns.barplot(x = Most_Funded_HeadQuarters["Amount($)"], y = Most_Funded_HeadQuarters["HeadQuarter"], orient = 'h', errorbar = None);
Most_Funded_HeadQuarters_Chart.set(xlabel = "Funding Amount Received", ylabel = "HeadQuarter", title = "Top 10 HeadQuarters That Received The Most Funding");

# %% [markdown]
# This implies that start-ups in Maharashtra received the highest funding amount (233,189,364,405 US Dollars), followed by start-ups in Karnataka (23,961,669,610	US Dollars), Haryana (8,197,616,180 US Dollars), Delhi (4,252,140,240 US Dollars), California (3,419,500,000 US Dollars), Tamil Nadu (1,401,925,826 US Dollars), Rajasthan (625,383,460 US Dollars), Uttar Pradesh (596,949,000 US Dollars) and Telangana (420,662,440 US Dollars). The funding amount in unknown locations, designated as N/A is 2,027,544,300 US Dollars.

# %% [markdown]
# # Question 8: What are the top ten HeadQuarters that received the least funding?

# %%
# Sorting from the lowest to highest
Funded_HeadQuarters.sort_values(['Amount($)'], ascending = True, inplace=True)

# Selecting amounts greater than 0
Least_Funded_HeadQuarters = Funded_HeadQuarters[Funded_HeadQuarters['Amount($)']>0].head(10)
Least_Funded_HeadQuarters
# Out:
#             HeadQuarter  Amount($)  Funding Year
# 17            Jharkhand     100000          4042
# 14               Guntur     130000          2018
# 28  Newcastle Upon Tyne     300000          2020
# 1        Andhra Pradesh     800000          2021
# 39             Silvassa    1000000          2021
# 33             Rajastan    1000000          2020
# 36              Seattle    1100000          2020
# 16            Hyderebad    1100000          2020
# 35               Riyadh    1300000          2020
# 37                Seoul    1400000          2020

# %%
# Creating a horizontal bar chart to illustrate the top 10 least funded HeadQuarters

Least_Funded_HeadQuarters_Chart = sns.barplot(x = Least_Funded_HeadQuarters["Amount($)"], y = Least_Funded_HeadQuarters["HeadQuarter"], orient = 'h', errorbar = None);
Least_Funded_HeadQuarters_Chart.set(xlabel = "Funding Amount Received", ylabel = "HeadQuarter", title = "Top 10 HeadQuarters That Received The Least Funding");

# %% [markdown]
# This implies that start-ups in Jharkand received the least funding amount (100,000 US Dollars), folllowed by start-ups in Guntur (130,000 US Dollars), Newcastle Upon Tyne (300,000 US Dollars), Andhra Pradesh (800,000 US Dollars), Silvassa and Rajastan (1,000,000 US Dollars) each, Seattle and Hyderebad (1,100,000 US Dollars) each, Riyadh (1,300,000 US Dollars) and Seoul (1,400,000 US Dollars). Most of these locations are not in India.

# %% [markdown]
# # Question 9: What is the trend of funding received by the top 5 HeadQuarters from 2018 to 2021
#
# From the answer to Question 7, it is seen that the top 5 Headquarters that received the highest funding are Maharashtra (233,189,364,405 US Dollars), Karnataka (23,961,669,610	US Dollars), Haryana (8,197,616,180 US Dollars), Delhi (4,252,140,240 US Dollars) and California (3,419,500,000 US Dollars) in descending order.

# %%
# Grouping 'Maharashtra','Karnataka','Haryana', 'Delhi','California' in the HeadQuarter column by the funding years
Top_5_HeadQuarter_Funding_Trend = df.query("HeadQuarter == ['Maharashtra','Karnataka','Haryana', 'Delhi','California']").groupby(["HeadQuarter","Funding Year"]).sum(numeric_only=True).reset_index()

# Sorting the funding year in ascending order
Top_5_HeadQuarter_Funding_Trend.sort_values(["Funding Year"], ascending = True, inplace=True)
Top_5_HeadQuarter_Funding_Trend
# Out:
#     HeadQuarter  Funding Year     Amount($)
# 2         Delhi          2018     530600040
# 14  Maharashtra          2018    1879167905
# 6       Haryana          2018    1020328380
# 10    Karnataka          2018    2686285252
# 15  Maharashtra          2019     378500000
# 3         Delhi          2019     355300000
# 7       Haryana          2019     790700000
# 11    Karnataka          2019     824900000
# 0    California          2020    3419500000
# 12    Karnataka          2020    5162449358
# 8       Haryana          2020    1698002800
# 16  Maharashtra          2020   76057061500
# 4         Delhi          2020    1311084200
# 5         Delhi          2021    2055156000
# 13    Karnataka          2021   15288035000
# 1    California          2021             0
# 9       Haryana          2021    4688585000
# 17  Maharashtra          2021  154874635000

# %%
# Creating a bar chart to illustrate the top 5 headQuarter funding trend

sns.barplot(x = Top_5_HeadQuarter_Funding_Trend["Funding Year"], y = Top_5_HeadQuarter_Funding_Trend["Amount($)"], hue = Top_5_HeadQuarter_Funding_Trend["HeadQuarter"])
plt.title("Top 5 HeadQuarter Funding Trend from 2018 to 2021")

# Shifting the legend to the middle
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1))

# %% [markdown]
# This implies that Maharashtra received very high funding in 2020 and 2021 compared to other locations.

# %% [markdown]
# # Conclusion
#
# The top 5 locations where start=ups received the highest funding are Maharashtra (233,189,364,405 US Dollars), Karnataka (23,961,669,610 US Dollars), Haryana (8,197,616,180 US Dollars), Delhi (4,252,140,240 US Dollars) and California (3,419,500,000 US Dollars) in descending order.
#
# Since the F-Statistic (0.04439448715568275) is less than the Significance Level (0.05), we fail to reject the null hypothesis. This implies that our null hypothesis (the sector does not influence the funding amounts received by the start-ups) is correct.

# %% [markdown]
# # Recommendation
#
# Intending start-ups are advised to explore Maharashtra, Karnataka or Haryana as start-ups in these states are likely to secure high funding amounts according to the analysis done.
